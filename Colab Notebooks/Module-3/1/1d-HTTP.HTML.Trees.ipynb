# %% [markdown]
# # curl, Requests, XPath, and CSS selectors

# %% [markdown]
# Setup

# %%
# %%capture output
# %%bash
apt-get update
apt-get install -y tree

# %% [markdown]
# ## Resources
#
# - [Introduction to web scraping]( https://carpentries-incubator.github.io/lc-webscraping/ )
#
#
#   - [Selecting content on a web page with XPath]( https://carpentries-incubator.github.io/lc-webscraping/02-xpath/index.html )
#
#   - [Web scraping using Python and Scrapy]( https://carpentries-incubator.github.io/lc-webscraping/04-scrapy/index.html )
#
# - [Playwright]( https://playwright.dev/python/ )
#
# - [HTML Scraping](https://python-docs.readthedocs.io/en/latest/scenarios/scrape.html)
#
# - [Parsing HTML with Beautiful Soup 4](https://automatetheboringstuff.com/2e/chapter12/#:~:text=Parsing%20HTML%20with%20the%20bs4%20Module)
#
#   - [Sample files as zip](https://nostarch.com/download/Automate_the_Boring_Stuff_onlinematerials_v.2.zip)
#
# - [CSS Selector notation]( https://www.w3schools.com/cssref/css_selectors.php )

# %% [markdown]
# ## Hyper Text Markup Language ( HTML )

# %% [markdown]
# "HTML describes the structure of a web page semantically and originally included cues for its appearance."
#
# Features:
# - Text with "markup"
# - markup == HTML elements/tags
# - most tags paired, <html> ... </html>
# - nested: tags within tags forming a hierarchy or tree
#
# The term was coined by [Ted Nelson]( https://en.wikipedia.org/wiki/Ted_Nelson ) around 1963 and implemented by [Tim Berners-Lee]( https://en.wikipedia.org/wiki/Tim_Berners-Lee ) in 1989.
#
# A simple [markup example.]( https://en.wikipedia.org/wiki/HTML#Markup )

# %% [markdown]
# ## Viewing HTML from the browser

# %% [markdown]
# ### Example.com

# %% [markdown]
# One way:
# 1. View the webpage at http://www.example.com
# 1. View the source ( Ctrl+U )
#
# Another way:
# 1. Open Developer tools ( Ctrl+Shift+I )
# 1. Click on the Elements tab
# 1. Alt+click or right+click on the "<html>" tag and select "Expand Recursively"

# %% [markdown]
# Locating individual elements:
# 1. Click on the "Select an Element" arrow ( Ctrl+Shift+C )
# 1. Click on the text "More information..."
#
# Notice that the corresponding section of HTML is highlighted.  You can also click on a section of HTML and the corresponding element in the page will be highlighted.

# %% [markdown]
# ### ABQ Library

# %% [markdown]
# One way:
# 1. Visit [ABQ databases]( https://abqlibrary.org/az.php?p=1 )
# 1. View the source ( Ctrl+U )
#
# Another way:
# 1. Open Developer tools ( Ctrl+Shift+I )
# 1. Click on the Elements tab
# 1. Alt+click or right+click on the "<html>" tag and select "Expand Recursively"

# %% [markdown]
# ## From the command line

# %%
# !curl http://www.example.com
# Out:
# <!doctype html>
# <html>
# <head>
#     <title>Example Domain</title>
#
#     <meta charset="utf-8" />
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
#
# <body>
# <div>
#     <h1>Example Domain</h1>
#     <p>This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.</p>
#     <p><a href="https://www.iana.org/domains/example">More information...</a></p>
# </div>
# </body>
# </html>

# %%
# !curl -v https://abqlibrary.org/az.php?p=1
# Out:
# *   Trying 34.194.39.199:443...
# * Connected to abqlibrary.org (34.194.39.199) port 443 (#0)
# * ALPN, offering h2
# * ALPN, offering http/1.1
# *  CAfile: /etc/ssl/certs/ca-certificates.crt
# *  CApath: /etc/ssl/certs
# * TLSv1.0 (OUT), TLS header, Certificate Status (22):
# * TLSv1.3 (OUT), TLS handshake, Client hello (1):
# * TLSv1.2 (IN), TLS header, Certificate Status (22):
# * TLSv1.3 (IN), TLS handshake, Server hello (2):
# * TLSv1.2 (IN), TLS header, Finished (20):
# * TLSv1.2 (IN), TLS header, Supplemental data (23):
# * TLSv1.3 (IN), TLS handshake, Encrypted Extensions (8):
# * TLSv1.2 (IN), TLS header, Supplemental data (23):
# * TLSv1.3 (IN), TLS handshake, Certificate (11):
# * TLSv1.2 (IN), TLS header, Supplemental data (23):
# * TLSv1.3 (IN), TLS handshake, CERT verify (15):
# * TLSv1.2 (IN), TLS header, Supplemental data (23):
# * TLSv1.3 (IN), TLS handshake, Finished (20):
# * TLSv1.2 (OUT), TLS header, Finished (20):
# * TLSv1.3 (OUT), TLS change cipher, Change cipher spec (1):
# * TLSv1.2 (OUT), TLS header, Supplemental data (23):
# * TLSv1.3 (OUT), TLS handshake, Finished (20):
# * SSL connection using TLSv1.3 / TLS_AES_256_GCM_SHA384
# * ALPN, server accepted to use h2
# * Server certificate:
# *  subject: CN=abqlibrary.org
# *  start date: May  1 12:02:43 2024 GMT
# *  expire date: Jul 30 12:02:42 2024 GMT
# *  subjectAltName: host "abqlibrary.org" matched cert's "abqlibrary.org"
# *  issuer: C=US; O=Let's Encrypt; CN=R3
# *  SSL certificate verify ok.
# * Using HTTP2, server supports multiplexing
# * Connection state changed (HTTP/2 confirmed)
# * Copying HTTP/2 data in stream buffer to connection buffer after upgrade: len=0
# * TLSv1.2 (OUT), TLS header, Supplemental data (23):
# * TLSv1.2 (OUT), TLS header, Supplemental data (23):
# * TLSv1.2 (OUT), TLS header, Supplemental data (23):
# * Using Stream ID: 1 (easy handle 0x581d72020eb0)
# * TLSv1.2 (OUT), TLS header, Supplemental data (23):
# > GET /az.php?p=1 HTTP/2
# > Host: abqlibrary.org
# > user-agent: curl/7.81.0
# > accept: */*
# >
# * TLSv1.2 (IN), TLS header, Supplemental data (23):
# * TLSv1.3 (IN), TLS handshake, Newsession Ticket (4):
# * TLSv1.2 (IN), TLS header, Supplemental data (23):
# * TLSv1.3 (IN), TLS handshake, Newsession Ticket (4):
# * old SSL session ID is stale, removing
# * TLSv1.2 (IN), TLS header, Supplemental data (23):
# * Connection state changed (MAX_CONCURRENT_STREAMS == 128)!
# * TLSv1.2 (OUT), TLS header, Supplemental data (23):
# * TLSv1.2 (IN), TLS header, Supplemental data (23):
# * TLSv1.2 (IN), TLS header, Supplemental data (23):
# < HTTP/2 302
# < server: nginx
# < date: Mon, 17 Jun 2024 16:16:31 GMT
# < content-type: text/html; charset=UTF-8
# < location: /az/databases
# < x-backend-server: libguides-us-4.springyaws.com
# < x-content-type-options: nosniff
# < content-security-policy: upgrade-insecure-requests
# < strict-transport-security: max-age=31536000; preload
# <
# * Connection #0 to host abqlibrary.org left intact

# %% [markdown]
# ## Hyper Text Transfer Protocol ( HTTP )

# %% [markdown]
# From [Wikipedia: HTTP]( https://en.wikipedia.org/wiki/HTTP )
#
# "The Hypertext Transfer Protocol (HTTP) is an application layer protocol in the Internet protocol suite model for distributed, collaborative, hypermedia information systems."
#
# "In 1991, the first documented official version of HTTP ..., HTTP/0.9, supported only GET method, allowing clients to only retrieve HTML documents from the server, but not supporting any other file formats or information upload."
#
# Features:
# - Data flows as a Request/Response pair
# - Connections are "stateless", i.e. the server doesn't remember previous requests/responses.
# - Requests contain a "verb" and key:value pairs in a Header, and sometimes a payload.
# - Responses contain a "status" and key:value pairs in a Header, and often a payload.

# %% [markdown]
# Although the protocol has a number of methods/verbs, we will be primarily using GET, HEAD, and POST methods.
# - [HTTP methods]( https://en.wikipedia.org/wiki/HTTP#Request_methods )

# %% [markdown]
# ### Viewing request/response pair from the browser

# %% [markdown]
# 1. View the webpage at http://www.example.com
# 1. Open Developer tools ( Ctrl+Shift+I )
# 1. Click on the Network tab
# 1. Refresh the page
# 1. Under the Name field, click on "www.example.com"
# 1. Scroll down to see the General, Request, and Response sections.
# 1. Click on the Raw checkbox.
# 1. Click on the Response tab to view the response payload.

# %% [markdown]
# ### Viewing request/response pair with curl

# %% [markdown]
# Requests have a "> " at the beginning of the line.
#
# Responses have a "< " at the beginning of the line.

# %%
# !curl --help
# Out:
# Usage: curl [options...] <url>
#  -d, --data <data>          HTTP POST data
#  -f, --fail                 Fail silently (no output at all) on HTTP errors
#  -h, --help <category>      Get help for commands
#  -i, --include              Include protocol response headers in the output
#  -o, --output <file>        Write to file instead of stdout
#  -O, --remote-name          Write output to a file named as the remote file
#  -s, --silent               Silent mode
#  -T, --upload-file <file>   Transfer local FILE to destination
#  -u, --user <user:password> Server user and password
#  -A, --user-agent <name>    Send User-Agent <name> to server
#  -v, --verbose              Make the operation more talkative
#  -V, --version              Show version number and quit
#
# This is not the full help, this menu is stripped into categories.
# Use "--help category" to get an overview of all categories.
# For all options use the manual or "--help all".

# %%
# !curl -s -v http://www.example.com
# Out:
# *   Trying 93.184.215.14:80...
# * Connected to www.example.com (93.184.215.14) port 80 (#0)
# > GET / HTTP/1.1
# > Host: www.example.com
# > User-Agent: curl/7.81.0
# > Accept: */*
# >
# * Mark bundle as not supporting multiuse
# < HTTP/1.1 200 OK
# < Accept-Ranges: bytes
# < Age: 336833
# < Cache-Control: max-age=604800
# < Content-Type: text/html; charset=UTF-8
# < Date: Mon, 17 Jun 2024 16:16:32 GMT
# < Etag: "3147526947"
# < Expires: Mon, 24 Jun 2024 16:16:32 GMT
# < Last-Modified: Thu, 17 Oct 2019 07:18:26 GMT
# < Server: ECAcc (sed/5906)
# < Vary: Accept-Encoding
# < X-Cache: HIT
# < Content-Length: 1256
# <
# <!doctype html>
# <html>
# <head>
#     <title>Example Domain</title>
#
#     <meta charset="utf-8" />
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
#
# <body>
# <div>
#     <h1>Example Domain</h1>
#     <p>This domain is for use in illustrative examples in documents. You may use this
#     domain in literature without prior coordination or asking for permission.</p>
#     <p><a href="https://www.iana.org/domains/example">More information...</a></p>
# </div>
# </body>
# </html>
# * Connection #0 to host www.example.com left intact

# %% [markdown]
# ## Using Python

# %% [markdown]
# ### Fetching files/pages using the requests module

# %%
import requests
import json

# %%
page = requests.get('http://www.example.com')

# %%
dict(page.headers)
# Out:
# {'Content-Encoding': 'gzip',
#  'Age': '336833',
#  'Cache-Control': 'max-age=604800',
#  'Content-Type': 'text/html; charset=UTF-8',
#  'Date': 'Mon, 17 Jun 2024 16:16:32 GMT',
#  'Etag': '"3147526947+gzip"',
#  'Expires': 'Mon, 24 Jun 2024 16:16:32 GMT',
#  'Last-Modified': 'Thu, 17 Oct 2019 07:18:26 GMT',
#  'Server': 'ECAcc (sed/5906)',
#  'Vary': 'Accept-Encoding',
#  'X-Cache': 'HIT',
#  'Content-Length': '648'}

# %%
page.reason, page.status_code
# Out:
# ('OK', 200)

# %%
[
page.request.url,
page.request.method,
page.request.path_url,
page.request.headers,
page.request.body,
]
# Out:
# ['http://www.example.com/',
#  'GET',
#  '/',
#  {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'},
#  None]

# %%
page.url
# Out:
# 'http://www.example.com/'

# %%
page.connection

# %%
page.cookies
# Out:
# <RequestsCookieJar[]>

# %%
page.text
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n    <h1>Example Domain</h1>\n    <p>This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.</p>\n    <p><a href="https://www.iana.org/domains/example">More information...</a></p>\n</div>\n</body>\n</html>\n'

# %%
page.content
# Out:
# b'<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n    <h1>Example Domain</h1>\n    <p>This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.</p>\n    <p><a href="https://www.iana.org/domains/example">More information...</a></p>\n</div>\n</body>\n</html>\n'

# %%
type(page)
# Out:
# requests.models.Response

# %% [markdown]
# ## Trees

# %% [markdown]
# From [Wikipedia: Tree (Graph)]( https://en.wikipedia.org/wiki/Tree_(graph_theory) )
#
# "In graph theory, a tree is an undirected graph in which any two vertices are connected by exactly one path, or equivalently a connected acyclic undirected graph."
#
# Structure:
# - Type of graph, i.e. nodes and edges
# - Zero or one parent node
# - Zero or more children nodes
#
# Nomenclature:
# - Nodes
# - Edges
# - Directed edge
# - Levels, up, down
# - Parent, child, sibling
# - Ancestors, descendants
# - Root ( no parent )
# - Branches ( parents and children )
# - Leaves ( no children )
# - Path: sequence of nodes and edges between two nodes
# - Traversing, recursing; depth first, breadth first
#
# Type of trees:
# - Binary: at most two children
# - Balanced: equal number of levels for all children
#
#
# Examples:
# - Filesystem
# - Org charts
# - Family pedigrees
# - HTML, XML, JSON, YAML

# %% [markdown]
# Example: `tree` command for viewing the filesystem

# %%
# !tree /etc/apt
# Out:
# /etc/apt
# ├── apt.conf.d
# │   ├── 01autoremove
# │   ├── 01-vendor-ubuntu
# │   ├── 20packagekit
# │   ├── 70debconf
# │   ├── 90assumeyes
# │   ├── docker-autoremove-suggests
# │   ├── docker-clean
# │   ├── docker-disable-periodic-update
# │   ├── docker-gzip-indexes
# │   └── docker-no-languages
# ├── auth.conf.d
# ├── keyrings
# ├── preferences.d
# │   └── cuda-repository-pin-600
# ├── sources.list
# ├── sources.list.d
# │   ├── archive_uri-https_cloud_r-project_org_bin_linux_ubuntu-jammy.list
# │   ├── c2d4u_team-ubuntu-c2d4u4_0_-jammy.list
# │   ├── cuda-ubuntu2204-x86_64.list
# │   ├── deadsnakes-ubuntu-ppa-jammy.list
# │   ├── graphics-drivers-ubuntu-ppa-jammy.list
# │   └── ubuntugis-ubuntu-ppa-jammy.list
# └── trusted.gpg.d
#     ├── c2d4u_team-ubuntu-c2d4u4_0_.gpg
#     ├── c2d4u_team-ubuntu-c2d4u4_0_.gpg~
#     ├── cran_ubuntu_key.asc
#     ├── deadsnakes-ubuntu-ppa.gpg
#     ├── deadsnakes-ubuntu-ppa.gpg~
#     ├── graphics-drivers-ubuntu-ppa.gpg
#     ├── graphics-drivers-ubuntu-ppa.gpg~
#     ├── ubuntugis-ubuntu-ppa.gpg
#     ├── ubuntugis-ubuntu-ppa.gpg~
#     ├── ubuntu-keyring-2012-cdimage.gpg
#     └── ubuntu-keyring-2018-archive.gpg
#
# 6 directories, 29 files

# %%
# !find /etc/apt
# Out:
# /etc/apt
# /etc/apt/preferences.d
# /etc/apt/preferences.d/cuda-repository-pin-600
# /etc/apt/sources.list.d
# /etc/apt/sources.list.d/archive_uri-https_cloud_r-project_org_bin_linux_ubuntu-jammy.list
# /etc/apt/sources.list.d/cuda-ubuntu2204-x86_64.list
# /etc/apt/sources.list.d/c2d4u_team-ubuntu-c2d4u4_0_-jammy.list
# /etc/apt/sources.list.d/graphics-drivers-ubuntu-ppa-jammy.list
# /etc/apt/sources.list.d/deadsnakes-ubuntu-ppa-jammy.list
# /etc/apt/sources.list.d/ubuntugis-ubuntu-ppa-jammy.list
# /etc/apt/trusted.gpg.d
# /etc/apt/trusted.gpg.d/ubuntu-keyring-2018-archive.gpg
# /etc/apt/trusted.gpg.d/ubuntu-keyring-2012-cdimage.gpg
# /etc/apt/trusted.gpg.d/deadsnakes-ubuntu-ppa.gpg~
# /etc/apt/trusted.gpg.d/ubuntugis-ubuntu-ppa.gpg~
# /etc/apt/trusted.gpg.d/deadsnakes-ubuntu-ppa.gpg
# /etc/apt/trusted.gpg.d/graphics-drivers-ubuntu-ppa.gpg
# /etc/apt/trusted.gpg.d/c2d4u_team-ubuntu-c2d4u4_0_.gpg~
# /etc/apt/trusted.gpg.d/c2d4u_team-ubuntu-c2d4u4_0_.gpg
# /etc/apt/trusted.gpg.d/cran_ubuntu_key.asc
# /etc/apt/trusted.gpg.d/graphics-drivers-ubuntu-ppa.gpg~
# /etc/apt/trusted.gpg.d/ubuntugis-ubuntu-ppa.gpg
# /etc/apt/sources.list
# /etc/apt/keyrings
# /etc/apt/auth.conf.d
# /etc/apt/apt.conf.d
# /etc/apt/apt.conf.d/docker-no-languages
# /etc/apt/apt.conf.d/docker-autoremove-suggests
# /etc/apt/apt.conf.d/70debconf
# /etc/apt/apt.conf.d/docker-clean
# /etc/apt/apt.conf.d/01autoremove
# /etc/apt/apt.conf.d/docker-gzip-indexes
# /etc/apt/apt.conf.d/docker-disable-periodic-update
# /etc/apt/apt.conf.d/01-vendor-ubuntu
# /etc/apt/apt.conf.d/90assumeyes
# /etc/apt/apt.conf.d/20packagekit

# %% [markdown]
# ## Beautiful Soup and CSS selectors

# %%
# %%capture
# %%bash
curl -s -L -O https://nostarch.com/download/Automate_the_Boring_Stuff_onlinematerials_v.2.zip
unzip -jo Automate_the_Boring_Stuff_onlinematerials_v.2.zip automate_online-materials/example.html

# %%
# !unzip -l Automate_the_Boring_Stuff_onlinematerials_v.2.zip
# Out:
# Archive:  Automate_the_Boring_Stuff_onlinematerials_v.2.zip
#   Length      Date    Time    Name
# ---------  ---------- -----   ----
#         0  2018-08-27 09:25   automate_online-materials/
#    582952  2015-03-30 08:51   automate_online-materials/alarm.wav
#       461  2015-03-30 08:51   automate_online-materials/allMyCats1.py
#       311  2015-03-30 08:51   automate_online-materials/allMyCats2.py
#      1415  2015-03-30 09:03   automate_online-materials/backupToZip.py
#       493  2015-03-30 08:51   automate_online-materials/birthdays.py
#       633  2015-03-30 11:55   automate_online-materials/boxPrint.py
#       223  2015-03-30 08:51   automate_online-materials/buggyAddingProgram.py
#       399  2015-03-30 09:17   automate_online-materials/bulletPointAdder.py
#       310  2015-03-30 09:18   automate_online-materials/calcProd.py
#     16726  2014-09-24 11:05   automate_online-materials/catlogo.png
#       121  2015-03-30 09:19   automate_online-materials/catnapping.py
#    155379  2015-03-30 08:51   automate_online-materials/census2010.py
#   2246155  2015-03-30 08:51   automate_online-materials/censuspopdata.xlsx
#       225  2015-03-30 08:51   automate_online-materials/characterCount.py
#       214  2015-03-30 08:51   automate_online-materials/coinFlip.py
#    517813  2015-03-30 08:51   automate_online-materials/combinedminutes.pdf
#       819  2015-03-30 09:25   automate_online-materials/combinePdfs.py
#       305  2015-03-30 09:29   automate_online-materials/countdown.py
#     42624  2015-03-30 09:33   automate_online-materials/demo.docx
#    454061  2015-03-30 08:51   automate_online-materials/dictionary.txt
#      5393  2015-03-30 08:51   automate_online-materials/dimensions.xlsx
#      1149  2015-03-30 09:38   automate_online-materials/downloadXkcd.py
#      8903  2015-03-30 08:51   automate_online-materials/duesRecords.xlsx
#    316481  2015-03-30 08:51   automate_online-materials/encrypted.pdf
#    235840  2015-03-30 08:51   automate_online-materials/encryptedminutes.pdf
#       103  2015-03-30 08:51   automate_online-materials/errorExample.py
#       191  2015-03-30 08:51   automate_online-materials/example.csv
#       324  2015-03-30 08:51   automate_online-materials/example.html
#      9898  2015-03-30 08:51   automate_online-materials/example.xlsx
#    382809  2015-03-30 08:51   automate_online-materials/example.zip
#    210691  2018-08-27 09:18   automate_online-materials/excelSpreadsheets.zip
#       170  2015-03-31 10:38   automate_online-materials/exitExample.py
#       478  2015-03-31 10:38   automate_online-materials/factorialLog.py
#        87  2015-03-31 10:39   automate_online-materials/fiveTimes.py
#      2757  2015-03-31 10:52   automate_online-materials/formFiller.py
#    504006  2015-03-30 08:51   automate_online-materials/freezeExample.xlsx
#       214  2015-03-30 08:51   automate_online-materials/getDocxText.py
#       675  2015-03-30 10:06   automate_online-materials/guessTheNumber.py
#        60  2015-03-30 08:51   automate_online-materials/guests.txt
#     34883  2015-03-30 08:51   automate_online-materials/headings.docx
#       370  2015-03-30 08:51   automate_online-materials/hello.py
#       114  2015-03-30 08:51   automate_online-materials/helloFunc.py
#        78  2015-03-30 08:51   automate_online-materials/helloFunc2.py
#     34837  2015-03-30 08:51   automate_online-materials/helloworld.docx
#       352  2015-03-30 08:51   automate_online-materials/inventory.py
#       812  2015-03-30 10:12   automate_online-materials/isPhoneNumber.py
#       163  2015-03-30 11:37   automate_online-materials/littleKid.py
#       555  2015-03-30 10:14   automate_online-materials/lucky.py
#       693  2015-03-30 08:51   automate_online-materials/magic8Ball.py
#       314  2015-03-30 08:51   automate_online-materials/magic8Ball2.py
#       392  2015-03-30 10:18   automate_online-materials/mapIt.py
#       732  2015-03-30 10:23   automate_online-materials/mcb.pyw
#    246927  2015-03-30 08:51   automate_online-materials/meetingminutes.pdf
#    301513  2015-03-30 08:51   automate_online-materials/meetingminutes2.pdf
#      5450  2015-03-30 08:51   automate_online-materials/merged.xlsx
#       454  2015-03-30 10:27   automate_online-materials/mouseNow.py
#       704  2015-03-30 10:29   automate_online-materials/mouseNow2.py
#      1613  2015-03-30 10:33   automate_online-materials/multidownloadXkcd.py
#     34907  2015-03-30 08:51   automate_online-materials/multipleParagraphs.docx
#       198  2015-03-30 08:51   automate_online-materials/myPets.py
#       106  2015-03-30 08:51   automate_online-materials/passingReference.py
#      1235  2015-03-30 10:39   automate_online-materials/phoneAndEmail.py
#       361  2015-03-30 08:51   automate_online-materials/picnicTable.py
#       248  2015-03-30 08:51   automate_online-materials/prettyCharacterCount.py
#        67  2015-03-31 10:39   automate_online-materials/printRandom.py
#    878030  2015-03-30 08:51   automate_online-materials/produceSales.xlsx
#       597  2015-03-30 10:43   automate_online-materials/pw.py
#       984  2015-03-30 10:46   automate_online-materials/quickWeather.py
#      3209  2015-03-30 10:51   automate_online-materials/randomQuizGenerator.py
#      1307  2015-03-30 10:56   automate_online-materials/readCensusExcel.py
#       210  2015-03-30 10:03   automate_online-materials/readDocx.py
#       958  2015-03-30 11:00   automate_online-materials/removeCsvHeader.py
#    678008  2015-03-30 08:51   automate_online-materials/removeCsvHeader.zip
#      1426  2015-03-30 11:03   automate_online-materials/renameDates.py
#      1430  2015-03-30 11:07   automate_online-materials/resizeAndAddLogo.py
#     48791  2015-03-30 11:08   automate_online-materials/restyled.docx
#       270  2015-03-30 08:51   automate_online-materials/sameName.py
#        89  2015-03-30 08:51   automate_online-materials/sameName2.py
#       231  2015-03-30 11:14   automate_online-materials/sameName3.py
#        91  2015-03-30 08:51   automate_online-materials/sameName4.py
#      7396  2015-03-30 08:51   automate_online-materials/sampleChart.xlsx
#      1392  2015-03-30 11:19   automate_online-materials/sendDuesReminders.py
#       823  2015-03-30 11:21   automate_online-materials/stopwatch.py
#      5376  2015-03-30 08:51   automate_online-materials/styled.xlsx
#      5447  2015-03-30 08:51   automate_online-materials/styles.xlsx
#       261  2015-03-31 10:39   automate_online-materials/swordfish.py
#       500  2015-03-30 11:25   automate_online-materials/textMyself.py
#       209  2015-03-30 08:51   automate_online-materials/threadDemo.py
#       707  2015-03-30 08:51   automate_online-materials/ticTacToe.py
#      3905  2015-03-30 11:31   automate_online-materials/torrentStarter.py
#     34868  2015-03-30 08:51   automate_online-materials/twoPage.docx
#    505451  2015-03-30 08:51   automate_online-materials/updatedProduceSales.xlsx
#       671  2015-03-30 11:34   automate_online-materials/updateProduce.py
#       379  2015-03-31 10:39   automate_online-materials/validateInput.py
#       247  2015-03-30 11:36   automate_online-materials/vampire.py
#       247  2015-03-30 11:35   automate_online-materials/vampire2.py
#     91339  2015-03-30 08:51   automate_online-materials/watermark.pdf
#       202  2015-03-30 08:51   automate_online-materials/zeroDivide.py
#   1364265  2015-03-30 08:51   automate_online-materials/zophie.png
# ---------                     -------
#  10009262                     100 files

# %%
pwd
# Out:
# '/content'

# %%
ls -l
# Out:
# total 8608
# -rw-r--r-- 1 root root 8802488 Jun 17 16:16 Automate_the_Boring_Stuff_onlinematerials_v.2.zip
# -rw-r--r-- 1 root root     324 Mar 30  2015 example.html
# drwxr-xr-x 1 root root    4096 Jun 13 13:28 sample_data/

# %%
# !cat -n example.html
# Out:
#      1	<!-- This is the example.html file. -->
#      2
#      3	<html><head><title>The Website Title</title></head>
#      4	<body>
#      5	<p>Download my <strong>Python</strong> book from <a href="http://inventwithpython.com">my website</a>.</p>
#      6	<p class="slogan">Learn Python the easy way!</p>
#      7	<p>By <span id="author">Al Sweigart</span></p>
#      8	</body></html>

# %%
import bs4

with open('example.html') as exampleFile:
  html = exampleFile.read()
exampleSoup = bs4.BeautifulSoup( html, 'html.parser')
print(html)
# Out:
# <!-- This is the example.html file. -->
#
# <html><head><title>The Website Title</title></head>
# <body>
# <p>Download my <strong>Python</strong> book from <a href="http://inventwithpython.com">my website</a>.</p>
# <p class="slogan">Learn Python the easy way!</p>
# <p>By <span id="author">Al Sweigart</span></p>
# </body></html>

# %%
html
# Out:
# '<!-- This is the example.html file. -->\n\n<html><head><title>The Website Title</title></head>\n<body>\n<p>Download my <strong>Python</strong> book from <a href="http://inventwithpython.com">my website</a>.</p>\n<p class="slogan">Learn Python the easy way!</p>\n<p>By <span id="author">Al Sweigart</span></p>\n</body></html>'

# %%
type(html)
# Out:
# str

# %%
for i, line in enumerate(html.split('\n')):
  print(i+1, line)
# Out:
# 1 <!-- This is the example.html file. -->
# 2
# 3 <html><head><title>The Website Title</title></head>
# 4 <body>
# 5 <p>Download my <strong>Python</strong> book from <a href="http://inventwithpython.com">my website</a>.</p>
# 6 <p class="slogan">Learn Python the easy way!</p>
# 7 <p>By <span id="author">Al Sweigart</span></p>
# 8 </body></html>

# %%
type(exampleSoup)
# Out:
# bs4.BeautifulSoup

# %%
elems = exampleSoup.select('#author')
elems
# Out:
# [<span id="author">Al Sweigart</span>]

# %%
type(elems) # elems is a list of Tag objects.
# Out:
# bs4.element.ResultSet

# %%
len(elems)
# Out:
# 1

# %%
elems[0]
# Out:
# <span id="author">Al Sweigart</span>

# %%
type(elems[0])
# Out:
# bs4.element.Tag

# %%
str(elems[0]) # The Tag object as a string.
# Out:
# '<span id="author">Al Sweigart</span>'

# %%
elems[0].getText()
# Out:
# 'Al Sweigart'

# %%
elems[0].attrs
# Out:
# {'id': 'author'}

# %%
pElems = exampleSoup.select('p')
pElems
# Out:
# [<p>Download my <strong>Python</strong> book from <a href="http://inventwithpython.com">my website</a>.</p>,
#  <p class="slogan">Learn Python the easy way!</p>,
#  <p>By <span id="author">Al Sweigart</span></p>]

# %%
len(pElems)
# Out:
# 3

# %%
pElems[:2]
# Out:
# [<p>Download my <strong>Python</strong> book from <a href="http://inventwithpython.com">my website</a>.</p>,
#  <p class="slogan">Learn Python the easy way!</p>]

# %%
pElems[0]
# Out:
# <p>Download my <strong>Python</strong> book from <a href="http://inventwithpython.com">my website</a>.</p>

# %%
type(pElems[0])
# Out:
# bs4.element.Tag

# %%
str(pElems[0])
# Out:
# '<p>Download my <strong>Python</strong> book from <a href="http://inventwithpython.com">my website</a>.</p>'

# %%
pElems[0].getText()
# Out:
# 'Download my Python book from my website.'

# %%
str(pElems[1])
# Out:
# '<p class="slogan">Learn Python the easy way!</p>'

# %%
pElems[1].getText()
# Out:
# 'Learn Python the easy way!'

# %%
str(pElems[2])
# Out:
# '<p>By <span id="author">Al Sweigart</span></p>'

# %%
pElems[2].getText()
# Out:
# 'By Al Sweigart'

# %%
aElems = exampleSoup.select('a')
aElems
# Out:
# [<a href="http://inventwithpython.com">my website</a>]

# %%
aElems[0]
# Out:
# <a href="http://inventwithpython.com">my website</a>

# %%
aElems[0].attrs
# Out:
# {'href': 'http://inventwithpython.com'}

# %%
aElems[0].attrs["href"]
# Out:
# 'http://inventwithpython.com'

# %%
exampleSoup.select("body")[0].get_text().split('\n')
# Out:
# ['',
#  'Download my Python book from my website.',
#  'Learn Python the easy way!',
#  'By Al Sweigart',
#  '']

# %% [markdown]
# ### Using DBpedia

# %%
dbpedia = requests.get("https://dbpedia.org/page/Digby_Morrell")
dbpedia
# Out:
# <Response [200]>

# %%
html = dbpedia.text
html
# Out:
# '<!DOCTYPE html>\n<html\n    prefix="\n        dbp: http://dbpedia.org/property/\n        dbo: http://dbedia.org/ontology/\n        dct: http://purl.org/dc/terms/\n        dbd: http://dbpedia.org/datatype/\n\tog:  https://ogp.me/ns#\n\t"\n>\n\n\n<!-- header -->\n<head>\n    <meta charset="utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n\n    <title>About: Digby Morrell</title>\n\n    <!-- Links -->\n    <link rel="alternate" type="application/rdf+xml" \t\thref="http://dbpedia.org/data/Digby_Morrell.rdf" title="Structured Descriptor Document (RDF/XML format)" />\n    <link rel="alternate" type="text/n3" \t\t\thref="http://dbpedia.org/data/Digby_Morrell.n3" title="Structured Descriptor Document (N3 format)" />\n    <link rel="alternate" type="text/turtle" \t\t\thref="http://dbpedia.org/data/Digby_Morrell.ttl" title="Structured Descriptor Document (Turtle format)" />\n    <link rel="alternate" type="application/json+rdf" \t\thref="http://dbpedia.org/data/Digby_Morrell.jrdf" title="Structured Descriptor Document (RDF/JSON format)" />\n    <link rel="alternate" type="application/json" \t\thref="http://dbpedia.org/data/Digby_Morrell.json" title="Structured Descriptor Document (RDF/JSON format)" />\n    <link rel="alternate" type="application/atom+xml" \t\thref="http://dbpedia.org/data/Digby_Morrell.atom" title="OData (Atom+Feed format)" />\n    <link rel="alternate" type="text/plain" \t\t\thref="http://dbpedia.org/data/Digby_Morrell.ntriples" title="Structured Descriptor Document (N-Triples format)" />\n    <link rel="alternate" type="text/csv"   \t\t\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fcsv" title="Structured Descriptor Document (CSV format)" />\n    \n    <link rel="alternate" type="application/microdata+json"\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=application%2Fmicrodata%2Bjson" title="Structured Descriptor Document (Microdata/JSON format)" />\n    <link rel="alternate" type="text/html" \t\t\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fhtml" title="Structured Descriptor Document (Microdata/HTML format)" />\n    <link rel="alternate" type="application/ld+json" \t\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=application%2Fld%2Bjson" title="Structured Descriptor Document (JSON-LD format)" />\n    <link rel="alternate" type="text/x-html-script-ld+json"\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fx-html-script-ld%2Bjson" title="Structured Descriptor Document (HTML with embedded JSON-LD)" />\n    <link rel="alternate" type="text/x-html-script-turtle"\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fx-html-script-turtle" title="Structured Descriptor Document (HTML with embedded Turtle)" />\n    <link rel="timegate" type="text/html" \t\t\thref="http://dbpedia.mementodepot.org/timegate/http://dbpedia.org/page/Digby_Morrell" title="Time Machine" />\n    <link rel="foaf:primarytopic" \t\t\t\thref="http://dbpedia.org/resource/Digby_Morrell"/>\n    <link rev="describedby" \t\t\t\t\thref="http://dbpedia.org/resource/Digby_Morrell"/>\n    <!-- /Links -->\n\n    <!-- Stylesheets -->\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap/5.2.1/css/bootstrap.min.css"\n\tintegrity="sha512-siwe/oXMhSjGCwLn+scraPOWrJxHlUgMBMZXdPe2Tnk3 ...

# %%
dom = bs4.BeautifulSoup(html, "html.parser")
dom
# Out:
# <!DOCTYPE html>
#
# <html prefix="
#         dbp: http://dbpedia.org/property/
#         dbo: http://dbedia.org/ontology/
#         dct: http://purl.org/dc/terms/
#         dbd: http://dbpedia.org/datatype/
# 	og:  https://ogp.me/ns#
# 	">
# <!-- header -->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>About: Digby Morrell</title>
# <!-- Links -->
# <link href="http://dbpedia.org/data/Digby_Morrell.rdf" rel="alternate" title="Structured Descriptor Document (RDF/XML format)" type="application/rdf+xml"/>
# <link href="http://dbpedia.org/data/Digby_Morrell.n3" rel="alternate" title="Structured Descriptor Document (N3 format)" type="text/n3"/>
# <link href="http://dbpedia.org/data/Digby_Morrell.ttl" rel="alternate" title="Structured Descriptor Document (Turtle format)" type="text/turtle"/>
# <link href="http://dbpedia.org/data/Digby_Morrell.jrdf" rel="alternate" title="Structured Descriptor Document (RDF/JSON format)" type="application/json+rdf"/>
# <link href="http://dbpedia.org/data/Digby_Morrell.json" rel="alternate" title="Structured Descriptor Document (RDF/JSON format)" type="application/json"/>
# <link href="http://dbpedia.org/data/Digby_Morrell.atom" rel="alternate" title="OData (Atom+Feed format)" type="application/atom+xml"/>
# <link href="http://dbpedia.org/data/Digby_Morrell.ntriples" rel="alternate" title="Structured Descriptor Document (N-Triples format)" type="text/plain"/>
# <link href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fcsv" rel="alternate" title="Structured Descriptor Document (CSV format)" type="text/csv"/>
# <link href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=application%2Fmicrodata%2Bjson" rel="alternate" title="Structured Descriptor Document (Microdata/JSON format)" type="application/microdata+json"/>
# <link href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fhtml" rel="alternate" title="Structured Descriptor Document (Microdata/HTML format)" type="text/html"/>
# <link href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=application%2Fld%2Bjson" rel="alternate" title="Structured Descriptor Document (JSON-LD format)" type="application/ld+json"/>
# <link href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fx-html-script-ld%2Bjson" rel="alternate" title="Structured Descriptor Document (HTML with embedded JSON-LD)" type="text/x-html-script-ld+json"/>
# <link href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fx-html-script-turtle" rel="alternate" title="Structured Descriptor Document (HTML with embedded Turtle)" type="text/x-html-script-turtle"/>
# <link href="http://dbpedia.mementodepot.org/timegate/http://dbpedia.org/page/Digby_Morrell" rel="timegate" title="Time Machine" type="text/html"/>
# <link href="http://dbpedia.org/resource/Digby_Morrell" rel="foaf:primarytopic"/>
# <link href="http://dbpedia.org/resource/Digby_Morrell" rev="describedby"/>
# <!-- /Links -->
# <!-- Stylesheets -->
# <link crossorigin="anonymous" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap/5.2.1/css/bootstrap.min.css" integrity="sha512-siwe/oXMhSjGCwLn+scraPOWrJxHlUgMBMZXdPe2Tnk3I0x3ESCoLz7WZ5NTH6SZrywMY+PB1cjyqJ5jAluCOg==" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap-icons/1.9.1/font/bootstrap-icons.min.css" integrity="sha512-5PV92qsds/16vyYIJo3T/As4m2d8b6oWYfoqV+vtizRB6KhF1F9kYzWzQmsO6T3z3QG2Xdhrx7FQ+5R1LiQdUA==" rel="stylesheet"/>
# <!-- link rel="stylesheet" href="/statics/css/dbpedia.css" -->
# <!-- /Stylesheets-->
# <!-- OpenGraph -->
# <meta content="Digby Morrell" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="http://dbpedia.org/resource/Digby_Morrell" property="og:url"/>
# <meta content="/statics/images/dbpedia_logo.png" property="og:image"/>
# <meta content="Digby Morrell (born 10 October 1979) is a former Australian rules footballer who played with the Kangaroos and Carlton in the Australian Football League (AFL). From Western Australia, Morrell played his early senior football for West Perth. His 44-game senior career for the Falcons spanned 1998–2000, and he was the club's leading goalkicker in 2000. At the age of 21, Morrell was recruited to the Australian Football League by the Kangaroos Football Club with its third round selection in the 2001 AFL Rookie Draft. As a forward he twice kicked five goals during his time with the Kangaroos. The first was in a losing cause against Sydney in 2002 and the other the following season in a drawn game against Brisbane." property="og:description"/>
# <meta content="DBpedia" property="og:site_name"/>
# <!-- /OpenGraph-->
# </head>
# <body about="http://dbpedia.org/resource/Digby_Morrell">
# <!-- navbar -->
# <nav class="navbar navbar-expand-md navbar-light bg-light fixed-top align-items-center">
# <div class="container-xl">
# <a class="navbar-brand" href="http://wiki.dbpedia.org/about" style="color: #2c5078" title="About DBpedia">
# <img alt="About DBpedia" class="img-fluid" src="/statics/images/dbpedia_logo_land_120.png"/>
# </a>
# <button aria-controls="dbp-navbar" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-bs-target="#dbp-navbar" data-bs-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse" id="dbp-navbar">
# <ul class="navbar-nav me-auto mb-2 mb-lg-0">
# <li class="nav-item dropdown">
# <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" id="navbarDropdownBrowse" role="button">
# <i class="bi-eye-fill"></i> Browse using<span class="caret"></span></a>
# <ul aria-labelledby="navbarDropdownBrowse" class="dropdown-menu">
# <li class="dropdown-item"><a class="nav-link" href="/describe/?uri=http%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell">OpenLink Faceted Browser</a></li>
# <li class="dropdown-item"><a class="nav-link" href="http://osde.demo.openlinksw.com/#/editor?uri=http%3A%2F%2Fdbpedia.org%2Fdata%2FDigby_Morrell.ttl&amp;view=statements">OpenLink Structured Data Editor</a></li>
# <li class="dropdown-item"><a class="nav-link" href="http://en.lodlive.it/?http%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell">LodLive Browser</a></li>
# <!-- li class="dropdown-item"><a class="nav-link" href="http://lodmilla.sztaki.hu/lodmilla/?url=http%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell">LODmilla Browser</a></li -->
# </ul>
# </li>
# <li class="nav-item dropdown">
# <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" id="navbarDropdownFormats" role="button">
# <i class="bi-file-earmark-fill"></i> Formats<span class="caret"></span></a>
# <ul aria-labelledby="navbarDropdownFormats" class="dropdown-menu">
# <li class="dropdown-item-text">RDF:</li>
# <li><a class="dropdown-item" href="http://dbpedia.org/data/Digby_Morrell.ntriples">N-Triples</a></li>
# <li><a class="dropdown-item" href="http://dbpedia.org/data/Digby_Morrell.n3">N3</a></li>
# <li><a class="dropdown-item" href="http://dbpedia.org/data/Digby_Morrell.ttl">Turtle</a></li>
# <li><a class="dropdown-item" href="http://dbpedia.org/data/Digby_Morrell.json">JSON</a></li>
# <li><a class="dropdown-item" href="http://dbpedia.org/data/Digby_Morrell.rdf">XML</a></li>
# <li class="dropdown-divider"></li>
# <li class="dropdown-item-text">OData:</li>
# <li><a class="dropdown-item" href="http://dbpedia.org/data/Digby_Morrell.atom">Atom</a></li>
# <li><a class="dropdown-item" href="http://dbpedia.org/data/Digby_Morrell.jsod">JSON</a></li>
# <li class="dropdown-divider"></li>
# <li class="dropdown-item-text">Microdata:</li>
# <li><a class="dropdown-item" href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=application%2Fmicrodata%2Bjson">JSON</a></li>
# <li><a class="dropdown-item" href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fhtml">HTML</a></li>
# <li class="dropdown-divider"></li>
# <li class="dropdown-item-text">Embedded:</li>
# <li><a class="dropdown-item" href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fx-html-script-ld%2Bjson">JSON</a></li>
# <li><a class="dropdown-item" href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fx-html-script-turtle">Turtle</a></li>
# <li class="dropdown-divider"></li>
# <li class="dropdown-item-text">Other:</li>
# <li><a class="dropdown-item" href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fcsv">CSV</a></li>
# <li><a class="dropdown-item" href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=application%2Fld%2Bjson">JSON-LD</a></li>
# </ul>
# </li>
# </ul>
# <ul class="navbar-nav ms-auto">
# <li class="nav-item">
# <a class="nav-link" href="/fct/" title="Switch to /fct endpoint"><i class="bi-box-arrow-up-right"></i> Faceted Browser </a>
# </li>
# <li class="nav-item">
# <a class="nav-link" href="/sparql/" title="Switch to /sparql endpoint"><i class="bi-box-arrow-up-right"></i> Sparql Endpoint </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div style="margin-bottom: 60px"></div>
# <!-- /navbar -->
# <!-- page-header -->
# <section>
# <div class="container-xl">
# <div class="row">
# <div class="col">
# <h1 class="display-6" id="title"><b>About:</b>
# <a href="http://dbpedia.org/resource/Digby_Morrell">Digby Morrell</a>
# </h1>
# </div>
# </div>
# <div class="row">
# <div class="col">
# <div class="text-muted">
# <span class="text-nowrap">An Entity of Type: <a href="http://dbpedia.org/ontology/Animal">animal</a>, </span>
# <span class="text-nowrap">from Named Graph:  <a href="http://dbpedia.org">http://dbpedia.org</a>, </span>
# <span class="text-nowrap">within Data Space: <a href="http://dbpedia.org">dbpedia.org</a></span>
# </div>
# </div>
# </div>
# <div class="row pt-2">
# <div class="col-xs-9 col-sm-10">
# <p class="lead">Digby Morrell (born 10 October 1979) is a former Australian rules footballer who played with the Kangaroos and Carlton in the Australian Football League (AFL). From Western Australia, Morrell played his early senior football for West Perth. His 44-game senior career for the Falcons spanned 1998–2000, and he was the club's leading goalkicker in 2000. At the age of 21, Morrell was recruited to the Australian Football League by the Kangaroos Football Club with its third round selection in the 2001 AFL Rookie Draft. As a forward he twice kicked five goals during his time with the Kangaroos. The first was in a losing cause against Sydney in 2002 and the other the following season in a drawn game against Brisbane.</p>
# </div>
# </div>
# </div>
# </section>
# <!-- page-header -->
# <!-- property-table -->
# <section>
# <div class="container-xl">
# <div class="row">
# <div class="table-responsive">
# <table class="table table-hover table-sm table-light">
# <thead>
# <tr>
# <th class="col-xs-3">Property</th>
# <th class="col-xs-9 px-3">Value</th>
# </tr>
# </thead>
# <tbody>
# <tr class="odd"><td class="col-2"><a class="uri" href="http://dbpedia.org/ontology/Person/height"><small>dbo:</small>Person/height</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="dbd:centimetre" prefix="ns0: http://dbpedia.org/ontology/Person/" property="ns0:height">191.0</span></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://dbpedia.org/ontology/Person/weight"><small>dbo:</small>Person/weight</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="dbd:kilogram" prefix="ns1: http://dbpedia.org/ontology/Person/" property="ns1:weight">97.0</span></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://dbpedia.org/ontology/abstract"><small>dbo:</small>abstract</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span lang="en" property="dbo:abstract">Digby Morrell (born 10 October 1979) is a former Australian rules footballer who played with the Kangaroos and Carlton in the Australian Football League (AFL). From Western Australia, Morrell played his early senior football for West Perth. His 44-game senior career for the Falcons spanned 1998–2000, and he was the club's leading goalkicker in 2000. At the age of 21, Morrell was recruited to the Australian Football League by the Kangaroos Football Club with its third round selection in the 2001 AFL Rookie Draft. As a forward he twice kicked five goals during his time with the Kangaroos. The first was in a losing cause against Sydney in 2002 and the other the following season in a drawn game against Brisbane. After the 2003 season, Morrell was traded, along with David Teague, to the Carlton Football Club in exchange for Corey McKernan. He played 32 games for the Blues before being delisted at the end of 2005. He continued to play Victorian Football League (VFL) football with the Northern Bullants, Carlton's VFL-affiliate in 2006, and acted as playing assistant coach in 2007. In 2008, he shifted to the Box Hill Hawks, before retiring from playing at the end of the season. From 2009 until 2013, Morrell was the senior coach of the Strathmore Football Club in the Essendon District Football League, leading the club to the 2011 Premier Division premiership.from 2014 - 2018 he was the senior coach of the West Coburg Football Club, also in the EDFL.In September 2018 he was appointed new coach of the Pascoe Vale Football Club. He currently teaches physical education at the Parade College Bundoora campus in Melbourne.</span><small> (en)</small></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://dbpedia.org/ontology/birthDate"><small>dbo:</small>birthDate</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="xsd:date" property="dbo:birthDate">1979-10-10</span><small> (xsd:date)</small></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://dbpedia.org/ontology/careerStation"><small>dbo:</small>careerStation</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Digby_Morrell__CareerStation__1" rel="dbo:careerStation" resource="http://dbpedia.org/resource/Digby_Morrell__CareerStation__1"><small>dbr</small>:Digby_Morrell__CareerStation__1</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Digby_Morrell__CareerStation__2" rel="dbo:careerStation" resource="http://dbpedia.org/resource/Digby_Morrell__CareerStation__2"><small>dbr</small>:Digby_Morrell__CareerStation__2</a></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://dbpedia.org/ontology/debutTeam"><small>dbo:</small>debutTeam</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/North_Melbourne_Football_Club" rel="dbo:debutTeam" resource="http://dbpedia.org/resource/North_Melbourne_Football_Club"><small>dbr</small>:North_Melbourne_Football_Club</a></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://dbpedia.org/ontology/height"><small>dbo:</small>height</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="xsd:double" property="dbo:height">1.910000</span><small> (xsd:double)</small></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://dbpedia.org/ontology/weight"><small>dbo:</small>weight</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="xsd:double" property="dbo:weight">97000.000000</span><small> (xsd:double)</small></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://dbpedia.org/ontology/wikiPageID"><small>dbo:</small>wikiPageID</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="xsd:integer" property="dbo:wikiPageID">12660423</span><small> (xsd:integer)</small></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://dbpedia.org/ontology/wikiPageLength"><small>dbo:</small>wikiPageLength</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="xsd:nonNegativeInteger" property="dbo:wikiPageLength">4013</span><small> (xsd:nonNegativeInteger)</small></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://dbpedia.org/ontology/wikiPageRevisionID"><small>dbo:</small>wikiPageRevisionID</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="xsd:integer" property="dbo:wikiPageRevisionID">1108573112</span><small> (xsd:integer)</small></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://dbpedia.org/ontology/wikiPageWikiLink"><small>dbo:</small>wikiPageWikiLink</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Carlton_Football_Club" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Carlton_Football_Club"><small>dbr</small>:Carlton_Football_Club</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Category:1979_births" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Category:1979_births"><small>dbc</small>:1979_births</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/David_Teague_(footballer)" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/David_Teague_(footballer)"><small>dbr</small>:David_Teague_(footballer)</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Victorian_Football_League" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Victorian_Football_League"><small>dbr</small>:Victorian_Football_League</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Category:Living_people" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Category:Living_people"><small>dbc</small>:Living_people</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Corey_McKernan" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Corey_McKernan"><small>dbr</small>:Corey_McKernan</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Strathmore_Football_Club" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Strathmore_Football_Club"><small>dbr</small>:Strathmore_Football_Club</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Australian_Football_League" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Australian_Football_League"><small>dbr</small>:Australian_Football_League</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/2000_AFL_Draft" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/2000_AFL_Draft"><small>dbr</small>:2000_AFL_Draft</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/West_Australian_Football_League" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/West_Australian_Football_League"><small>dbr</small>:West_Australian_Football_League</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/West_Coburg_Football_Club" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/West_Coburg_Football_Club"><small>dbr</small>:West_Coburg_Football_Club</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/West_Perth_Football_Club" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/West_Perth_Football_Club"><small>dbr</small>:West_Perth_Football_Club</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Essendon_District_Football_League" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Essendon_District_Football_League"><small>dbr</small>:Essendon_District_Football_League</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/North_Melbourne_Football_Club" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/North_Melbourne_Football_Club"><small>dbr</small>:North_Melbourne_Football_Club</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Parade_College" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Parade_College"><small>dbr</small>:Parade_College</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Pascoe_Vale_Football_Club" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Pascoe_Vale_Football_Club"><small>dbr</small>:Pascoe_Vale_Football_Club</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Category:Australian_rules_footballers_from_Western_Australia" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Category:Australian_rules_footballers_from_Western_Australia"><small>dbc</small>:Australian_rules_footballers_from_Western_Australia</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Category:Box_Hill_Football_Club_players" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Category:Box_Hill_Football_Club_players"><small>dbc</small>:Box_Hill_Football_Club_players</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Category:Carlton_Football_Club_players" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Category:Carlton_Football_Club_players"><small>dbc</small>:Carlton_Football_Club_players</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Category:North_Melbourne_Football_Club_players" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Category:North_Melbourne_Football_Club_players"><small>dbc</small>:North_Melbourne_Football_Club_players</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Category:Preston_Football_Club_(VFA)_players" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Category:Preston_Football_Club_(VFA)_players"><small>dbc</small>:Preston_Football_Club_(VFA)_players</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Australian_rules_football" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Australian_rules_football"><small>dbr</small>:Australian_rules_football</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Northern_Bullants" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Northern_Bullants"><small>dbr</small>:Northern_Bullants</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Box_Hill_Hawks" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Box_Hill_Hawks"><small>dbr</small>:Box_Hill_Hawks</a></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/birthDate"><small>dbp:</small>birthDate</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="xsd:date" property="dbp:birthDate">1979-10-10</span><small> (xsd:date)</small></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/club"><small>dbp:</small>club</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Carlton_Football_Club" rel="dbp:club" resource="http://dbpedia.org/resource/Carlton_Football_Club"><small>dbr</small>:Carlton_Football_Club</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/North_Melbourne_Football_Club" rel="dbp:club" resource="http://dbpedia.org/resource/North_Melbourne_Football_Club"><small>dbr</small>:North_Melbourne_Football_Club</a></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/debutdate"><small>dbp:</small>debutdate</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="xsd:integer" property="dbp:debutdate">2001</span><small> (xsd:integer)</small></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/debutopponent"><small>dbp:</small>debutopponent</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span lang="en" property="dbp:debutopponent">Richmond</span><small> (en)</small></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/debutstadium"><small>dbp:</small>debutstadium</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span lang="en" property="dbp:debutstadium">Docklands</span><small> (en)</small></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/debutteam"><small>dbp:</small>debutteam</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/North_Melbourne_Football_Club" rel="dbp:debutteam" resource="http://dbpedia.org/resource/North_Melbourne_Football_Club"><small>dbr</small>:North_Melbourne_Football_Club</a></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/gamesGoals"><small>dbp:</small>gamesGoals</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="xsd:integer" property="dbp:gamesGoals">32</span><small> (xsd:integer)</small></span></li>
# <li><span class="literal"><span datatype="xsd:integer" property="dbp:gamesGoals">40</span><small> (xsd:integer)</small></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/gamesGoalstotal"><small>dbp:</small>gamesGoalstotal</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="xsd:integer" property="dbp:gamesGoalstotal">72</span><small> (xsd:integer)</small></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/height"><small>dbp:</small>height</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="dbd:centimetre" property="dbp:height">191.0</span></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/name"><small>dbp:</small>name</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span lang="en" property="dbp:name">Digby Morrell</span><small> (en)</small></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/originalteam"><small>dbp:</small>originalteam</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span lang="en" property="dbp:originalteam">West Perth  Pingrup</span><small> (en)</small></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/statsend"><small>dbp:</small>statsend</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="xsd:integer" property="dbp:statsend">2005</span><small> (xsd:integer)</small></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/weight"><small>dbp:</small>weight</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="dbd:kilogram" property="dbp:weight">97.0</span></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/wikiPageUsesTemplate"><small>dbp:</small>wikiPageUsesTemplate</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Template:AFL_Tables" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:AFL_Tables"><small>dbt</small>:AFL_Tables</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Template:Commons_category" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:Commons_category"><small>dbt</small>:Commons_category</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Template:Reflist" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:Reflist"><small>dbt</small>:Reflist</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Template:Short_description" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:Short_description"><small>dbt</small>:Short_description</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Template:Use_Australian_English" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:Use_Australian_English"><small>dbt</small>:Use_Australian_English</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Template:Use_dmy_dates" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:Use_dmy_dates"><small>dbt</small>:Use_dmy_dates</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Template:Birth_date_and_age" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:Birth_date_and_age"><small>dbt</small>:Birth_date_and_age</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Template:2001_AFL_rookie_draft" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:2001_AFL_rookie_draft"><small>dbt</small>:2001_AFL_rookie_draft</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Template:Infobox_AFL_biography" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:Infobox_AFL_biography"><small>dbt</small>:Infobox_AFL_biography</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Template:VFL-affiliate" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:VFL-affiliate"><small>dbt</small>:VFL-affiliate</a></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/wordnet_type"><small>dbp:</small>wordnet_type</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://www.w3.org/2006/03/wn/wn20/instances/synset-football_player-noun-1" rel="dbp:wordnet_type nofollow" resource="http://www.w3.org/2006/03/wn/wn20/instances/synset-football_player-noun-1">http://www.w3.org/2006/03/wn/wn20/instances/synset-football_player-noun-1</a></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://dbpedia.org/property/years"><small>dbp:</small>years</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span datatype="xsd:integer" property="dbp:years">2001</span><small> (xsd:integer)</small></span></li>
# <li><span class="literal"><span datatype="xsd:integer" property="dbp:years">2004</span><small> (xsd:integer)</small></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://purl.org/dc/terms/subject"><small>dcterms:</small>subject</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Category:1979_births" prefix="dcterms: http://purl.org/dc/terms/" rel="dcterms:subject" resource="http://dbpedia.org/resource/Category:1979_births"><small>dbc</small>:1979_births</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Category:Living_people" prefix="dcterms: http://purl.org/dc/terms/" rel="dcterms:subject" resource="http://dbpedia.org/resource/Category:Living_people"><small>dbc</small>:Living_people</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Category:Australian_rules_footballers_from_Western_Australia" prefix="dcterms: http://purl.org/dc/terms/" rel="dcterms:subject" resource="http://dbpedia.org/resource/Category:Australian_rules_footballers_from_Western_Australia"><small>dbc</small>:Australian_rules_footballers_from_Western_Australia</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Category:Box_Hill_Football_Club_players" prefix="dcterms: http://purl.org/dc/terms/" rel="dcterms:subject" resource="http://dbpedia.org/resource/Category:Box_Hill_Football_Club_players"><small>dbc</small>:Box_Hill_Football_Club_players</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Category:Carlton_Football_Club_players" prefix="dcterms: http://purl.org/dc/terms/" rel="dcterms:subject" resource="http://dbpedia.org/resource/Category:Carlton_Football_Club_players"><small>dbc</small>:Carlton_Football_Club_players</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Category:North_Melbourne_Football_Club_players" prefix="dcterms: http://purl.org/dc/terms/" rel="dcterms:subject" resource="http://dbpedia.org/resource/Category:North_Melbourne_Football_Club_players"><small>dbc</small>:North_Melbourne_Football_Club_players</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Category:Preston_Football_Club_(VFA)_players" prefix="dcterms: http://purl.org/dc/terms/" rel="dcterms:subject" resource="http://dbpedia.org/resource/Category:Preston_Football_Club_(VFA)_players"><small>dbc</small>:Preston_Football_Club_(VFA)_players</a></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://purl.org/linguistics/gold/hypernym"><small>gold:</small>hypernym</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Footballer" prefix="gold: http://purl.org/linguistics/gold/" rel="gold:hypernym" resource="http://dbpedia.org/resource/Footballer"><small>dbr</small>:Footballer</a></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://www.w3.org/1999/02/22-rdf-syntax-ns#type"><small>rdf:</small>type</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://www.w3.org/2002/07/owl#Thing" rel="rdf:type" resource="http://www.w3.org/2002/07/owl#Thing"><small>owl</small>:Thing</a></span></li>
# <li><span class="literal"><a class="uri" href="http://xmlns.com/foaf/0.1/Person" rel="rdf:type" resource="http://xmlns.com/foaf/0.1/Person"><small>foaf</small>:Person</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/ontology/Person" rel="rdf:type" resource="http://dbpedia.org/ontology/Person"><small>dbo</small>:Person</a></span></li>
# <li><span class="literal"><a class="uri" href="http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#NaturalPerson" rel="rdf:type" resource="http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#NaturalPerson"><small>dul</small>:NaturalPerson</a></span></li>
# <li><span class="literal"><a class="uri" href="http://www.wikidata.org/entity/Q19088" rel="rdf:type" resource="http://www.wikidata.org/entity/Q19088"><small>wikidata</small>:Q19088</a></span></li>
# <li><span class="literal"><a class="uri" href="http://www.wikidata.org/entity/Q215627" rel="rdf:type" resource="http://www.wikidata.org/entity/Q215627"><small>wikidata</small>:Q215627</a></span></li>
# <li><span class="literal"><a class="uri" href="http://www.wikidata.org/entity/Q5" rel="rdf:type" resource="http://www.wikidata.org/entity/Q5"><small>wikidata</small>:Q5</a></span></li>
# <li><span class="literal"><a class="uri" href="http://www.wikidata.org/entity/Q729" rel="rdf:type" resource="http://www.wikidata.org/entity/Q729"><small>wikidata</small>:Q729</a></span></li>
# <li><span class="literal"><a class="uri" href="http://www.wikidata.org/entity/Q13414980" rel="rdf:type" resource="http://www.wikidata.org/entity/Q13414980"><small>wikidata</small>:Q13414980</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/WikicatAustralianRulesFootballersFromWesternAustralia" rel="rdf:type" resource="http://dbpedia.org/class/yago/WikicatAustralianRulesFootballersFromWesternAustralia"><small>yago</small>:WikicatAustralianRulesFootballersFromWesternAustralia</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/WikicatBoxHillFootballClubPlayers" rel="rdf:type" resource="http://dbpedia.org/class/yago/WikicatBoxHillFootballClubPlayers"><small>yago</small>:WikicatBoxHillFootballClubPlayers</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/ontology/Animal" rel="rdf:type" resource="http://dbpedia.org/ontology/Animal"><small>dbo</small>:Animal</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/ontology/Athlete" rel="rdf:type" resource="http://dbpedia.org/ontology/Athlete"><small>dbo</small>:Athlete</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/ontology/AustralianRulesFootballPlayer" rel="rdf:type" resource="http://dbpedia.org/ontology/AustralianRulesFootballPlayer"><small>dbo</small>:AustralianRulesFootballPlayer</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/ontology/Eukaryote" rel="rdf:type" resource="http://dbpedia.org/ontology/Eukaryote"><small>dbo</small>:Eukaryote</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/ontology/SoccerPlayer" rel="rdf:type" resource="http://dbpedia.org/ontology/SoccerPlayer"><small>dbo</small>:SoccerPlayer</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/ontology/Species" rel="rdf:type" resource="http://dbpedia.org/ontology/Species"><small>dbo</small>:Species</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/WikicatCarltonFootballClubPlayers" rel="rdf:type" resource="http://dbpedia.org/class/yago/WikicatCarltonFootballClubPlayers"><small>yago</small>:WikicatCarltonFootballClubPlayers</a></span></li>
# <li><span class="literal"><a class="uri" href="http://schema.org/Person" rel="rdf:type" resource="http://schema.org/Person"><small>schema</small>:Person</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/WikicatLivingPeople" rel="rdf:type" resource="http://dbpedia.org/class/yago/WikicatLivingPeople"><small>yago</small>:WikicatLivingPeople</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/WikicatNorthMelbourneFootballClubPlayers" rel="rdf:type" resource="http://dbpedia.org/class/yago/WikicatNorthMelbourneFootballClubPlayers"><small>yago</small>:WikicatNorthMelbourneFootballClubPlayers</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/WikicatNorthernBluesPlayers" rel="rdf:type" resource="http://dbpedia.org/class/yago/WikicatNorthernBluesPlayers"><small>yago</small>:WikicatNorthernBluesPlayers</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/Athlete109820263" rel="rdf:type" resource="http://dbpedia.org/class/yago/Athlete109820263"><small>yago</small>:Athlete109820263</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/CausalAgent100007347" rel="rdf:type" resource="http://dbpedia.org/class/yago/CausalAgent100007347"><small>yago</small>:CausalAgent100007347</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/Contestant109613191" rel="rdf:type" resource="http://dbpedia.org/class/yago/Contestant109613191"><small>yago</small>:Contestant109613191</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/FootballPlayer110101634" rel="rdf:type" resource="http://dbpedia.org/class/yago/FootballPlayer110101634"><small>yago</small>:FootballPlayer110101634</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/LivingThing100004258" rel="rdf:type" resource="http://dbpedia.org/class/yago/LivingThing100004258"><small>yago</small>:LivingThing100004258</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/Object100002684" rel="rdf:type" resource="http://dbpedia.org/class/yago/Object100002684"><small>yago</small>:Object100002684</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/Organism100004475" rel="rdf:type" resource="http://dbpedia.org/class/yago/Organism100004475"><small>yago</small>:Organism100004475</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/Person100007846" rel="rdf:type" resource="http://dbpedia.org/class/yago/Person100007846"><small>yago</small>:Person100007846</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/PhysicalEntity100001930" rel="rdf:type" resource="http://dbpedia.org/class/yago/PhysicalEntity100001930"><small>yago</small>:PhysicalEntity100001930</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/Player110439851" rel="rdf:type" resource="http://dbpedia.org/class/yago/Player110439851"><small>yago</small>:Player110439851</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/YagoLegalActor" rel="rdf:type" resource="http://dbpedia.org/class/yago/YagoLegalActor"><small>yago</small>:YagoLegalActor</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/YagoLegalActorGeo" rel="rdf:type" resource="http://dbpedia.org/class/yago/YagoLegalActorGeo"><small>yago</small>:YagoLegalActorGeo</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/class/yago/Whole100003553" rel="rdf:type" resource="http://dbpedia.org/class/yago/Whole100003553"><small>yago</small>:Whole100003553</a></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://www.w3.org/2000/01/rdf-schema#comment"><small>rdfs:</small>comment</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span lang="en" property="rdfs:comment">Digby Morrell (born 10 October 1979) is a former Australian rules footballer who played with the Kangaroos and Carlton in the Australian Football League (AFL). From Western Australia, Morrell played his early senior football for West Perth. His 44-game senior career for the Falcons spanned 1998–2000, and he was the club's leading goalkicker in 2000. At the age of 21, Morrell was recruited to the Australian Football League by the Kangaroos Football Club with its third round selection in the 2001 AFL Rookie Draft. As a forward he twice kicked five goals during his time with the Kangaroos. The first was in a losing cause against Sydney in 2002 and the other the following season in a drawn game against Brisbane.</span><small> (en)</small></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://www.w3.org/2000/01/rdf-schema#label"><small>rdfs:</small>label</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span lang="en" property="rdfs:label">Digby Morrell</span><small> (en)</small></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://www.w3.org/2002/07/owl#sameAs"><small>owl:</small>sameAs</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://rdf.freebase.com/ns/m.02w_8_k" rel="owl:sameAs" resource="http://rdf.freebase.com/ns/m.02w_8_k"><small>freebase</small>:Digby Morrell</a></span></li>
# <li><span class="literal"><a class="uri" href="http://yago-knowledge.org/resource/Digby_Morrell" rel="owl:sameAs" resource="http://yago-knowledge.org/resource/Digby_Morrell"><small>yago-res</small>:Digby Morrell</a></span></li>
# <li><span class="literal"><a class="uri" href="http://www.wikidata.org/entity/Q5275580" rel="owl:sameAs" resource="http://www.wikidata.org/entity/Q5275580"><small>wikidata</small>:Digby Morrell</a></span></li>
# <li><span class="literal"><a class="uri" href="https://global.dbpedia.org/id/4innu" rel="owl:sameAs" resource="https://global.dbpedia.org/id/4innu">https://global.dbpedia.org/id/4innu</a></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://www.w3.org/ns/prov#wasDerivedFrom"><small>prov:</small>wasDerivedFrom</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://en.wikipedia.org/wiki/Digby_Morrell?oldid=1108573112&amp;ns=0" rel="prov:wasDerivedFrom" resource="http://en.wikipedia.org/wiki/Digby_Morrell?oldid=1108573112&amp;ns=0"><small>wikipedia-en</small>:Digby_Morrell?oldid=1108573112&amp;ns=0</a></span></li>
# </ul></td></tr><tr class="even"><td class="col-2"><a class="uri" href="http://xmlns.com/foaf/0.1/isPrimaryTopicOf"><small>foaf:</small>isPrimaryTopicOf</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://en.wikipedia.org/wiki/Digby_Morrell" rel="foaf:isPrimaryTopicOf" resource="http://en.wikipedia.org/wiki/Digby_Morrell"><small>wikipedia-en</small>:Digby_Morrell</a></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2"><a class="uri" href="http://xmlns.com/foaf/0.1/name"><small>foaf:</small>name</a>
# </td><td class="col-10 text-break"><ul>
# <li><span class="literal"><span lang="en" property="foaf:name">Digby Morrell</span><small> (en)</small></span></li>
# </ul></td></tr><tr class="even"><td class="col-2">is <a class="uri" href="http://dbpedia.org/ontology/wikiPageDisambiguates"><small>dbo:</small>wikiPageDisambiguates</a>
#  of</td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Morrell" resource="http://dbpedia.org/resource/Morrell" rev="dbo:wikiPageDisambiguates"><small>dbr</small>:Morrell</a></span></li>
# </ul></td></tr><tr class="odd"><td class="col-2">is <a class="uri" href="http://dbpedia.org/ontology/wikiPageWikiLink"><small>dbo:</small>wikiPageWikiLink</a>
#  of</td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Morrell" resource="http://dbpedia.org/resource/Morrell" rev="dbo:wikiPageWikiLink"><small>dbr</small>:Morrell</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/1998_Westar_Rules_Grand_Final" resource="http://dbpedia.org/resource/1998_Westar_Rules_Grand_Final" rev="dbo:wikiPageWikiLink"><small>dbr</small>:1998_Westar_Rules_Grand_Final</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/2001_WAFL_season" resource="http://dbpedia.org/resource/2001_WAFL_season" rev="dbo:wikiPageWikiLink"><small>dbr</small>:2001_WAFL_season</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/2002_AFL_draft" resource="http://dbpedia.org/resource/2002_AFL_draft" rev="dbo:wikiPageWikiLink"><small>dbr</small>:2002_AFL_draft</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/2003_AFL_draft" resource="http://dbpedia.org/resource/2003_AFL_draft" rev="dbo:wikiPageWikiLink"><small>dbr</small>:2003_AFL_draft</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/List_of_AFL_debuts_in_2004" resource="http://dbpedia.org/resource/List_of_AFL_debuts_in_2004" rev="dbo:wikiPageWikiLink"><small>dbr</small>:List_of_AFL_debuts_in_2004</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/List_of_Carlton_Football_Club_players" resource="http://dbpedia.org/resource/List_of_Carlton_Football_Club_players" rev="dbo:wikiPageWikiLink"><small>dbr</small>:List_of_Carlton_Football_Club_players</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/2005_VFL_season" resource="http://dbpedia.org/resource/2005_VFL_season" rev="dbo:wikiPageWikiLink"><small>dbr</small>:2005_VFL_season</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/2006_VFL_season" resource="http://dbpedia.org/resource/2006_VFL_season" rev="dbo:wikiPageWikiLink"><small>dbr</small>:2006_VFL_season</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/Digby_(name)" resource="http://dbpedia.org/resource/Digby_(name)" rev="dbo:wikiPageWikiLink"><small>dbr</small>:Digby_(name)</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/List_of_North_Melbourne_Football_Club_players" resource="http://dbpedia.org/resource/List_of_North_Melbourne_Football_Club_players" rev="dbo:wikiPageWikiLink"><small>dbr</small>:List_of_North_Melbourne_Football_Club_players</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/List_of_Old_Haleians" resource="http://dbpedia.org/resource/List_of_Old_Haleians" rev="dbo:wikiPageWikiLink"><small>dbr</small>:List_of_Old_Haleians</a></span></li>
# <li><span class="literal"><a class="uri" href="http://dbpedia.org/resource/2000_AFL_draft" resource="http://dbpedia.org/resource/2000_AFL_draft" rev="dbo:wikiPageWikiLink"><small>dbr</small>:2000_AFL_draft</a></span></li>
# </ul></td></tr><tr class="even"><td class="col-2">is <a class="uri" href="http://xmlns.com/foaf/0.1/primaryTopic"><small>foaf:</small>primaryTopic</a>
#  of</td><td class="col-10 text-break"><ul>
# <li><span class="literal"><a class="uri" href="http://en.wikipedia.org/wiki/Digby_Morrell" resource="http://en.wikipedia.org/wiki/Digby_Morrell" rev="foaf:primaryTopic"><small>wikipedia-en</small>:Digby_Morrell</a></span></li>
# </ul></td></tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </section>
# <!-- property-table -->
# <!-- footer -->
# <section>
# <div class="container-xl">
# <div class="text-center p-4 bg-light">
# <a href="https://virtuoso.openlinksw.com/" title="OpenLink Virtuoso"><img alt="Powered by OpenLink Virtuoso" class="powered_by" src="/statics/images/virt_power_no_border.png"/></a>
# 	    <a href="http://linkeddata.org/"><img alt="This material is Open Knowledge" src="/statics/images/LoDLogo.gif"/></a>
# 	    <a href="http://dbpedia.org/sparql"><img alt="W3C Semantic Web Technology" src="/statics/images/sw-sparql-blue.png"/></a>
# 	    <a href="https://opendefinition.org/"><img alt="This material is Open Knowledge" src="/statics/images/od_80x15_red_green.png"/></a>
# 	    <span about="" rel="dc:conformsTo" resource="http://www.w3.org/TR/rdfa-syntax" style="display:none;">
# <a href="https://validator.w3.org/check?uri=referer">
# <img alt="Valid XHTML + RDFa" src="https://www.w3.org/Icons/valid-xhtml-rdfa"/>
# </a>
# </span>
# <br/>
# <small class="text-muted">
# 		This content was extracted from <a href="http://en.wikipedia.org/wiki/Digby_Morrell">Wikipedia</a> and is licensed under the <a href="http://creativecommons.org/licenses/by-sa/3.0/">Creative Commons Attribution-ShareAlike 3.0 Unported License</a>
# </small>
# </div>
# </div>
# </section>
# <!-- #footer -->
# <!-- scripts -->
# <script crossorigin="anonymous" integrity="sha512-1TK4hjCY5+E9H3r5+05bEGbKGyK506WaDPfPe1s/ihwRjr6OtL43zJLzOFQ+/zciONEd+sp7LwrfOCnyukPSsg==" src="https://cdnjs.cloudflare.com/ajax/libs/bootstrap/5.2.1/js/bootstrap.bundle.min.js">
# </script>
# </body>
# </html>

# %%
type(html)
# Out:
# str

# %%
type(dom)
# Out:
# bs4.BeautifulSoup

# %%
a_tags = dom.select("a")
a_tags
# Out:
# [<a class="navbar-brand" href="http://wiki.dbpedia.org/about" style="color: #2c5078" title="About DBpedia">
#  <img alt="About DBpedia" class="img-fluid" src="/statics/images/dbpedia_logo_land_120.png"/>
#  </a>,
#  <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" id="navbarDropdownBrowse" role="button">
#  <i class="bi-eye-fill"></i> Browse using<span class="caret"></span></a>,
#  <a class="nav-link" href="/describe/?uri=http%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell">OpenLink Faceted Browser</a>,
#  <a class="nav-link" href="http://osde.demo.openlinksw.com/#/editor?uri=http%3A%2F%2Fdbpedia.org%2Fdata%2FDigby_Morrell.ttl&amp;view=statements">OpenLink Structured Data Editor</a>,
#  <a class="nav-link" href="http://en.lodlive.it/?http%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell">LodLive Browser</a>,
#  <a aria-expanded="false" class="nav-link dropdown-toggle" data-bs-toggle="dropdown" href="#" id="navbarDropdownFormats" role="button">
#  <i class="bi-file-earmark-fill"></i> Formats<span class="caret"></span></a>,
#  <a class="dropdown-item" href="http://dbpedia.org/data/Digby_Morrell.ntriples">N-Triples</a>,
#  <a class="dropdown-item" href="http://dbpedia.org/data/Digby_Morrell.n3">N3</a>,
#  <a class="dropdown-item" href="http://dbpedia.org/data/Digby_Morrell.ttl">Turtle</a>,
#  <a class="dropdown-item" href="http://dbpedia.org/data/Digby_Morrell.json">JSON</a>,
#  <a class="dropdown-item" href="http://dbpedia.org/data/Digby_Morrell.rdf">XML</a>,
#  <a class="dropdown-item" href="http://dbpedia.org/data/Digby_Morrell.atom">Atom</a>,
#  <a class="dropdown-item" href="http://dbpedia.org/data/Digby_Morrell.jsod">JSON</a>,
#  <a class="dropdown-item" href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=application%2Fmicrodata%2Bjson">JSON</a>,
#  <a class="dropdown-item" href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fhtml">HTML</a>,
#  <a class="dropdown-item" href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fx-html-script-ld%2Bjson">JSON</a>,
#  <a class="dropdown-item" href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fx-html-script-turtle">Turtle</a>,
#  <a class="dropdown-item" href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=text%2Fcsv">CSV</a>,
#  <a class="dropdown-item" href="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&amp;format=application%2Fld%2Bjson">JSON-LD</a>,
#  <a class="nav-link" href="/fct/" title="Switch to /fct endpoint"><i class="bi-box-arrow-up-right"></i> Faceted Browser </a>,
#  <a class="nav-link" href="/sparql/" title="Switch to /sparql endpoint"><i class="bi-box-arrow-up-right"></i> Sparql Endpoint </a>,
#  <a href="http://dbpedia.org/resource/Digby_Morrell">Digby Morrell</a>,
#  <a href="http://dbpedia.org/ontology/Animal">animal</a>,
#  <a href="http://dbpedia.org">http://dbpedia.org</a>,
#  <a href="http://dbpedia.org">dbpedia.org</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/Person/height"><small>dbo:</small>Person/height</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/Person/weight"><small>dbo:</small>Person/weight</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/abstract"><small>dbo:</small>abstract</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/birthDate"><small>dbo:</small>birthDate</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/careerStation"><small>dbo:</small>careerStation</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Digby_Morrell__CareerStation__1" rel="dbo:careerStation" resource="http://dbpedia.org/resource/Digby_Morrell__CareerStation__1"><small>dbr</small>:Digby_Morrell__CareerStation__1</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Digby_Morrell__CareerStation__2" rel="dbo:careerStation" resource="http://dbpedia.org/resource/Digby_Morrell__CareerStation__2"><small>dbr</small>:Digby_Morrell__CareerStation__2</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/debutTeam"><small>dbo:</small>debutTeam</a>,
#  <a class="uri" href="http://dbpedia.org/resource/North_Melbourne_Football_Club" rel="dbo:debutTeam" resource="http://dbpedia.org/resource/North_Melbourne_Football_Club"><small>dbr</small>:North_Melbourne_Football_Club</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/height"><small>dbo:</small>height</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/weight"><small>dbo:</small>weight</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/wikiPageID"><small>dbo:</small>wikiPageID</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/wikiPageLength"><small>dbo:</small>wikiPageLength</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/wikiPageRevisionID"><small>dbo:</small>wikiPageRevisionID</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/wikiPageWikiLink"><small>dbo:</small>wikiPageWikiLink</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Carlton_Football_Club" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Carlton_Football_Club"><small>dbr</small>:Carlton_Football_Club</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Category:1979_births" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Category:1979_births"><small>dbc</small>:1979_births</a>,
#  <a class="uri" href="http://dbpedia.org/resource/David_Teague_(footballer)" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/David_Teague_(footballer)"><small>dbr</small>:David_Teague_(footballer)</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Victorian_Football_League" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Victorian_Football_League"><small>dbr</small>:Victorian_Football_League</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Category:Living_people" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Category:Living_people"><small>dbc</small>:Living_people</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Corey_McKernan" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Corey_McKernan"><small>dbr</small>:Corey_McKernan</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Strathmore_Football_Club" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Strathmore_Football_Club"><small>dbr</small>:Strathmore_Football_Club</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Australian_Football_League" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Australian_Football_League"><small>dbr</small>:Australian_Football_League</a>,
#  <a class="uri" href="http://dbpedia.org/resource/2000_AFL_Draft" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/2000_AFL_Draft"><small>dbr</small>:2000_AFL_Draft</a>,
#  <a class="uri" href="http://dbpedia.org/resource/West_Australian_Football_League" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/West_Australian_Football_League"><small>dbr</small>:West_Australian_Football_League</a>,
#  <a class="uri" href="http://dbpedia.org/resource/West_Coburg_Football_Club" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/West_Coburg_Football_Club"><small>dbr</small>:West_Coburg_Football_Club</a>,
#  <a class="uri" href="http://dbpedia.org/resource/West_Perth_Football_Club" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/West_Perth_Football_Club"><small>dbr</small>:West_Perth_Football_Club</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Essendon_District_Football_League" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Essendon_District_Football_League"><small>dbr</small>:Essendon_District_Football_League</a>,
#  <a class="uri" href="http://dbpedia.org/resource/North_Melbourne_Football_Club" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/North_Melbourne_Football_Club"><small>dbr</small>:North_Melbourne_Football_Club</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Parade_College" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Parade_College"><small>dbr</small>:Parade_College</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Pascoe_Vale_Football_Club" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Pascoe_Vale_Football_Club"><small>dbr</small>:Pascoe_Vale_Football_Club</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Category:Australian_rules_footballers_from_Western_Australia" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Category:Australian_rules_footballers_from_Western_Australia"><small>dbc</small>:Australian_rules_footballers_from_Western_Australia</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Category:Box_Hill_Football_Club_players" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Category:Box_Hill_Football_Club_players"><small>dbc</small>:Box_Hill_Football_Club_players</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Category:Carlton_Football_Club_players" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Category:Carlton_Football_Club_players"><small>dbc</small>:Carlton_Football_Club_players</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Category:North_Melbourne_Football_Club_players" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Category:North_Melbourne_Football_Club_players"><small>dbc</small>:North_Melbourne_Football_Club_players</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Category:Preston_Football_Club_(VFA)_players" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Category:Preston_Football_Club_(VFA)_players"><small>dbc</small>:Preston_Football_Club_(VFA)_players</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Australian_rules_football" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Australian_rules_football"><small>dbr</small>:Australian_rules_football</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Northern_Bullants" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Northern_Bullants"><small>dbr</small>:Northern_Bullants</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Box_Hill_Hawks" rel="dbo:wikiPageWikiLink" resource="http://dbpedia.org/resource/Box_Hill_Hawks"><small>dbr</small>:Box_Hill_Hawks</a>,
#  <a class="uri" href="http://dbpedia.org/property/birthDate"><small>dbp:</small>birthDate</a>,
#  <a class="uri" href="http://dbpedia.org/property/club"><small>dbp:</small>club</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Carlton_Football_Club" rel="dbp:club" resource="http://dbpedia.org/resource/Carlton_Football_Club"><small>dbr</small>:Carlton_Football_Club</a>,
#  <a class="uri" href="http://dbpedia.org/resource/North_Melbourne_Football_Club" rel="dbp:club" resource="http://dbpedia.org/resource/North_Melbourne_Football_Club"><small>dbr</small>:North_Melbourne_Football_Club</a>,
#  <a class="uri" href="http://dbpedia.org/property/debutdate"><small>dbp:</small>debutdate</a>,
#  <a class="uri" href="http://dbpedia.org/property/debutopponent"><small>dbp:</small>debutopponent</a>,
#  <a class="uri" href="http://dbpedia.org/property/debutstadium"><small>dbp:</small>debutstadium</a>,
#  <a class="uri" href="http://dbpedia.org/property/debutteam"><small>dbp:</small>debutteam</a>,
#  <a class="uri" href="http://dbpedia.org/resource/North_Melbourne_Football_Club" rel="dbp:debutteam" resource="http://dbpedia.org/resource/North_Melbourne_Football_Club"><small>dbr</small>:North_Melbourne_Football_Club</a>,
#  <a class="uri" href="http://dbpedia.org/property/gamesGoals"><small>dbp:</small>gamesGoals</a>,
#  <a class="uri" href="http://dbpedia.org/property/gamesGoalstotal"><small>dbp:</small>gamesGoalstotal</a>,
#  <a class="uri" href="http://dbpedia.org/property/height"><small>dbp:</small>height</a>,
#  <a class="uri" href="http://dbpedia.org/property/name"><small>dbp:</small>name</a>,
#  <a class="uri" href="http://dbpedia.org/property/originalteam"><small>dbp:</small>originalteam</a>,
#  <a class="uri" href="http://dbpedia.org/property/statsend"><small>dbp:</small>statsend</a>,
#  <a class="uri" href="http://dbpedia.org/property/weight"><small>dbp:</small>weight</a>,
#  <a class="uri" href="http://dbpedia.org/property/wikiPageUsesTemplate"><small>dbp:</small>wikiPageUsesTemplate</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Template:AFL_Tables" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:AFL_Tables"><small>dbt</small>:AFL_Tables</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Template:Commons_category" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:Commons_category"><small>dbt</small>:Commons_category</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Template:Reflist" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:Reflist"><small>dbt</small>:Reflist</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Template:Short_description" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:Short_description"><small>dbt</small>:Short_description</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Template:Use_Australian_English" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:Use_Australian_English"><small>dbt</small>:Use_Australian_English</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Template:Use_dmy_dates" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:Use_dmy_dates"><small>dbt</small>:Use_dmy_dates</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Template:Birth_date_and_age" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:Birth_date_and_age"><small>dbt</small>:Birth_date_and_age</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Template:2001_AFL_rookie_draft" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:2001_AFL_rookie_draft"><small>dbt</small>:2001_AFL_rookie_draft</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Template:Infobox_AFL_biography" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:Infobox_AFL_biography"><small>dbt</small>:Infobox_AFL_biography</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Template:VFL-affiliate" rel="dbp:wikiPageUsesTemplate" resource="http://dbpedia.org/resource/Template:VFL-affiliate"><small>dbt</small>:VFL-affiliate</a>,
#  <a class="uri" href="http://dbpedia.org/property/wordnet_type"><small>dbp:</small>wordnet_type</a>,
#  <a class="uri" href="http://www.w3.org/2006/03/wn/wn20/instances/synset-football_player-noun-1" rel="dbp:wordnet_type nofollow" resource="http://www.w3.org/2006/03/wn/wn20/instances/synset-football_player-noun-1">http://www.w3.org/2006/03/wn/wn20/instances/synset-football_player-noun-1</a>,
#  <a class="uri" href="http://dbpedia.org/property/years"><small>dbp:</small>years</a>,
#  <a class="uri" href="http://purl.org/dc/terms/subject"><small>dcterms:</small>subject</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Category:1979_births" prefix="dcterms: http://purl.org/dc/terms/" rel="dcterms:subject" resource="http://dbpedia.org/resource/Category:1979_births"><small>dbc</small>:1979_births</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Category:Living_people" prefix="dcterms: http://purl.org/dc/terms/" rel="dcterms:subject" resource="http://dbpedia.org/resource/Category:Living_people"><small>dbc</small>:Living_people</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Category:Australian_rules_footballers_from_Western_Australia" prefix="dcterms: http://purl.org/dc/terms/" rel="dcterms:subject" resource="http://dbpedia.org/resource/Category:Australian_rules_footballers_from_Western_Australia"><small>dbc</small>:Australian_rules_footballers_from_Western_Australia</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Category:Box_Hill_Football_Club_players" prefix="dcterms: http://purl.org/dc/terms/" rel="dcterms:subject" resource="http://dbpedia.org/resource/Category:Box_Hill_Football_Club_players"><small>dbc</small>:Box_Hill_Football_Club_players</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Category:Carlton_Football_Club_players" prefix="dcterms: http://purl.org/dc/terms/" rel="dcterms:subject" resource="http://dbpedia.org/resource/Category:Carlton_Football_Club_players"><small>dbc</small>:Carlton_Football_Club_players</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Category:North_Melbourne_Football_Club_players" prefix="dcterms: http://purl.org/dc/terms/" rel="dcterms:subject" resource="http://dbpedia.org/resource/Category:North_Melbourne_Football_Club_players"><small>dbc</small>:North_Melbourne_Football_Club_players</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Category:Preston_Football_Club_(VFA)_players" prefix="dcterms: http://purl.org/dc/terms/" rel="dcterms:subject" resource="http://dbpedia.org/resource/Category:Preston_Football_Club_(VFA)_players"><small>dbc</small>:Preston_Football_Club_(VFA)_players</a>,
#  <a class="uri" href="http://purl.org/linguistics/gold/hypernym"><small>gold:</small>hypernym</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Footballer" prefix="gold: http://purl.org/linguistics/gold/" rel="gold:hypernym" resource="http://dbpedia.org/resource/Footballer"><small>dbr</small>:Footballer</a>,
#  <a class="uri" href="http://www.w3.org/1999/02/22-rdf-syntax-ns#type"><small>rdf:</small>type</a>,
#  <a class="uri" href="http://www.w3.org/2002/07/owl#Thing" rel="rdf:type" resource="http://www.w3.org/2002/07/owl#Thing"><small>owl</small>:Thing</a>,
#  <a class="uri" href="http://xmlns.com/foaf/0.1/Person" rel="rdf:type" resource="http://xmlns.com/foaf/0.1/Person"><small>foaf</small>:Person</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/Person" rel="rdf:type" resource="http://dbpedia.org/ontology/Person"><small>dbo</small>:Person</a>,
#  <a class="uri" href="http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#NaturalPerson" rel="rdf:type" resource="http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#NaturalPerson"><small>dul</small>:NaturalPerson</a>,
#  <a class="uri" href="http://www.wikidata.org/entity/Q19088" rel="rdf:type" resource="http://www.wikidata.org/entity/Q19088"><small>wikidata</small>:Q19088</a>,
#  <a class="uri" href="http://www.wikidata.org/entity/Q215627" rel="rdf:type" resource="http://www.wikidata.org/entity/Q215627"><small>wikidata</small>:Q215627</a>,
#  <a class="uri" href="http://www.wikidata.org/entity/Q5" rel="rdf:type" resource="http://www.wikidata.org/entity/Q5"><small>wikidata</small>:Q5</a>,
#  <a class="uri" href="http://www.wikidata.org/entity/Q729" rel="rdf:type" resource="http://www.wikidata.org/entity/Q729"><small>wikidata</small>:Q729</a>,
#  <a class="uri" href="http://www.wikidata.org/entity/Q13414980" rel="rdf:type" resource="http://www.wikidata.org/entity/Q13414980"><small>wikidata</small>:Q13414980</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/WikicatAustralianRulesFootballersFromWesternAustralia" rel="rdf:type" resource="http://dbpedia.org/class/yago/WikicatAustralianRulesFootballersFromWesternAustralia"><small>yago</small>:WikicatAustralianRulesFootballersFromWesternAustralia</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/WikicatBoxHillFootballClubPlayers" rel="rdf:type" resource="http://dbpedia.org/class/yago/WikicatBoxHillFootballClubPlayers"><small>yago</small>:WikicatBoxHillFootballClubPlayers</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/Animal" rel="rdf:type" resource="http://dbpedia.org/ontology/Animal"><small>dbo</small>:Animal</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/Athlete" rel="rdf:type" resource="http://dbpedia.org/ontology/Athlete"><small>dbo</small>:Athlete</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/AustralianRulesFootballPlayer" rel="rdf:type" resource="http://dbpedia.org/ontology/AustralianRulesFootballPlayer"><small>dbo</small>:AustralianRulesFootballPlayer</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/Eukaryote" rel="rdf:type" resource="http://dbpedia.org/ontology/Eukaryote"><small>dbo</small>:Eukaryote</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/SoccerPlayer" rel="rdf:type" resource="http://dbpedia.org/ontology/SoccerPlayer"><small>dbo</small>:SoccerPlayer</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/Species" rel="rdf:type" resource="http://dbpedia.org/ontology/Species"><small>dbo</small>:Species</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/WikicatCarltonFootballClubPlayers" rel="rdf:type" resource="http://dbpedia.org/class/yago/WikicatCarltonFootballClubPlayers"><small>yago</small>:WikicatCarltonFootballClubPlayers</a>,
#  <a class="uri" href="http://schema.org/Person" rel="rdf:type" resource="http://schema.org/Person"><small>schema</small>:Person</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/WikicatLivingPeople" rel="rdf:type" resource="http://dbpedia.org/class/yago/WikicatLivingPeople"><small>yago</small>:WikicatLivingPeople</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/WikicatNorthMelbourneFootballClubPlayers" rel="rdf:type" resource="http://dbpedia.org/class/yago/WikicatNorthMelbourneFootballClubPlayers"><small>yago</small>:WikicatNorthMelbourneFootballClubPlayers</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/WikicatNorthernBluesPlayers" rel="rdf:type" resource="http://dbpedia.org/class/yago/WikicatNorthernBluesPlayers"><small>yago</small>:WikicatNorthernBluesPlayers</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/Athlete109820263" rel="rdf:type" resource="http://dbpedia.org/class/yago/Athlete109820263"><small>yago</small>:Athlete109820263</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/CausalAgent100007347" rel="rdf:type" resource="http://dbpedia.org/class/yago/CausalAgent100007347"><small>yago</small>:CausalAgent100007347</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/Contestant109613191" rel="rdf:type" resource="http://dbpedia.org/class/yago/Contestant109613191"><small>yago</small>:Contestant109613191</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/FootballPlayer110101634" rel="rdf:type" resource="http://dbpedia.org/class/yago/FootballPlayer110101634"><small>yago</small>:FootballPlayer110101634</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/LivingThing100004258" rel="rdf:type" resource="http://dbpedia.org/class/yago/LivingThing100004258"><small>yago</small>:LivingThing100004258</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/Object100002684" rel="rdf:type" resource="http://dbpedia.org/class/yago/Object100002684"><small>yago</small>:Object100002684</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/Organism100004475" rel="rdf:type" resource="http://dbpedia.org/class/yago/Organism100004475"><small>yago</small>:Organism100004475</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/Person100007846" rel="rdf:type" resource="http://dbpedia.org/class/yago/Person100007846"><small>yago</small>:Person100007846</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/PhysicalEntity100001930" rel="rdf:type" resource="http://dbpedia.org/class/yago/PhysicalEntity100001930"><small>yago</small>:PhysicalEntity100001930</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/Player110439851" rel="rdf:type" resource="http://dbpedia.org/class/yago/Player110439851"><small>yago</small>:Player110439851</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/YagoLegalActor" rel="rdf:type" resource="http://dbpedia.org/class/yago/YagoLegalActor"><small>yago</small>:YagoLegalActor</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/YagoLegalActorGeo" rel="rdf:type" resource="http://dbpedia.org/class/yago/YagoLegalActorGeo"><small>yago</small>:YagoLegalActorGeo</a>,
#  <a class="uri" href="http://dbpedia.org/class/yago/Whole100003553" rel="rdf:type" resource="http://dbpedia.org/class/yago/Whole100003553"><small>yago</small>:Whole100003553</a>,
#  <a class="uri" href="http://www.w3.org/2000/01/rdf-schema#comment"><small>rdfs:</small>comment</a>,
#  <a class="uri" href="http://www.w3.org/2000/01/rdf-schema#label"><small>rdfs:</small>label</a>,
#  <a class="uri" href="http://www.w3.org/2002/07/owl#sameAs"><small>owl:</small>sameAs</a>,
#  <a class="uri" href="http://rdf.freebase.com/ns/m.02w_8_k" rel="owl:sameAs" resource="http://rdf.freebase.com/ns/m.02w_8_k"><small>freebase</small>:Digby Morrell</a>,
#  <a class="uri" href="http://yago-knowledge.org/resource/Digby_Morrell" rel="owl:sameAs" resource="http://yago-knowledge.org/resource/Digby_Morrell"><small>yago-res</small>:Digby Morrell</a>,
#  <a class="uri" href="http://www.wikidata.org/entity/Q5275580" rel="owl:sameAs" resource="http://www.wikidata.org/entity/Q5275580"><small>wikidata</small>:Digby Morrell</a>,
#  <a class="uri" href="https://global.dbpedia.org/id/4innu" rel="owl:sameAs" resource="https://global.dbpedia.org/id/4innu">https://global.dbpedia.org/id/4innu</a>,
#  <a class="uri" href="http://www.w3.org/ns/prov#wasDerivedFrom"><small>prov:</small>wasDerivedFrom</a>,
#  <a class="uri" href="http://en.wikipedia.org/wiki/Digby_Morrell?oldid=1108573112&amp;ns=0" rel="prov:wasDerivedFrom" resource="http://en.wikipedia.org/wiki/Digby_Morrell?oldid=1108573112&amp;ns=0"><small>wikipedia-en</small>:Digby_Morrell?oldid=1108573112&amp;ns=0</a>,
#  <a class="uri" href="http://xmlns.com/foaf/0.1/isPrimaryTopicOf"><small>foaf:</small>isPrimaryTopicOf</a>,
#  <a class="uri" href="http://en.wikipedia.org/wiki/Digby_Morrell" rel="foaf:isPrimaryTopicOf" resource="http://en.wikipedia.org/wiki/Digby_Morrell"><small>wikipedia-en</small>:Digby_Morrell</a>,
#  <a class="uri" href="http://xmlns.com/foaf/0.1/name"><small>foaf:</small>name</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/wikiPageDisambiguates"><small>dbo:</small>wikiPageDisambiguates</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Morrell" resource="http://dbpedia.org/resource/Morrell" rev="dbo:wikiPageDisambiguates"><small>dbr</small>:Morrell</a>,
#  <a class="uri" href="http://dbpedia.org/ontology/wikiPageWikiLink"><small>dbo:</small>wikiPageWikiLink</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Morrell" resource="http://dbpedia.org/resource/Morrell" rev="dbo:wikiPageWikiLink"><small>dbr</small>:Morrell</a>,
#  <a class="uri" href="http://dbpedia.org/resource/1998_Westar_Rules_Grand_Final" resource="http://dbpedia.org/resource/1998_Westar_Rules_Grand_Final" rev="dbo:wikiPageWikiLink"><small>dbr</small>:1998_Westar_Rules_Grand_Final</a>,
#  <a class="uri" href="http://dbpedia.org/resource/2001_WAFL_season" resource="http://dbpedia.org/resource/2001_WAFL_season" rev="dbo:wikiPageWikiLink"><small>dbr</small>:2001_WAFL_season</a>,
#  <a class="uri" href="http://dbpedia.org/resource/2002_AFL_draft" resource="http://dbpedia.org/resource/2002_AFL_draft" rev="dbo:wikiPageWikiLink"><small>dbr</small>:2002_AFL_draft</a>,
#  <a class="uri" href="http://dbpedia.org/resource/2003_AFL_draft" resource="http://dbpedia.org/resource/2003_AFL_draft" rev="dbo:wikiPageWikiLink"><small>dbr</small>:2003_AFL_draft</a>,
#  <a class="uri" href="http://dbpedia.org/resource/List_of_AFL_debuts_in_2004" resource="http://dbpedia.org/resource/List_of_AFL_debuts_in_2004" rev="dbo:wikiPageWikiLink"><small>dbr</small>:List_of_AFL_debuts_in_2004</a>,
#  <a class="uri" href="http://dbpedia.org/resource/List_of_Carlton_Football_Club_players" resource="http://dbpedia.org/resource/List_of_Carlton_Football_Club_players" rev="dbo:wikiPageWikiLink"><small>dbr</small>:List_of_Carlton_Football_Club_players</a>,
#  <a class="uri" href="http://dbpedia.org/resource/2005_VFL_season" resource="http://dbpedia.org/resource/2005_VFL_season" rev="dbo:wikiPageWikiLink"><small>dbr</small>:2005_VFL_season</a>,
#  <a class="uri" href="http://dbpedia.org/resource/2006_VFL_season" resource="http://dbpedia.org/resource/2006_VFL_season" rev="dbo:wikiPageWikiLink"><small>dbr</small>:2006_VFL_season</a>,
#  <a class="uri" href="http://dbpedia.org/resource/Digby_(name)" resource="http://dbpedia.org/resource/Digby_(name)" rev="dbo:wikiPageWikiLink"><small>dbr</small>:Digby_(name)</a>,
#  <a class="uri" href="http://dbpedia.org/resource/List_of_North_Melbourne_Football_Club_players" resource="http://dbpedia.org/resource/List_of_North_Melbourne_Football_Club_players" rev="dbo:wikiPageWikiLink"><small>dbr</small>:List_of_North_Melbourne_Football_Club_players</a>,
#  <a class="uri" href="http://dbpedia.org/resource/List_of_Old_Haleians" resource="http://dbpedia.org/resource/List_of_Old_Haleians" rev="dbo:wikiPageWikiLink"><small>dbr</small>:List_of_Old_Haleians</a>,
#  <a class="uri" href="http://dbpedia.org/resource/2000_AFL_draft" resource="http://dbpedia.org/resource/2000_AFL_draft" rev="dbo:wikiPageWikiLink"><small>dbr</small>:2000_AFL_draft</a>,
#  <a class="uri" href="http://xmlns.com/foaf/0.1/primaryTopic"><small>foaf:</small>primaryTopic</a>,
#  <a class="uri" href="http://en.wikipedia.org/wiki/Digby_Morrell" resource="http://en.wikipedia.org/wiki/Digby_Morrell" rev="foaf:primaryTopic"><small>wikipedia-en</small>:Digby_Morrell</a>,
#  <a href="https://virtuoso.openlinksw.com/" title="OpenLink Virtuoso"><img alt="Powered by OpenLink Virtuoso" class="powered_by" src="/statics/images/virt_power_no_border.png"/></a>,
#  <a href="http://linkeddata.org/"><img alt="This material is Open Knowledge" src="/statics/images/LoDLogo.gif"/></a>,
#  <a href="http://dbpedia.org/sparql"><img alt="W3C Semantic Web Technology" src="/statics/images/sw-sparql-blue.png"/></a>,
#  <a href="https://opendefinition.org/"><img alt="This material is Open Knowledge" src="/statics/images/od_80x15_red_green.png"/></a>,
#  <a href="https://validator.w3.org/check?uri=referer">
#  <img alt="Valid XHTML + RDFa" src="https://www.w3.org/Icons/valid-xhtml-rdfa"/>
#  </a>,
#  <a href="http://en.wikipedia.org/wiki/Digby_Morrell">Wikipedia</a>,
#  <a href="http://creativecommons.org/licenses/by-sa/3.0/">Creative Commons Attribution-ShareAlike 3.0 Unported License</a>]

# %%
len(a_tags)
# Out:
# 177

# %%
[ tag.attrs for tag in a_tags ]
# Out:
# [{'class': ['navbar-brand'],
#   'href': 'http://wiki.dbpedia.org/about',
#   'title': 'About DBpedia',
#   'style': 'color: #2c5078'},
#  {'class': ['nav-link', 'dropdown-toggle'],
#   'href': '#',
#   'id': 'navbarDropdownBrowse',
#   'role': 'button',
#   'data-bs-toggle': 'dropdown',
#   'aria-expanded': 'false'},
#  {'class': ['nav-link'],
#   'href': '/describe/?uri=http%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell'},
#  {'class': ['nav-link'],
#   'href': 'http://osde.demo.openlinksw.com/#/editor?uri=http%3A%2F%2Fdbpedia.org%2Fdata%2FDigby_Morrell.ttl&view=statements'},
#  {'class': ['nav-link'],
#   'href': 'http://en.lodlive.it/?http%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell'},
#  {'class': ['nav-link', 'dropdown-toggle'],
#   'href': '#',
#   'id': 'navbarDropdownFormats',
#   'role': 'button',
#   'data-bs-toggle': 'dropdown',
#   'aria-expanded': 'false'},
#  {'class': ['dropdown-item'],
#   'href': 'http://dbpedia.org/data/Digby_Morrell.ntriples'},
#  {'class': ['dropdown-item'],
#   'href': 'http://dbpedia.org/data/Digby_Morrell.n3'},
#  {'class': ['dropdown-item'],
#   'href': 'http://dbpedia.org/data/Digby_Morrell.ttl'},
#  {'class': ['dropdown-item'],
#   'href': 'http://dbpedia.org/data/Digby_Morrell.json'},
#  {'class': ['dropdown-item'],
#   'href': 'http://dbpedia.org/data/Digby_Morrell.rdf'},
#  {'class': ['dropdown-item'],
#   'href': 'http://dbpedia.org/data/Digby_Morrell.atom'},
#  {'class': ['dropdown-item'],
#   'href': 'http://dbpedia.org/data/Digby_Morrell.jsod'},
#  {'class': ['dropdown-item'],
#   'href': 'http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&format=application%2Fmicrodata%2Bjson'},
#  {'class': ['dropdown-item'],
#   'href': 'http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&format=text%2Fhtml'},
#  {'class': ['dropdown-item'],
#   'href': 'http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&format=text%2Fx-html-script-ld%2Bjson'},
#  {'class': ['dropdown-item'],
#   'href': 'http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&format=text%2Fx-html-script-turtle'},
#  {'class': ['dropdown-item'],
#   'href': 'http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&format=text%2Fcsv'},
#  {'class': ['dropdown-item'],
#   'href': 'http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FDigby_Morrell%3E&format=application%2Fld%2Bjson'},
#  {'class': ['nav-link'], 'href': '/fct/', 'title': 'Switch to /fct endpoint'},
#  {'class': ['nav-link'],
#   'href': '/sparql/',
#   'title': 'Switch to /sparql endpoint'},
#  {'href': 'http://dbpedia.org/resource/Digby_Morrell'},
#  {'href': 'http://dbpedia.org/ontology/Animal'},
#  {'href': 'http://dbpedia.org'},
#  {'href': 'http://dbpedia.org'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/ontology/Person/height'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/ontology/Person/weight'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/ontology/abstract'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/ontology/birthDate'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/ontology/careerStation'},
#  {'class': ['uri'],
#   'rel': ['dbo:careerStation'],
#   'resource': 'http://dbpedia.org/resource/Digby_Morrell__CareerStation__1',
#   'href': 'http://dbpedia.org/resource/Digby_Morrell__CareerStation__1'},
#  {'class': ['uri'],
#   'rel': ['dbo:careerStation'],
#   'resource': 'http://dbpedia.org/resource/Digby_Morrell__CareerStation__2',
#   'href': 'http://dbpedia.org/resource/Digby_Morrell__CareerStation__2'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/ontology/debutTeam'},
#  {'class': ['uri'],
#   'rel': ['dbo:debutTeam'],
#   'resource': 'http://dbpedia.org/resource/North_Melbourne_Football_Club',
#   'href': 'http://dbpedia.org/resource/North_Melbourne_Football_Club'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/ontology/height'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/ontology/weight'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/ontology/wikiPageID'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/ontology/wikiPageLength'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/ontology/wikiPageRevisionID'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Carlton_Football_Club',
#   'href': 'http://dbpedia.org/resource/Carlton_Football_Club'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Category:1979_births',
#   'href': 'http://dbpedia.org/resource/Category:1979_births'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/David_Teague_(footballer)',
#   'href': 'http://dbpedia.org/resource/David_Teague_(footballer)'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Victorian_Football_League',
#   'href': 'http://dbpedia.org/resource/Victorian_Football_League'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Category:Living_people',
#   'href': 'http://dbpedia.org/resource/Category:Living_people'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Corey_McKernan',
#   'href': 'http://dbpedia.org/resource/Corey_McKernan'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Strathmore_Football_Club',
#   'href': 'http://dbpedia.org/resource/Strathmore_Football_Club'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Australian_Football_League',
#   'href': 'http://dbpedia.org/resource/Australian_Football_League'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/2000_AFL_Draft',
#   'href': 'http://dbpedia.org/resource/2000_AFL_Draft'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/West_Australian_Football_League',
#   'href': 'http://dbpedia.org/resource/West_Australian_Football_League'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/West_Coburg_Football_Club',
#   'href': 'http://dbpedia.org/resource/West_Coburg_Football_Club'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/West_Perth_Football_Club',
#   'href': 'http://dbpedia.org/resource/West_Perth_Football_Club'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Essendon_District_Football_League',
#   'href': 'http://dbpedia.org/resource/Essendon_District_Football_League'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/North_Melbourne_Football_Club',
#   'href': 'http://dbpedia.org/resource/North_Melbourne_Football_Club'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Parade_College',
#   'href': 'http://dbpedia.org/resource/Parade_College'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Pascoe_Vale_Football_Club',
#   'href': 'http://dbpedia.org/resource/Pascoe_Vale_Football_Club'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Category:Australian_rules_footballers_from_Western_Australia',
#   'href': 'http://dbpedia.org/resource/Category:Australian_rules_footballers_from_Western_Australia'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Category:Box_Hill_Football_Club_players',
#   'href': 'http://dbpedia.org/resource/Category:Box_Hill_Football_Club_players'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Category:Carlton_Football_Club_players',
#   'href': 'http://dbpedia.org/resource/Category:Carlton_Football_Club_players'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Category:North_Melbourne_Football_Club_players',
#   'href': 'http://dbpedia.org/resource/Category:North_Melbourne_Football_Club_players'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Category:Preston_Football_Club_(VFA)_players',
#   'href': 'http://dbpedia.org/resource/Category:Preston_Football_Club_(VFA)_players'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Australian_rules_football',
#   'href': 'http://dbpedia.org/resource/Australian_rules_football'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Northern_Bullants',
#   'href': 'http://dbpedia.org/resource/Northern_Bullants'},
#  {'class': ['uri'],
#   'rel': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Box_Hill_Hawks',
#   'href': 'http://dbpedia.org/resource/Box_Hill_Hawks'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/property/birthDate'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/property/club'},
#  {'class': ['uri'],
#   'rel': ['dbp:club'],
#   'resource': 'http://dbpedia.org/resource/Carlton_Football_Club',
#   'href': 'http://dbpedia.org/resource/Carlton_Football_Club'},
#  {'class': ['uri'],
#   'rel': ['dbp:club'],
#   'resource': 'http://dbpedia.org/resource/North_Melbourne_Football_Club',
#   'href': 'http://dbpedia.org/resource/North_Melbourne_Football_Club'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/property/debutdate'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/property/debutopponent'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/property/debutstadium'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/property/debutteam'},
#  {'class': ['uri'],
#   'rel': ['dbp:debutteam'],
#   'resource': 'http://dbpedia.org/resource/North_Melbourne_Football_Club',
#   'href': 'http://dbpedia.org/resource/North_Melbourne_Football_Club'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/property/gamesGoals'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/property/gamesGoalstotal'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/property/height'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/property/name'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/property/originalteam'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/property/statsend'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/property/weight'},
#  {'class': ['uri'],
#   'href': 'http://dbpedia.org/property/wikiPageUsesTemplate'},
#  {'class': ['uri'],
#   'rel': ['dbp:wikiPageUsesTemplate'],
#   'resource': 'http://dbpedia.org/resource/Template:AFL_Tables',
#   'href': 'http://dbpedia.org/resource/Template:AFL_Tables'},
#  {'class': ['uri'],
#   'rel': ['dbp:wikiPageUsesTemplate'],
#   'resource': 'http://dbpedia.org/resource/Template:Commons_category',
#   'href': 'http://dbpedia.org/resource/Template:Commons_category'},
#  {'class': ['uri'],
#   'rel': ['dbp:wikiPageUsesTemplate'],
#   'resource': 'http://dbpedia.org/resource/Template:Reflist',
#   'href': 'http://dbpedia.org/resource/Template:Reflist'},
#  {'class': ['uri'],
#   'rel': ['dbp:wikiPageUsesTemplate'],
#   'resource': 'http://dbpedia.org/resource/Template:Short_description',
#   'href': 'http://dbpedia.org/resource/Template:Short_description'},
#  {'class': ['uri'],
#   'rel': ['dbp:wikiPageUsesTemplate'],
#   'resource': 'http://dbpedia.org/resource/Template:Use_Australian_English',
#   'href': 'http://dbpedia.org/resource/Template:Use_Australian_English'},
#  {'class': ['uri'],
#   'rel': ['dbp:wikiPageUsesTemplate'],
#   'resource': 'http://dbpedia.org/resource/Template:Use_dmy_dates',
#   'href': 'http://dbpedia.org/resource/Template:Use_dmy_dates'},
#  {'class': ['uri'],
#   'rel': ['dbp:wikiPageUsesTemplate'],
#   'resource': 'http://dbpedia.org/resource/Template:Birth_date_and_age',
#   'href': 'http://dbpedia.org/resource/Template:Birth_date_and_age'},
#  {'class': ['uri'],
#   'rel': ['dbp:wikiPageUsesTemplate'],
#   'resource': 'http://dbpedia.org/resource/Template:2001_AFL_rookie_draft',
#   'href': 'http://dbpedia.org/resource/Template:2001_AFL_rookie_draft'},
#  {'class': ['uri'],
#   'rel': ['dbp:wikiPageUsesTemplate'],
#   'resource': 'http://dbpedia.org/resource/Template:Infobox_AFL_biography',
#   'href': 'http://dbpedia.org/resource/Template:Infobox_AFL_biography'},
#  {'class': ['uri'],
#   'rel': ['dbp:wikiPageUsesTemplate'],
#   'resource': 'http://dbpedia.org/resource/Template:VFL-affiliate',
#   'href': 'http://dbpedia.org/resource/Template:VFL-affiliate'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/property/wordnet_type'},
#  {'class': ['uri'],
#   'rel': ['dbp:wordnet_type', 'nofollow'],
#   'resource': 'http://www.w3.org/2006/03/wn/wn20/instances/synset-football_player-noun-1',
#   'href': 'http://www.w3.org/2006/03/wn/wn20/instances/synset-football_player-noun-1'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/property/years'},
#  {'class': ['uri'], 'href': 'http://purl.org/dc/terms/subject'},
#  {'class': ['uri'],
#   'rel': ['dcterms:subject'],
#   'resource': 'http://dbpedia.org/resource/Category:1979_births',
#   'prefix': 'dcterms: http://purl.org/dc/terms/',
#   'href': 'http://dbpedia.org/resource/Category:1979_births'},
#  {'class': ['uri'],
#   'rel': ['dcterms:subject'],
#   'resource': 'http://dbpedia.org/resource/Category:Living_people',
#   'prefix': 'dcterms: http://purl.org/dc/terms/',
#   'href': 'http://dbpedia.org/resource/Category:Living_people'},
#  {'class': ['uri'],
#   'rel': ['dcterms:subject'],
#   'resource': 'http://dbpedia.org/resource/Category:Australian_rules_footballers_from_Western_Australia',
#   'prefix': 'dcterms: http://purl.org/dc/terms/',
#   'href': 'http://dbpedia.org/resource/Category:Australian_rules_footballers_from_Western_Australia'},
#  {'class': ['uri'],
#   'rel': ['dcterms:subject'],
#   'resource': 'http://dbpedia.org/resource/Category:Box_Hill_Football_Club_players',
#   'prefix': 'dcterms: http://purl.org/dc/terms/',
#   'href': 'http://dbpedia.org/resource/Category:Box_Hill_Football_Club_players'},
#  {'class': ['uri'],
#   'rel': ['dcterms:subject'],
#   'resource': 'http://dbpedia.org/resource/Category:Carlton_Football_Club_players',
#   'prefix': 'dcterms: http://purl.org/dc/terms/',
#   'href': 'http://dbpedia.org/resource/Category:Carlton_Football_Club_players'},
#  {'class': ['uri'],
#   'rel': ['dcterms:subject'],
#   'resource': 'http://dbpedia.org/resource/Category:North_Melbourne_Football_Club_players',
#   'prefix': 'dcterms: http://purl.org/dc/terms/',
#   'href': 'http://dbpedia.org/resource/Category:North_Melbourne_Football_Club_players'},
#  {'class': ['uri'],
#   'rel': ['dcterms:subject'],
#   'resource': 'http://dbpedia.org/resource/Category:Preston_Football_Club_(VFA)_players',
#   'prefix': 'dcterms: http://purl.org/dc/terms/',
#   'href': 'http://dbpedia.org/resource/Category:Preston_Football_Club_(VFA)_players'},
#  {'class': ['uri'], 'href': 'http://purl.org/linguistics/gold/hypernym'},
#  {'class': ['uri'],
#   'rel': ['gold:hypernym'],
#   'resource': 'http://dbpedia.org/resource/Footballer',
#   'prefix': 'gold: http://purl.org/linguistics/gold/',
#   'href': 'http://dbpedia.org/resource/Footballer'},
#  {'class': ['uri'], 'href': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://www.w3.org/2002/07/owl#Thing',
#   'href': 'http://www.w3.org/2002/07/owl#Thing'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://xmlns.com/foaf/0.1/Person',
#   'href': 'http://xmlns.com/foaf/0.1/Person'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/ontology/Person',
#   'href': 'http://dbpedia.org/ontology/Person'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#NaturalPerson',
#   'href': 'http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#NaturalPerson'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://www.wikidata.org/entity/Q19088',
#   'href': 'http://www.wikidata.org/entity/Q19088'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://www.wikidata.org/entity/Q215627',
#   'href': 'http://www.wikidata.org/entity/Q215627'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://www.wikidata.org/entity/Q5',
#   'href': 'http://www.wikidata.org/entity/Q5'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://www.wikidata.org/entity/Q729',
#   'href': 'http://www.wikidata.org/entity/Q729'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://www.wikidata.org/entity/Q13414980',
#   'href': 'http://www.wikidata.org/entity/Q13414980'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/WikicatAustralianRulesFootballersFromWesternAustralia',
#   'href': 'http://dbpedia.org/class/yago/WikicatAustralianRulesFootballersFromWesternAustralia'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/WikicatBoxHillFootballClubPlayers',
#   'href': 'http://dbpedia.org/class/yago/WikicatBoxHillFootballClubPlayers'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/ontology/Animal',
#   'href': 'http://dbpedia.org/ontology/Animal'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/ontology/Athlete',
#   'href': 'http://dbpedia.org/ontology/Athlete'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/ontology/AustralianRulesFootballPlayer',
#   'href': 'http://dbpedia.org/ontology/AustralianRulesFootballPlayer'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/ontology/Eukaryote',
#   'href': 'http://dbpedia.org/ontology/Eukaryote'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/ontology/SoccerPlayer',
#   'href': 'http://dbpedia.org/ontology/SoccerPlayer'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/ontology/Species',
#   'href': 'http://dbpedia.org/ontology/Species'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/WikicatCarltonFootballClubPlayers',
#   'href': 'http://dbpedia.org/class/yago/WikicatCarltonFootballClubPlayers'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://schema.org/Person',
#   'href': 'http://schema.org/Person'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/WikicatLivingPeople',
#   'href': 'http://dbpedia.org/class/yago/WikicatLivingPeople'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/WikicatNorthMelbourneFootballClubPlayers',
#   'href': 'http://dbpedia.org/class/yago/WikicatNorthMelbourneFootballClubPlayers'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/WikicatNorthernBluesPlayers',
#   'href': 'http://dbpedia.org/class/yago/WikicatNorthernBluesPlayers'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/Athlete109820263',
#   'href': 'http://dbpedia.org/class/yago/Athlete109820263'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/CausalAgent100007347',
#   'href': 'http://dbpedia.org/class/yago/CausalAgent100007347'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/Contestant109613191',
#   'href': 'http://dbpedia.org/class/yago/Contestant109613191'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/FootballPlayer110101634',
#   'href': 'http://dbpedia.org/class/yago/FootballPlayer110101634'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/LivingThing100004258',
#   'href': 'http://dbpedia.org/class/yago/LivingThing100004258'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/Object100002684',
#   'href': 'http://dbpedia.org/class/yago/Object100002684'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/Organism100004475',
#   'href': 'http://dbpedia.org/class/yago/Organism100004475'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/Person100007846',
#   'href': 'http://dbpedia.org/class/yago/Person100007846'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/PhysicalEntity100001930',
#   'href': 'http://dbpedia.org/class/yago/PhysicalEntity100001930'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/Player110439851',
#   'href': 'http://dbpedia.org/class/yago/Player110439851'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/YagoLegalActor',
#   'href': 'http://dbpedia.org/class/yago/YagoLegalActor'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/YagoLegalActorGeo',
#   'href': 'http://dbpedia.org/class/yago/YagoLegalActorGeo'},
#  {'class': ['uri'],
#   'rel': ['rdf:type'],
#   'resource': 'http://dbpedia.org/class/yago/Whole100003553',
#   'href': 'http://dbpedia.org/class/yago/Whole100003553'},
#  {'class': ['uri'], 'href': 'http://www.w3.org/2000/01/rdf-schema#comment'},
#  {'class': ['uri'], 'href': 'http://www.w3.org/2000/01/rdf-schema#label'},
#  {'class': ['uri'], 'href': 'http://www.w3.org/2002/07/owl#sameAs'},
#  {'class': ['uri'],
#   'rel': ['owl:sameAs'],
#   'resource': 'http://rdf.freebase.com/ns/m.02w_8_k',
#   'href': 'http://rdf.freebase.com/ns/m.02w_8_k'},
#  {'class': ['uri'],
#   'rel': ['owl:sameAs'],
#   'resource': 'http://yago-knowledge.org/resource/Digby_Morrell',
#   'href': 'http://yago-knowledge.org/resource/Digby_Morrell'},
#  {'class': ['uri'],
#   'rel': ['owl:sameAs'],
#   'resource': 'http://www.wikidata.org/entity/Q5275580',
#   'href': 'http://www.wikidata.org/entity/Q5275580'},
#  {'class': ['uri'],
#   'rel': ['owl:sameAs'],
#   'resource': 'https://global.dbpedia.org/id/4innu',
#   'href': 'https://global.dbpedia.org/id/4innu'},
#  {'class': ['uri'], 'href': 'http://www.w3.org/ns/prov#wasDerivedFrom'},
#  {'class': ['uri'],
#   'rel': ['prov:wasDerivedFrom'],
#   'resource': 'http://en.wikipedia.org/wiki/Digby_Morrell?oldid=1108573112&ns=0',
#   'href': 'http://en.wikipedia.org/wiki/Digby_Morrell?oldid=1108573112&ns=0'},
#  {'class': ['uri'], 'href': 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf'},
#  {'class': ['uri'],
#   'rel': ['foaf:isPrimaryTopicOf'],
#   'resource': 'http://en.wikipedia.org/wiki/Digby_Morrell',
#   'href': 'http://en.wikipedia.org/wiki/Digby_Morrell'},
#  {'class': ['uri'], 'href': 'http://xmlns.com/foaf/0.1/name'},
#  {'class': ['uri'],
#   'href': 'http://dbpedia.org/ontology/wikiPageDisambiguates'},
#  {'class': ['uri'],
#   'rev': ['dbo:wikiPageDisambiguates'],
#   'resource': 'http://dbpedia.org/resource/Morrell',
#   'href': 'http://dbpedia.org/resource/Morrell'},
#  {'class': ['uri'], 'href': 'http://dbpedia.org/ontology/wikiPageWikiLink'},
#  {'class': ['uri'],
#   'rev': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Morrell',
#   'href': 'http://dbpedia.org/resource/Morrell'},
#  {'class': ['uri'],
#   'rev': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/1998_Westar_Rules_Grand_Final',
#   'href': 'http://dbpedia.org/resource/1998_Westar_Rules_Grand_Final'},
#  {'class': ['uri'],
#   'rev': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/2001_WAFL_season',
#   'href': 'http://dbpedia.org/resource/2001_WAFL_season'},
#  {'class': ['uri'],
#   'rev': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/2002_AFL_draft',
#   'href': 'http://dbpedia.org/resource/2002_AFL_draft'},
#  {'class': ['uri'],
#   'rev': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/2003_AFL_draft',
#   'href': 'http://dbpedia.org/resource/2003_AFL_draft'},
#  {'class': ['uri'],
#   'rev': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/List_of_AFL_debuts_in_2004',
#   'href': 'http://dbpedia.org/resource/List_of_AFL_debuts_in_2004'},
#  {'class': ['uri'],
#   'rev': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/List_of_Carlton_Football_Club_players',
#   'href': 'http://dbpedia.org/resource/List_of_Carlton_Football_Club_players'},
#  {'class': ['uri'],
#   'rev': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/2005_VFL_season',
#   'href': 'http://dbpedia.org/resource/2005_VFL_season'},
#  {'class': ['uri'],
#   'rev': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/2006_VFL_season',
#   'href': 'http://dbpedia.org/resource/2006_VFL_season'},
#  {'class': ['uri'],
#   'rev': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/Digby_(name)',
#   'href': 'http://dbpedia.org/resource/Digby_(name)'},
#  {'class': ['uri'],
#   'rev': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/List_of_North_Melbourne_Football_Club_players',
#   'href': 'http://dbpedia.org/resource/List_of_North_Melbourne_Football_Club_players'},
#  {'class': ['uri'],
#   'rev': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/List_of_Old_Haleians',
#   'href': 'http://dbpedia.org/resource/List_of_Old_Haleians'},
#  {'class': ['uri'],
#   'rev': ['dbo:wikiPageWikiLink'],
#   'resource': 'http://dbpedia.org/resource/2000_AFL_draft',
#   'href': 'http://dbpedia.org/resource/2000_AFL_draft'},
#  {'class': ['uri'], 'href': 'http://xmlns.com/foaf/0.1/primaryTopic'},
#  {'class': ['uri'],
#   'rev': ['foaf:primaryTopic'],
#   'resource': 'http://en.wikipedia.org/wiki/Digby_Morrell',
#   'href': 'http://en.wikipedia.org/wiki/Digby_Morrell'},
#  {'href': 'https://virtuoso.openlinksw.com/', 'title': 'OpenLink Virtuoso'},
#  {'href': 'http://linkeddata.org/'},
#  {'href': 'http://dbpedia.org/sparql'},
#  {'href': 'https://opendefinition.org/'},
#  {'href': 'https://validator.w3.org/check?uri=referer'},
#  {'href': 'http://en.wikipedia.org/wiki/Digby_Morrell'},
#  {'href': 'http://creativecommons.org/licenses/by-sa/3.0/'}]

# %%
for a_tag in a_tags:
  href = a_tag.attrs["href"]
  if href.startswith("http"):
    rev = a_tag.attrs.get("rev","")
    if "foaf:primaryTopic" in rev:
      print(href)
# Out:
# http://en.wikipedia.org/wiki/Digby_Morrell

# %% [markdown]
# Using only CSS selectors.

# %%
foaf_pt = dom.select('a[href^="http"][rev="foaf:primaryTopic"]')
foaf_pt[0].attrs["href"]
# Out:
# 'http://en.wikipedia.org/wiki/Digby_Morrell'

# %%
foaf_pt[0].attrs["href"].split("/")[-1]

# %% [markdown]
# ### STEM Boomerang

# %% [markdown]
# https://stemboomerang.org/stem-career-fair-23/

# %%
url = "https://stemboomerang.org/stem-career-fair-23/"

# %% [markdown]
# Using curl to save an html file, then parse the html file.

# %%
# !curl -s {url} > boom.html
# !ls -la
# Out:
# total 8916
# drwxr-xr-x 1 root root    4096 Jun 17 16:27 .
# drwxr-xr-x 1 root root    4096 Jun 17 16:15 ..
# -rw-r--r-- 1 root root 8802488 Jun 17 16:16 Automate_the_Boring_Stuff_onlinematerials_v.2.zip
# -rw-r--r-- 1 root root  300630 Jun 17 16:27 boom.html
# drwxr-xr-x 4 root root    4096 Jun 13 13:27 .config
# -rw-r--r-- 1 root root     324 Mar 30  2015 example.html
# drwxr-xr-x 1 root root    4096 Jun 13 13:28 sample_data

# %%
# !grep -i tricore boom.html
# Out:
# <p>.</div></div></div></div></div><div class="wpb_column vc_column_container vc_col-sm-4 vc_col-has-fill "><div class="vc_column-inner vc_custom_1675479607705"><div class="wpb_wrapper"><style type="text/css" scoped="scoped">.vc_front_widget.fs_scope_5{background-color: #ffffff;color: #777777;transition: all .2s linear; -webkit-transition: all .2s linear;border: 1px solid #eeeeee;}.vc_front_widget.fs_scope_5:hover{background-color: #0daa95;color: #ffffff;border-color:#ffffff;}.vc_front_widget.fs_scope_5 .font_icons {color: #db9232;transition: all .2s linear; -webkit-transition: all .2s linear;}.vc_front_widget.fs_scope_5:hover .font_icons {color: #ffffff;}.vc_front_widget.fs_scope_5 a {color: #4a9b45;transition: all .2s linear; -webkit-transition: all .2s linear;}.vc_front_widget.fs_scope_5:hover a {color: #ffffff;}.vc_front_widget.fs_scope_5 h3.widget-title, .vc_front_widget.fs_scope_5 h3.widget-title a {color: #444444;transition: all .2s linear; -webkit-transition: all .2s linear;}.vc_front_widget.fs_scope_5:hover h3.widget-title, .vc_front_widget.fs_scope_5:hover h3.widget-title a {color: #ffffff;}.vc_front_widget.fs_scope_5 .content_box_text {color: #777777;transition: all .2s linear; -webkit-transition: all .2s linear;}.vc_front_widget.fs_scope_5:hover .content_box_text {color: #ffffff;}</style><div class="vc_front_widget w-full text-center text-gray-600 box-border p-6 bg-transparent transition-colors duration-200 ease-linear fs_scope_5  " ><span class="shortcode_img z-10 no_white_circle block rounded-none bg-transparent h-auto w-auto mb-6 font_icons"><i class="vc_li vc_li-banknote" style="font-size: 30px"></i></span><h3 class="widget-title text-base font-bold mb-6 text-center uppercase">COST</h3><div class="content_box_text leading-loose block">FREE for job seekers and students</div></div><style type="text/css" scoped="scoped">.vc_front_widget.fs_scope_6{background-color: #ffffff;color: #777777;transition: all .2s linear; -webkit-transition: all .2s linear;border: 1px solid #eeeeee;}.vc_front_widget.fs_scope_6:hover{background-color: #0daa95;color: #ffffff;border-color:#ffffff;}.vc_front_widget.fs_scope_6 .font_icons {color: #db9232;transition: all .2s linear; -webkit-transition: all .2s linear;}.vc_front_widget.fs_scope_6:hover .font_icons {color: #ffffff;}.vc_front_widget.fs_scope_6 a {color: #4a9b45;transition: all .2s linear; -webkit-transition: all .2s linear;}.vc_front_widget.fs_scope_6:hover a {color: #ffffff;}.vc_front_widget.fs_scope_6 h3.widget-title, .vc_front_widget.fs_scope_6 h3.widget-title a {color: #444444;transition: all .2s linear; -webkit-transition: all .2s linear;}.vc_front_widget.fs_scope_6:hover h3.widget-title, .vc_front_widget.fs_scope_6:hover h3.widget-title a {color: #ffffff;}.vc_front_widget.fs_scope_6 .content_box_text {color: #777777;transition: all .2s linear; -webkit-transition: all .2s linear;}.vc_front_widget.fs_scope_6:hover .content_box_text {color: #ffffff;}</style><div class="vc_front_widget w-full text-center text-gray-600 box-border p-6 bg-transparent transition-colors duration-200 ease-linear fs_scope_6  " ><span class="shortcode_img z-10 no_white_circle block rounded-none bg-transparent h-auto w-auto mb-6 font_icons"><i class="vc_li vc_li-like" style="font-size: 30px"></i></span><h3 class="widget-title text-base font-bold mb-6 text-center uppercase">BEFORE THE EVENT</h3><div class="content_box_text leading-loose block"><a href="http://www.boomerang-nm.com">Create a free Career profile</a></div></div></div></div></div></div><div class="vc_row-full-width vc_clearfix"></div><div data-vc-full-width="true" data-vc-full-width-init="false" class="vc_row wpb_row vc_row-fluid vc_custom_1447688555128"><div class="wpb_column vc_column_container vc_col-sm-12 vc_col-has-fill "><div class="vc_column-inner vc_custom_1677125876998"><div class="wpb_wrapper"><h2 style="font-size: 40px;color: #3d3d3d;line-height: 1;text-align: center;font-family:Roboto;font-weight:400;font-style:normal" class="vc_cu ...

# %%
with open('boom.html') as boom_file:
  html = boom_file.read()
dom = bs4.BeautifulSoup( html, 'html.parser')
str(dom)[:500]
# Out:
# '<!DOCTYPE html>\n\n<html class="creativo-elements-custom-header" dir="ltr" lang="en-US" prefix="og: https://ogp.me/ns#" xmlns:fb="//www.facebook.com/2008/fbml" xmlns:og="//opengraphprotocol.org/schema/">\n<head>\n<meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n<meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n<meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>\n<meta charset="utf-8"/>\n<link href="https://gmpg.org/xfn/11" rel="profile"/>\n<ti'

# %% [markdown]
# Using `requests` and `bs4`.

# %%
url = "https://stemboomerang.org/stem-career-fair-23/"
boom = requests.get(url)
boom
# Out:
# <Response [406]>

# %%
boom.request.headers
# Out:
# {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %% [markdown]
# Modify the `user-agent` header.

# %%
user_agent = {'User-agent': 'Mozilla/5.0 (X11; CrOS x86_64 14541.0.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'}
user_agent = {'User-agent': 'foobar'}
user_agent = {'User-agent': 'python-requests'}
user_agent = {'User-agent': 'I am a hacker.  I should be blocked from your site.'}
boom = requests.get(url, headers = user_agent)
boom
# Out:
# <Response [200]>

# %%
boom.request.headers
# Out:
# {'User-agent': 'I am a hacker.  I should be blocked from your site.', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
html = boom.text

# %%
dom = bs4.BeautifulSoup( html, 'html.parser')
str(dom)[:500]
# Out:
# '<!DOCTYPE html>\n\n<html class="creativo-elements-custom-header" dir="ltr" lang="en-US" prefix="og: https://ogp.me/ns#" xmlns:fb="//www.facebook.com/2008/fbml" xmlns:og="//opengraphprotocol.org/schema/">\n<head>\n<meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n<meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>\n<meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>\n<meta charset="utf-8"/>\n<link href="https://gmpg.org/xfn/11" rel="profile"/>\n<ti'

# %%
a_tags = dom.select("a")
a_tags
# Out:
# [<a class="skip-link screen-reader-text" href="#content">Skip to content</a>,
#  <a href="https://stemboomerang.org" rel="home" title="stemboomerang.org">
#  						stemboomerang.org					</a>,
#  <a href="https://stemboomerang.org" rel="home" title="stemboomerang.org">
#  <img alt="Boomerang New Mexico" class="cr-site-logo-default" decoding="async" height="527" sizes="(max-width: 2095px) 100vw, 2095px" src="https://i0.wp.com/stemboomerang.org/wp-content/uploads/2021/01/BoomerangNM.jpg?fit=2095%2C527&amp;ssl=1" srcset="https://i0.wp.com/stemboomerang.org/wp-content/uploads/2021/01/BoomerangNM.jpg?w=2095&amp;ssl=1 2095w, https://i0.wp.com/stemboomerang.org/wp-content/uploads/2021/01/BoomerangNM.jpg?resize=300%2C75&amp;ssl=1 300w, https://i0.wp.com/stemboomerang.org/wp-content/uploads/2021/01/BoomerangNM.jpg?resize=1024%2C258&amp;ssl=1 1024w, https://i0.wp.com/stemboomerang.org/wp-content/uploads/2021/01/BoomerangNM.jpg?resize=768%2C193&amp;ssl=1 768w, https://i0.wp.com/stemboomerang.org/wp-content/uploads/2021/01/BoomerangNM.jpg?resize=1536%2C386&amp;ssl=1 1536w, https://i0.wp.com/stemboomerang.org/wp-content/uploads/2021/01/BoomerangNM.jpg?resize=2048%2C515&amp;ssl=1 2048w, https://i0.wp.com/stemboomerang.org/wp-content/uploads/2021/01/BoomerangNM.jpg?w=1280&amp;ssl=1 1280w, https://i0.wp.com/stemboomerang.org/wp-content/uploads/2021/01/BoomerangNM.jpg?w=1920&amp;ssl=1 1920w" width="2095"/> </a>,
#  <a href="https://stemboomerang.org">Home</a>,
#  <a href="https://stemboomerang.org/our-mission/">Mission</a>,
#  <a href="https://www.boomerang-nm.com/info">Job Seekers</a>,
#  <a href="https://stemboomerang.org/home/contact/">Contact Us</a>,
#  <a href="https://stemboomerang.org"></a>,
#  <a href="https://www.qstation.tech/">Q Station</a>,
#  <a href="mailto:Info@stemboomerang.org">Info@stemboomerang.org</a>,
#  <a href="http://www.boomerang-nm.com">Create a free Career profile</a>,
#  <a class="block" href="https://jgmsinc.com/" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a class="block" href="https://techsource-inc.com/careers" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a class="block" href="https://www.visionquest-bio.com/" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a class="block" href="www.phs.org" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a class="block" href="www.ideas-tek.com/join-us" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a class="block" href="https://careers-encantadotech.icims.com/jobs/search?ss=1&amp;searchRelation=keyword_all&amp;searchCategory=8730" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a class="block" href="https://rs21.io/careers" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a class="block" href="https://axientcorp.com/resource/corporate-overview/" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a class="block" href="https://www.stemsantafe.org/jobs" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a class="block" href="https://www.tricore.org/about-tricore/careers/" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a class="block" href="https://www.tecolote.com/careers" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a class="block" href="https://goadelante.org/315-2/employment/" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a class="block" href="https://goadelante.org/315-2/employment/" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a class="block" href="https://honeywell.phenompro.com/us/en/campaign-fm-t" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a class="block" href="https://jobs.boeing.com/" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a class="block" href="https://www.pebblelabs.com/careers" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>,
#  <a href="https://theencantadofoundation.org/">Sponsored by Encantado Foundation</a>,
#  <a class="vc_single_image-wrapper vc_box_border_grey" href="https://theencantadofoundation.org/" target="_self"><img alt="" class="vc_single_image-img attachment-medium" decoding="async" height="79" sizes="(max-width: 300px) 100vw, 300px" src="https://i0.wp.com/stemboomerang.org/wp-content/uploads/2023/02/encantado-foundation-logo.png?fit=300%2C79&amp;ssl=1" srcset="https://i0.wp.com/stemboomerang.org/wp-content/uploads/2023/02/encantado-foundation-logo.png?w=439&amp;ssl=1 439w, https://i0.wp.com/stemboomerang.org/wp-content/uploads/2023/02/encantado-foundation-logo.png?resize=300%2C79&amp;ssl=1 300w" title="encantado foundation logo" width="300"/></a>,
#  <a href="https://stemboomerang.org" rel="home" title="stemboomerang.org">
#  </a>,
#  <a class="facebook ntip" href="https://www.facebook.com/STEMBoomerang" target="_blank" title="Follow on Facebook"><i class="fa fa-facebook"></i></a>,
#  <a class="linkedin ntip" href="https://www.linkedin.com/company/stem-boomerang/" target="_blank" title="Follow on LinkedIn"><i class="fa fa-linkedin"></i></a>,
#  <a href="https://www.monsterinsights.com/?utm_source=verifiedBadge&amp;utm_medium=verifiedBadge&amp;utm_campaign=verifiedbyMonsterInsights" rel="nofollow" target="_blank"><img alt="Verified by MonsterInsights" src="https://stemboomerang.org/wp-content/plugins/google-analytics-for-wordpress/assets/images/monsterinsights-badge-light.svg" style="display: inline-block" title="Verified by MonsterInsights"/></a>]

# %%
len(a_tags)
# Out:
# 33

# %%
[ tag.attrs for tag in a_tags ]
# Out:
# [{'class': ['skip-link', 'screen-reader-text'], 'href': '#content'},
#  {'href': 'https://stemboomerang.org',
#   'title': 'stemboomerang.org',
#   'rel': ['home']},
#  {'href': 'https://stemboomerang.org',
#   'rel': ['home'],
#   'title': 'stemboomerang.org'},
#  {'href': 'https://stemboomerang.org'},
#  {'href': 'https://stemboomerang.org/our-mission/'},
#  {'href': 'https://www.boomerang-nm.com/info'},
#  {'href': 'https://stemboomerang.org/home/contact/'},
#  {'href': 'https://stemboomerang.org'},
#  {'href': 'https://www.qstation.tech/'},
#  {'href': 'mailto:Info@stemboomerang.org'},
#  {'href': 'http://www.boomerang-nm.com'},
#  {'href': 'https://jgmsinc.com/', 'target': '_self', 'class': ['block']},
#  {'href': 'https://techsource-inc.com/careers',
#   'target': '_self',
#   'class': ['block']},
#  {'href': 'https://www.visionquest-bio.com/',
#   'target': '_self',
#   'class': ['block']},
#  {'href': 'www.phs.org', 'target': '_self', 'class': ['block']},
#  {'href': 'www.ideas-tek.com/join-us', 'target': '_self', 'class': ['block']},
#  {'href': 'https://careers-encantadotech.icims.com/jobs/search?ss=1&searchRelation=keyword_all&searchCategory=8730',
#   'target': '_self',
#   'class': ['block']},
#  {'href': 'https://rs21.io/careers', 'target': '_self', 'class': ['block']},
#  {'href': 'https://axientcorp.com/resource/corporate-overview/',
#   'target': '_self',
#   'class': ['block']},
#  {'href': 'https://www.stemsantafe.org/jobs',
#   'target': '_self',
#   'class': ['block']},
#  {'href': 'https://www.tricore.org/about-tricore/careers/',
#   'target': '_self',
#   'class': ['block']},
#  {'href': 'https://www.tecolote.com/careers',
#   'target': '_self',
#   'class': ['block']},
#  {'href': 'https://goadelante.org/315-2/employment/',
#   'target': '_self',
#   'class': ['block']},
#  {'href': 'https://goadelante.org/315-2/employment/',
#   'target': '_self',
#   'class': ['block']},
#  {'href': 'https://honeywell.phenompro.com/us/en/campaign-fm-t',
#   'target': '_self',
#   'class': ['block']},
#  {'href': 'https://jobs.boeing.com/', 'target': '_self', 'class': ['block']},
#  {'href': 'https://www.pebblelabs.com/careers',
#   'target': '_self',
#   'class': ['block']},
#  {'href': 'https://theencantadofoundation.org/'},
#  {'href': 'https://theencantadofoundation.org/',
#   'target': '_self',
#   'class': ['vc_single_image-wrapper', 'vc_box_border_grey']},
#  {'href': 'https://stemboomerang.org',
#   'rel': ['home'],
#   'title': 'stemboomerang.org'},
#  {'class': ['facebook', 'ntip'],
#   'href': 'https://www.facebook.com/STEMBoomerang',
#   'title': 'Follow on Facebook',
#   'target': '_blank'},
#  {'class': ['linkedin', 'ntip'],
#   'href': 'https://www.linkedin.com/company/stem-boomerang/',
#   'title': 'Follow on LinkedIn',
#   'target': '_blank'},
#  {'href': 'https://www.monsterinsights.com/?utm_source=verifiedBadge&utm_medium=verifiedBadge&utm_campaign=verifiedbyMonsterInsights',
#   'target': '_blank',
#   'rel': ['nofollow']}]

# %%
[ tag.attrs["href"] for tag in a_tags[:10] ]
# Out:
# ['#content',
#  'https://stemboomerang.org',
#  'https://stemboomerang.org',
#  'https://stemboomerang.org',
#  'https://stemboomerang.org/our-mission/',
#  'https://www.boomerang-nm.com/info',
#  'https://stemboomerang.org/home/contact/',
#  'https://stemboomerang.org',
#  'https://www.qstation.tech/',
#  'mailto:Info@stemboomerang.org']

# %%
hrefs = []
for a_tag in a_tags:
  href = a_tag.attrs["href"]
  if href.startswith("http"):
    foo = a_tag.attrs.get("class","")
    if "block" in foo:
      hrefs += [ href ]

len(hrefs)
# Out:
# 14

# %%
sorted(hrefs)
# Out:
# ['https://axientcorp.com/resource/corporate-overview/',
#  'https://careers-encantadotech.icims.com/jobs/search?ss=1&searchRelation=keyword_all&searchCategory=8730',
#  'https://goadelante.org/315-2/employment/',
#  'https://goadelante.org/315-2/employment/',
#  'https://honeywell.phenompro.com/us/en/campaign-fm-t',
#  'https://jgmsinc.com/',
#  'https://jobs.boeing.com/',
#  'https://rs21.io/careers',
#  'https://techsource-inc.com/careers',
#  'https://www.pebblelabs.com/careers',
#  'https://www.stemsantafe.org/jobs',
#  'https://www.tecolote.com/careers',
#  'https://www.tricore.org/about-tricore/careers/',
#  'https://www.visionquest-bio.com/']

# %% [markdown]
# Using only CSS selectors.

# %%
a_tags = dom.select("a[href^='http'][class*='block']")
len(a_tags)
# Out:
# 14

# %%
a_tags[0]
# Out:
# <a class="block" href="https://jgmsinc.com/" target="_self"><span class="overlay_effect block absolute top-0 w-full h-full opacity-0 bg-black transition-opacity duration-200 ease-linear group-hover:opacity-75 flex items-center justify-center"><i class="fa fa-link text-4xl"></i></span></a>

# %%
[ tag.attrs["href"] for tag in a_tags ]
# Out:
# ['https://jgmsinc.com/',
#  'https://techsource-inc.com/careers',
#  'https://www.visionquest-bio.com/',
#  'https://careers-encantadotech.icims.com/jobs/search?ss=1&searchRelation=keyword_all&searchCategory=8730',
#  'https://rs21.io/careers',
#  'https://axientcorp.com/resource/corporate-overview/',
#  'https://www.stemsantafe.org/jobs',
#  'https://www.tricore.org/about-tricore/careers/',
#  'https://www.tecolote.com/careers',
#  'https://goadelante.org/315-2/employment/',
#  'https://goadelante.org/315-2/employment/',
#  'https://honeywell.phenompro.com/us/en/campaign-fm-t',
#  'https://jobs.boeing.com/',
#  'https://www.pebblelabs.com/careers']

# %% [markdown]
# ## XPath

# %% [markdown]
# Using the `lxml` library to pull the same information as the CSS selector.

# %%
from lxml import html
import requests

# %%
page = requests.get('http://www.example.com')
tree = html.fromstring(page.content)
tree
# Out:
# <Element html at 0x79e753d23790>

# %%
page.content
# Out:
# b'<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n    <h1>Example Domain</h1>\n    <p>This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.</p>\n    <p><a href="https://www.iana.org/domains/example">More information...</a></p>\n</div>\n</body>\n</html>\n'

# %%
title = tree.xpath('/html/head/title/text()')
print(title[0])
# Out:
# Example Domain

# %%
link = tree.xpath('/html/body/div/p[2]/a/@href')
print(link[0])
# Out:
# https://www.iana.org/domains/example

# %%
with open('example.html') as exampleFile:
  content = exampleFile.read()
print(content)
# Out:
# <!-- This is the example.html file. -->
#
# <html><head><title>The Website Title</title></head>
# <body>
# <p>Download my <strong>Python</strong> book from <a href="http://inventwithpython.com">my website</a>.</p>
# <p class="slogan">Learn Python the easy way!</p>
# <p>By <span id="author">Al Sweigart</span></p>
# </body></html>

# %%
# Get an element list
tree = html.fromstring( content )
elems_xp = tree.xpath('//*[@*="author"]')
elems_xp
# Out:
# [<Element span at 0x79e753c7d8f0>]

# %%
# Get one element
elems_xp[0]
# Out:
# <Element span at 0x79e753c7d8f0>

# %%
# Text bounded by the tag
elems_xp[0].text
# Out:
# 'Al Sweigart'

# %%
# Element attributes
elems_xp[0].attrib
# Out:
# {'id': 'author'}

# %%
pElems_xp = tree.xpath('//p')
pElems_xp
# Out:
# [<Element p at 0x79e753c7e1b0>,
#  <Element p at 0x79e753c7e200>,
#  <Element p at 0x79e753c7e250>]

# %%
pElems_xp[0]
# Out:
# <Element p at 0x79e753c7e1b0>

# %%
pElems_xp[0].text
# Out:
# 'Download my '

# %%
pElems_xp[1]
# Out:
# <Element p at 0x79e753c7e200>

# %%
pElems_xp[1].text
# Out:
# 'Learn Python the easy way!'

# %%
pElems_xp[2]
# Out:
# <Element p at 0x79e753c7e250>

# %%
pElems_xp[2].text
# Out:
# 'By '

# %% [markdown]
# ## CSS vs XPATH

# %%
example = '''
<body>
  <p class="phrase">Hello, world!</p>
  <p>By <span id="name">Foo Bar</span></p>
</body></html>
'''
example
# Out:
# '\n<body>\n  <p class="phrase">Hello, world!</p>\n  <p>By <span id="name">Foo Bar</span></p>\n</body></html>\n'

# %%
# Using CSS selectors
import bs4
tree_css = bs4.BeautifulSoup( example, 'html.parser')
elems_css = tree_css.select('#name')
elems_css
# Out:
# [<span id="name">Foo Bar</span>]

# %%
tree_css
# Out:
# <body>
# <p class="phrase">Hello, world!</p>
# <p>By <span id="name">Foo Bar</span></p>
# </body>

# %%
elems_css[0]
# Out:
# <span id="name">Foo Bar</span>

# %%
elems_css[0].text
# Out:
# 'Foo Bar'

# %%
str(elems_css[0])
# Out:
# '<span id="name">Foo Bar</span>'

# %%
# Using XPath
from lxml import html
tree = html.fromstring( example )
elems_xp = tree.xpath('//*[@*="name"]')
elems_xp
# Out:
# [<Element span at 0x79e753c89350>]

# %%
elems_xp[0]
# Out:
# <Element span at 0x79e753c89350>

# %%
# Text bounded by the tag
elems_xp[0].text
# Out:
# 'Foo Bar'

# %%
# Can't seem to get the text of the entire tag
str(elems_xp[0])
# Out:
# '<Element span at 0x79e753c89350>'

# %% [markdown]
# ## HEAD request

# %% [markdown]
# Having fun with HTTP headers:
# - [Fun and unusual HTTP response headers]( https://www.pingdom.com/blog/fun-and-unusual-http-response-headers/ )
#
# Response codes:
# - MDN [HTTP response status codes]( https://developer.mozilla.org/en-US/docs/Web/HTTP/Status )
# - Wikipedia [List of HTTP status codes]( https://en.wikipedia.org/wiki/List_of_HTTP_status_codes )

# %%
# !curl -s -I -XHEAD 'https://jgmsinc.com/'
# Out:
# HTTP/2 301
# age: 69605
# date: Sun, 16 Jun 2024 21:54:20 GMT
# location: https://www.jgmsinc.com/
# server: Squarespace
# set-cookie: crumb=BYC2GVhSG66+NjU5YzJiNTZiMGYyMzYyZDllZGYwN2QyMTJlY2Uy;Secure;Path=/
# strict-transport-security: max-age=15552000
# x-contextid: nS2ORyRj/jD7xUOBO
# content-length: 0

# %%
# !curl -s -I -XHEAD 'https://careers-encantadotech.icims.com/jobs/search?ss=1&searchRelation=keyword_all&searchCategory=8730'
# Out:
# HTTP/2 200
# content-type: text/html;charset=UTF-8
# server: nginx
# date: Mon, 17 Jun 2024 17:15:02 GMT
# p3p: CP="CAO PSA OUR"
# strict-transport-security: max-age=63072000; includeSubDomains
# expires: Sun, 16 Jun 2024 17:15:02 GMT
# cache-control: no-cache, no-store
# pragma: no-cache
# set-cookie: JSESSIONID=6B0C8443A7FA07BD2B6B002BACDF9AA9; Path=/; Secure; HttpOnly; SameSite=Lax
# icims-ats-host: appip-10-47-163-217-prod206
# icims-ats-customer: 12243
# x-icims-tenant: 0x0001
# x-cache: Miss from cloudfront
# via: 1.1 29147f9e38067439b15976c1b4e88fc2.cloudfront.net (CloudFront)
# x-amz-cf-pop: HKG1-P1
# alt-svc: h3=":443"; ma=86400
# x-amz-cf-id: PseBUJRyHF16X4-T0Hk4OIKP7BLBlfLRIx1XWIBCCzvluicXrc-efg==
# server-timing: cdn-upstream-layer;desc="REC",cdn-upstream-dns;dur=5,cdn-upstream-connect;dur=623,cdn-upstream-fbl;dur=843,cdn-cache-miss,cdn-pop;desc="HKG1-P1",cdn-rid;desc="PseBUJRyHF16X4-T0Hk4OIKP7BLBlfLRIx1XWIBCCzvluicXrc-efg==",cdn-downstream-fbl;dur=899

# %%
# !curl -s -L -I -XHEAD 'https://cnmingenuity.org/'
# Out:
# HTTP/2 301
# date: Mon, 17 Jun 2024 17:16:17 GMT
# content-type: text/html; charset=UTF-8
# location: https://www.cnmingenuity.org/
# expires: Mon, 17 Jun 2024 18:14:43 GMT
# x-redirect-by: WordPress
# x-powered-by: WP Engine
# x-cacheable: non200
# cache-control: max-age=600, must-revalidate
# x-cache: HIT: 1
# x-cache-group: normal
# cf-cache-status: DYNAMIC
# server: cloudflare
# cf-ray: 8954afc00cf78410-TPE
# alt-svc: h3=":443"; ma=86400
#
# HTTP/2 200
# date: Mon, 17 Jun 2024 17:16:17 GMT
# content-type: text/html; charset=UTF-8
# vary: Accept-Encoding
# vary: Accept-Encoding
# vary: Accept-Encoding
# vary: Accept-Encoding,Cookie
# link: <https://www.cnmingenuity.org/wp-json/>; rel="https://api.w.org/"
# link: <https://www.cnmingenuity.org/wp-json/wp/v2/pages/2>; rel="alternate"; type="application/json"
# link: <https://www.cnmingenuity.org/>; rel=shortlink
# x-powered-by: WP Engine
# x-cacheable: SHORT
# cache-control: max-age=600, must-revalidate
# x-cache: HIT: 3
# x-cache-group: normal
# cf-cache-status: DYNAMIC
# server: cloudflare
# cf-ray: 8954afc29b1b4a21-TPE
# alt-svc: h3=":443"; ma=86400

# %%
# !curl -I -s https://ddc-datascience.s3.amazonaws.com/Projects/Project.1-Transactions/Data/Transaction.train.csv
# Out:
# HTTP/1.1 200 OK
# x-amz-id-2: TckodZ4QNSmep2PxyevBOJ7vX7aW1CKccasnqoMMhv9fAunrklU2WlJINn24Ef0x3FwAUExzAjA=
# x-amz-request-id: FFH2E2SVXPZJNJDD
# Date: Mon, 17 Jun 2024 17:17:24 GMT
# Last-Modified: Sat, 23 Sep 2023 18:46:31 GMT
# ETag: "97b9422de3eca4f1c4adbd7789fd110c-9"
# x-amz-server-side-encryption: AES256
# Accept-Ranges: bytes
# Content-Type: text/csv
# Server: AmazonS3
# Content-Length: 73445257

# %% [markdown]
# ## robots.txt

# %% [markdown]
# "robots.txt is the filename used for implementing the Robots Exclusion Protocol, a standard used by websites to indicate to visiting web crawlers and other web robots which portions of the website they are allowed to visit."
#
# - Wikipedia [robots.txt]( https://en.wikipedia.org/wiki/Robots.txt )
# - Google docs [Introduction to robots.txt]( https://developers.google.com/search/docs/crawling-indexing/robots/intro )
# - [RFC 9309]( https://www.rfc-editor.org/rfc/rfc9309 )

# %%
# !curl -s 'https://cnmingenuity.org/robots.txt'
# Out:
# User-agent: *
# Disallow: /wp-admin/
# Allow: /wp-admin/admin-ajax.php

# %%
# !curl -s 'https://www.cabq.gov/robots.txt'
# Out:
# Sitemap: https://www.cabq.gov/sitemap.xml.gz
#
# # Define access-restrictions for robots/spiders
# # http://www.robotstxt.org/wc/norobots.html
#
#
#
# # By default we allow robots to access all areas of our site
# # already accessible to anonymous users
#
# User-agent: *
# Disallow:
#
#
#
# # Add Googlebot-specific syntax extension to exclude forms
# # that are repeated for each piece of content in the site
# # the wildcard is only supported by Googlebot
# # http://www.google.com/support/webmasters/bin/answer.py?answer=40367&ctx=sibling
#
# User-Agent: Googlebot
# Disallow: /*?
# Disallow: /*atct_album_view$
# Disallow: /*folder_factories$
# Disallow: /*folder_summary_view$
# Disallow: /*login_form$
# Disallow: /*mail_password_form$
# Disallow: /@@search
# Disallow: /*search_rss$
# Disallow: /*sendto_form$
# Disallow: /*summary_view$
# Disallow: /*thumbnail_view$
# Disallow: /*view$

# %% [markdown]
# ## Sitemaps

# %% [markdown]
# - Wikipedia [sitemaps]( https://en.wikipedia.org/wiki/Sitemaps )

# %%
# !zcat --help
# Out:
# Usage: /usr/bin/zcat [OPTION]... [FILE]...
# Uncompress FILEs to standard output.
#
#   -f, --force       force; read compressed data even from a terminal
#   -l, --list        list compressed file contents
#   -q, --quiet       suppress all warnings
#   -r, --recursive   operate recursively on directories
#   -S, --suffix=SUF  use suffix SUF on compressed files
#       --synchronous synchronous output (safer if system crashes, but slower)
#   -t, --test        test compressed file integrity
#   -v, --verbose     verbose mode
#       --help        display this help and exit
#       --version     display version information and exit
#
# With no FILE, or when FILE is -, read standard input.
#
# Report bugs to <bug-gzip@gnu.org>.

# %%
# !curl -s 'https://www.cabq.gov/sitemap.xml.gz' | zcat
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <sitemapindex xmlns="http://www.sitemaps.org/schemas/sitemap/0.9" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.sitemaps.org/schemas/sitemap/0.9 http://www.sitemaps.org/schemas/sitemap/0.9/sitemap.xsd">
#   <sitemap>
#     <loc>https://www.cabq.gov/sitemap1.xml.gz</loc>
#     <lastmod>2024-06-17T00:30:40-06:00</lastmod>
#   </sitemap>
#   <sitemap>
#     <loc>https://www.cabq.gov/sitemap2.xml.gz</loc>
#     <lastmod>2024-06-17T00:30:40-06:00</lastmod>
#   </sitemap>
# </sitemapindex>

# %%
# !curl -s 'https://www.cabq.gov/sitemap1.xml.gz' | zcat | head -20
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.sitemaps.org/schemas/sitemap/0.9 http://www.sitemaps.org/schemas/sitemap/0.9/sitemap.xsd">
#
#   <url>
#     <loc>https://www.cabq.gov</loc>
#     <lastmod>2024-06-10T15:32:57-06:00</lastmod>
#
#
#   </url>
#   <url>
#     <loc>https://www.cabq.gov/clerk/documents/augut-29-2022-lb-cancellation.pdf</loc>
#     <lastmod>2022-08-23T14:07:05-06:00</lastmod>
#
#
#   </url>
#   <url>
#     <loc>https://www.cabq.gov/cpoa/documents/draft-cpoa-board-minutes-august-11-2022-w-attachments.pdf</loc>
#     <lastmod>2022-09-30T11:18:53-06:00</lastmod>

# %%
# %%bash
# curl -s 'https://www.cabq.gov/sitemap1.xml.gz' |
# zcat |
# fgrep '<loc>' |
# sed -e 's#<loc>##g ; s#</loc>##g' |
# head -3 |
# while read url ; do
#   echo == ${url}
#   curl -s -I ${url}
# done
# Out:
# == https://www.cabq.gov
# HTTP/2 200
# date: Mon, 17 Jun 2024 17:40:25 GMT
# content-type: text/html;charset=utf-8
# content-language: en
# expires: Fri, 20 Jun 2014 15:28:15 GMT
# vary: X-Anonymous
# x-frame-options: SAMEORIGIN
# age: 7929
# x-cache: HIT
# cache-control: max-age=0, s-maxage=0, must-revalidate
# accept-ranges: bytes
# cf-cache-status: DYNAMIC
# server: cloudflare
# cf-ray: 8954d3165cfa85ff-HKG
#
# == https://www.cabq.gov/clerk/documents/augut-29-2022-lb-cancellation.pdf
# HTTP/2 200
# date: Mon, 17 Jun 2024 17:40:25 GMT
# content-type: application/pdf
# content-length: 25337
# expires: Fri, 20 Jun 2014 17:38:15 GMT
# vary: X-Anonymous
# x-frame-options: SAMEORIGIN
# x-cache: HIT
# cache-control: max-age=0, s-maxage=0, must-revalidate
# cf-cache-status: MISS
# last-modified: Mon, 17 Jun 2024 17:40:25 GMT
# accept-ranges: bytes
# server: cloudflare
# cf-ray: 8954d31a89b6048d-HKG
#
# == https://www.cabq.gov/cpoa/documents/draft-cpoa-board-minutes-august-11-2022-w-attachments.pdf
# HTTP/2 200
# date: Mon, 17 Jun 2024 17:40:26 GMT
# content-type: application/pdf
# content-length: 915008
# expires: Fri, 20 Jun 2014 17:38:16 GMT
# vary: X-Anonymous
# x-frame-options: SAMEORIGIN
# x-cache: HIT
# cache-control: max-age=0, s-maxage=0, must-revalidate
# cf-cache-status: MISS
# last-modified: Mon, 17 Jun 2024 17:40:26 GMT
# accept-ranges: bytes
# server: cloudflare
# cf-ray: 8954d31e39f6210b-HKG

# %%
# %%bash
# curl -s 'https://www.cabq.gov/sitemap1.xml.gz' |
# zcat |
# fgrep '<loc>' |
# sed -e 's#<loc>##g ; s#</loc>##g' |
# wc
# Out:
#   40000   40000 3564999

# %%
# %%bash
# curl -s 'https://www.cabq.gov/sitemap2.xml.gz' |
# zcat |
# fgrep '<loc>' |
# sed -e 's#<loc>##g ; s#</loc>##g' |
# wc
# Out:
#   25269   25269 2145025

# %%
# !curl -s https://blog.nimblebox.ai/robots.txt
# Out:
# User-agent: *
# Allow: /
#
# Sitemap: https://blog.nimblebox.ai/sitemap.xml

# %%
# !curl -s -I https://blog.nimblebox.ai/sitemap.xml
# Out:
# HTTP/2 200
# alt-svc: h3=":443"; ma=2592000
# cache-control: public, max-age=0, must-revalidate
# content-type: text/xml
# date: Mon, 17 Jun 2024 18:00:58 GMT
# etag: "f0164362eb3c72570c56da9f9dd343ed"
# last-modified: Mon, 29 Apr 2024 06:25:05 GMT
# server: Framer/22dcab7
# server-timing: region;desc="ap-northeast-2", cache;desc="not-cached", ssg-status;desc="optimized", version;desc="22dcab7"
# strict-transport-security: max-age=31536000
# vary: Accept-Encoding
# content-length: 6847

# %%
# %%bash
# curl -s https://blog.nimblebox.ai/sitemap.xml |
# fgrep '<loc>' |
# sed -e 's#<loc>##g ; s#</loc>##g' |
# while read url ; do
#   echo == ${url}
#   curl -s -I ${url}
# done > nimblebox.txt

# %%
# !cat nimblebox.txt | head -100
# Out:
# == https://blog.nimblebox.ai/mlops-top-python-packages
# HTTP/2 200
# alt-svc: h3=":443"; ma=2592000
# cache-control: public, max-age=0, must-revalidate
# content-type: text/html
# date: Mon, 17 Jun 2024 18:02:36 GMT
# etag: "fc3505c9f389b1d8ba95dc63129046ec"
# last-modified: Mon, 29 Apr 2024 06:25:04 GMT
# link: <https://framerusercontent.com>; rel="preconnect", <https://framerusercontent.com>; rel="preconnect"; crossorigin=""
# server: Framer/22dcab7
# server-timing: region;desc="ap-northeast-2", cache;desc="not-cached", ssg-status;desc="optimized", version;desc="22dcab7"
# strict-transport-security: max-age=31536000
# vary: Accept-Encoding
# content-length: 98329
#
# == https://blog.nimblebox.ai/mlops-the-ultimate-guide
# HTTP/2 200
# alt-svc: h3=":443"; ma=2592000
# cache-control: public, max-age=0, must-revalidate
# content-type: text/html
# date: Mon, 17 Jun 2024 18:02:37 GMT
# etag: "c274d888635ce5eabdeec772c1713aa9"
# last-modified: Mon, 29 Apr 2024 06:25:04 GMT
# link: <https://framerusercontent.com>; rel="preconnect", <https://framerusercontent.com>; rel="preconnect"; crossorigin=""
# server: Framer/22dcab7
# server-timing: region;desc="ap-northeast-2", cache;desc="not-cached", ssg-status;desc="optimized", version;desc="22dcab7"
# strict-transport-security: max-age=31536000
# vary: Accept-Encoding
# content-length: 92739
#
# == https://blog.nimblebox.ai/slack-communities-mlops
# HTTP/2 200
# alt-svc: h3=":443"; ma=2592000
# cache-control: public, max-age=0, must-revalidate
# content-type: text/html
# date: Mon, 17 Jun 2024 18:02:37 GMT
# etag: "d3656c642fe105879ed23019ce23bcc5"
# last-modified: Mon, 29 Apr 2024 06:25:04 GMT
# link: <https://framerusercontent.com>; rel="preconnect", <https://framerusercontent.com>; rel="preconnect"; crossorigin=""
# server: Framer/22dcab7
# server-timing: region;desc="ap-northeast-2", cache;desc="not-cached", ssg-status;desc="optimized", version;desc="22dcab7"
# strict-transport-security: max-age=31536000
# vary: Accept-Encoding
# content-length: 94551
#
# == https://blog.nimblebox.ai/gato-deepmind
# HTTP/2 200
# alt-svc: h3=":443"; ma=2592000
# cache-control: public, max-age=0, must-revalidate
# content-type: text/html
# date: Mon, 17 Jun 2024 18:02:37 GMT
# etag: "3abc23152d0a9322f2fe47a494234b20"
# last-modified: Mon, 29 Apr 2024 06:25:04 GMT
# link: <https://framerusercontent.com>; rel="preconnect", <https://framerusercontent.com>; rel="preconnect"; crossorigin=""
# server: Framer/22dcab7
# server-timing: region;desc="ap-northeast-2", cache;desc="not-cached", ssg-status;desc="optimized", version;desc="22dcab7"
# strict-transport-security: max-age=31536000
# vary: Accept-Encoding
# content-length: 87489
#
# == https://blog.nimblebox.ai/mlops-discord-servers
# HTTP/2 200
# alt-svc: h3=":443"; ma=2592000
# cache-control: public, max-age=0, must-revalidate
# content-type: text/html
# date: Mon, 17 Jun 2024 18:02:38 GMT
# etag: "8b203f179a4b218ea64226c7bcac6bd3"
# last-modified: Mon, 29 Apr 2024 06:25:04 GMT
# link: <https://framerusercontent.com>; rel="preconnect", <https://framerusercontent.com>; rel="preconnect"; crossorigin=""
# server: Framer/22dcab7
# server-timing: region;desc="ap-northeast-2", cache;desc="not-cached", ssg-status;desc="optimized", version;desc="22dcab7"
# strict-transport-security: max-age=31536000
# vary: Accept-Encoding
# content-length: 91323
#
# == https://blog.nimblebox.ai/mlops-team-structure
# HTTP/2 200
# alt-svc: h3=":443"; ma=2592000
# cache-control: public, max-age=0, must-revalidate
# content-type: text/html
# date: Mon, 17 Jun 2024 18:02:38 GMT
# etag: "d812abc79f3c1f5a64b42dc481bba749"
# last-modified: Mon, 29 Apr 2024 06:25:04 GMT
# link: <https://framerusercontent.com>; rel="preconnect", <https://framerusercontent.com>; rel="preconnect"; crossorigin=""
# server: Framer/22dcab7
# server-timing: region;desc="ap-northeast-2", cache;desc="not-cached", ssg-status;desc="optimized", version;desc="22dcab7"
# strict-transport-security: max-age=31536000
# vary: Accept-Encoding
# content-length: 92063
#
# == https://blog.nimblebox.ai/mlops-maintain-scale
# HTTP/2 200
# alt-svc: h3=":443"; ma=2592000
# cache-control: public, max-age=0, must-revalidate
# content-type: text/html
# date: Mon, 17 Jun 2024 18:02:39 GMT
# etag: "90156713b611b26b843bd65211d96d5f"
# last-modified: Mon, 29 Apr 2024 06:25:04 GMT
# link: <https://framerusercontent.com>; rel="preconnect", <https://framerusercontent.com>; rel="preconnect"; crossorigin=""
# server: Framer/22dcab7

# %%
# !grep ^HTTP nimblebox.txt | sort | uniq -c
# Out:
#      77 HTTP/2 200

# %%
# !grep team nimblebox.txt
# Out:
# == https://blog.nimblebox.ai/mlops-team-structure

# %%
# !curl -s -L https://nimblebox.ai/blog/mlops-team-structure | head -200
# Out:
# <!doctype html>
# <!-- ✨ Built with Framer • https://www.framer.com/ -->
# <html lang="en-US">
# <head>
#     <meta charset="utf-8">
#     <script type="importmap">{"imports":{"@emotion/hash":"https://ga.jspm.io/npm:@emotion/hash@0.9.0/dist/emotion-hash.esm.js","@motionone/dom":"https://ga.jspm.io/npm:@motionone/dom@10.12.0/dist/index.es.js","@motionone/easing":"https://ga.jspm.io/npm:@motionone/easing@10.13.1/dist/index.es.js","@motionone/utils":"https://ga.jspm.io/npm:@motionone/utils@10.12.0/dist/index.es.js","@react-three/drei":"https://ga.jspm.io/npm:@react-three/drei@8.3.1/index.js","@react-three/fiber":"https://ga.jspm.io/npm:@react-three/fiber@7.0.24/dist/react-three-fiber.esm.js","airtable":"https://ga.jspm.io/npm:airtable@0.11.1/lib/airtable.js","canvas-confetti":"https://ga.jspm.io/npm:canvas-confetti@1.4.0/src/confetti.js","color-diff":"https://ga.jspm.io/npm:color-diff@1.2.0/lib/index.js","color-hash":"https://ga.jspm.io/npm:color-hash@2.0.1/dist/color-hash.js","framer-motion-3d":"https://ga.jspm.io/npm:framer-motion-3d@6.0.0-beta.8/dist/es/index.mjs","framesync":"https://ga.jspm.io/npm:framesync@6.1.2/dist/es/index.mjs","motion":"https://ga.jspm.io/npm:motion@10.12.0/dist/main.es.js","popmotion":"https://ga.jspm.io/npm:popmotion@11.0.3/dist/es/index.mjs","react-confetti":"https://ga.jspm.io/npm:react-confetti@6.0.1/dist/react-confetti.min.js","shopify-buy":"https://ga.jspm.io/npm:shopify-buy@2.14.0/index.js","style-value-types":"https://ga.jspm.io/npm:style-value-types@5.1.0/dist/es/index.mjs","three":"https://ga.jspm.io/npm:three@0.136.0/build/three.module.js","tinycolor2":"https://ga.jspm.io/npm:tinycolor2@1.4.2/tinycolor.js","valtio":"https://ga.jspm.io/npm:valtio@1.2.9/esm/index.js","zustand":"https://ga.jspm.io/npm:zustand@3.7.1/esm/index.js","zustand/middleware":"https://ga.jspm.io/npm:zustand@3.7.1/esm/middleware.js","react-tsparticles":"https://ga.jspm.io/npm:react-tsparticles@2.9.3/esm/index.js","tsparticles":"https://ga.jspm.io/npm:tsparticles@2.9.3/esm/index.js","react-spring":"https://ga.jspm.io/npm:react-spring@9.6.1/dist/react-spring.esm.js","@codesandbox/sandpack-react":"https://ga.jspm.io/npm:@codesandbox/sandpack-react@1.3.1/dist/esm/index.js","@vimeo/player":"https://ga.jspm.io/npm:@vimeo/player@2.16.4/dist/player.es.js","arc-text":"https://ga.jspm.io/npm:arc-text@1.0.1/dist/arc-text.umd.js","browser-jsonp":"https://ga.jspm.io/npm:browser-jsonp@1.1.5/lib/jsonp.js","easing-coordinates":"https://ga.jspm.io/npm:easing-coordinates@2.0.2/dist/cjs/index.js","fetch-jsonp":"https://ga.jspm.io/npm:fetch-jsonp@1.2.1/build/fetch-jsonp.js","figma-squircle":"https://ga.jspm.io/npm:figma-squircle@0.3.0/dist/module.js","firebase/app":"https://ga.jspm.io/npm:firebase@9.17.1/app/dist/esm/index.esm.js","firebase/auth":"https://ga.jspm.io/npm:firebase@9.12.1/auth/dist/index.esm.js","firebase/firestore":"https://ga.jspm.io/npm:firebase@9.12.1/firestore/dist/index.esm.js","highlight.js":"https://ga.jspm.io/npm:highlight.js@11.5.0/es/index.js","highlight.js/lib/common":"https://ga.jspm.io/npm:highlight.js@11.5.0/es/common.js","hsluv":"https://ga.jspm.io/npm:hsluv@1.0.0/dist/esm/hsluv.js","jsonp":"https://ga.jspm.io/npm:jsonp@0.2.1/index.js","prismjs":"https://ga.jspm.io/npm:prismjs@1.29.0/prism.js","prismjs/components/prism-jsx":"https://ga.jspm.io/npm:prismjs@1.29.0/components/prism-jsx.js","prismjs/components/prism-tsx":"https://ga.jspm.io/npm:prismjs@1.29.0/components/prism-tsx.js","react-helmet":"https://ga.jspm.io/npm:react-helmet@6.1.0/lib/Helmet.js","react-hook-form":"https://ga.jspm.io/npm:react-hook-form@7.39.5/dist/index.esm.mjs","react-parallax-tilt":"https://ga.jspm.io/npm:react-parallax-tilt@1.7.92/dist/index.esm.js","react-svg":"https://ga.jspm.io/npm:react-svg@15.1.9/dist/react-svg.esm.js","react-tooltip":"https://ga.jspm.io/npm:react-tooltip@4.4.3/dist/index.es.js","@faker-js/faker":"https://ga.jspm.io/npm:@faker-js/faker@7.6.0/dist/esm/index.mjs","@popmotion/popcorn":"https://ga.jspm.io/npm:@popmotion/popcorn@0.4.4/lib/index.js","@rainbow-me/rainbowkit":"https://ga.jspm.io/npm:@rainbow-me/rainbowkit@0.4.5/dist/index.js","@rainbow-me ...
#     <script async src="https://ga.jspm.io/npm:es-module-shims@1.6.3/dist/es-module-shims.js" crossorigin="anonymous" data-framer-es-module-shims></script>
#     <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-W9GNZ9PF');</script>
# <!-- End Google Tag Manager -->
# <style>
#     li>p.framer-text{
#         margin-bottom: 8px;
#     }
#     ol.framer-text, ul.framer-text{
#         padding-top: 12px !important;
#     }
# </style>
#     <!-- End of headStart -->
#     <meta name="viewport" content="width=device-width">
#     <meta name="generator" content="Framer 3fa6aa4">
#     <title>Tune AI | Enterprise Gen AI Stack</title>
#     <meta name="description" content="Enterprises and individuals use Tune AI to fine-tune and deploy LLMs and to chat with open-source models." />
#     <meta name="framer-search-index" content="indexing">
#     <meta name="framer-html-plugin" content="disable">
#     <link rel="icon" href="https://framerusercontent.com/images/YTt1nFKcEsYBlIiZqA85gtvTrGw.png">
#     <!-- Open Graph / Facebook -->
#     <meta property="og:type" content="website">
#     <meta property="og:title" content="Tune AI | Enterprise Gen AI Stack">
#     <meta property="og:description" content="Enterprises and individuals use Tune AI to fine-tune and deploy LLMs and to chat with open-source models.">
#     <meta property="og:image" content="https://framerusercontent.com/images/G9lg6LvfjTlQntQ6hx1L87ftm8.png">
#     <!-- Twitter -->
#     <meta name="twitter:card" content="summary_large_image">
#     <meta name="twitter:title" content="Tune AI | Enterprise Gen AI Stack">
#     <meta name="twitter:description" content="Enterprises and individuals use Tune AI to fine-tune and deploy LLMs and to chat with open-source models.">
#     <meta name="twitter:image" content="https://framerusercontent.com/images/G9lg6LvfjTlQntQ6hx1L87ftm8.png">
#
#     <!-- Global site tag (gtag.js) - Google Analytics -->
#     <script async src="https://www.googletagmanager.com/gtag/js?id=G-EN6NJLMZ17"></script>
#     <script>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){window.dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-EN6NJLMZ17');
#     </script>
#     <style data-framer-css-ssr>
#         html, body, #main {
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         }
#         :root {
#             -webkit-font-smoothing: antialiased;
#             -moz-osx-font-smoothing: grayscale;
#         }
#         * {
#             box-sizing: border-box;
#             -webkit-font-smoothing: inherit;
#         }
#         h1, h2, h3, h4, h5, h6, p, figure {
#             margin: 0;
#         }
#         body, input, textarea, select, button { font-size: 12px; font-family: sans-serif; }
#         body { --token-62384f20-bb9d-4eef-9216-9660fa5aa172: rgb(18, 18, 18);--token-2edcd068-dd4a-43a0-8803-2a845ecf65e0: rgb(84, 86, 89);--token-1bccc6bb-1355-4dfb-bb11-868d204257a8: rgb(166, 166, 168);--token-84c3a504-3a3e-4424-94e1-dc354cd46e7f: rgb(110, 24, 251);--token-f3582f8e-8ac1-4a6b-8e9c-37ac97fb870d: rgb(127, 102, 255);--token-cc6a8bee-ee31-4142-abc7-2b7bec875e1c: rgb(255, 255, 255);--token-b64d3765-3a65-40dd-93e7-65689179b53e: rgb(218, 206, 255);--token-b1448873-0032-4c9f-9ee0-24e9bdcc33bc: rgb(255, 255, 255);--token-02f0b911-5e2b-429b-8c14-3c2f91a3250c: rgb(110, 24, 251);--token-99527e02-0c0e-4470-a6d1-1a46950a638b: rgb(206, 194, 255);--token-e008f491-b1d3-4bd4-9c12-2eab298a656f: rgb(224, 216, 255);--token-38e03e70-a000-4d8a-97a8-a2e911608915: rgb(255, 106, 31);--token-99ed6293-ef0e-4e86-81c5-a29b2eb362ca: rgb(254, 255, 217);--token-a1c03989-13b3-4d89-834d-62d5a9ceaa72: rgb(127, 102, 255);--token-e8a49cab-6ecb-44c6-8b8a-4e3e8f22e4fb: rgb(206, 194, 255); }
# @media (prefers-color-scheme: dark) { body {  } }
#
#         /* cyrillic-ext */
# @font-face {
#   font-family: 'Fragment Mono';
#   font-style: normal;
#   font-weight: 400;
#   font-display: block;
#   src: url(https://fonts.gstatic.com/s/fragmentmono/v4/4iCr6K5wfMRRjxp0DA6-2CLnB45HhrUI.woff2) format('woff2');
#   unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
# }
# /* latin-ext */
# @font-face {
#   font-family: 'Fragment Mono';
#   font-style: normal;
#   font-weight: 400;
#   font-display: block;
#   src: url(https://fonts.gstatic.com/s/fragmentmono/v4/4iCr6K5wfMRRjxp0DA6-2CLnB41HhrUI.woff2) format('woff2');
#   unicode-range: U+0100-02AF, U+0304, U+0308, U+0329, U+1E00-1E9F, U+1EF2-1EFF, U+2020, U+20A0-20AB, U+20AD-20C0, U+2113, U+2C60-2C7F, U+A720-A7FF;
# }
# /* latin */
# @font-face {
#   font-family: 'Fragment Mono';
#   font-style: normal;
#   font-weight: 400;
#   font-display: block;
#   src: url(https://fonts.gstatic.com/s/fragmentmono/v4/4iCr6K5wfMRRjxp0DA6-2CLnB4NHhg.woff2) format('woff2');
#   unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+0304, U+0308, U+0329, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
# }
# /* cyrillic-ext */
# @font-face {
#   font-family: 'Roboto Mono';
#   font-style: normal;
#   font-weight: 400;
#   font-display: block;
#   src: url(https://fonts.gstatic.com/s/robotomono/v23/L0xuDF4xlVMF-BfR8bXMIhJHg45mwgGEFl0_3vq_SeW4Ep0.woff2) format('woff2');
#   unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;
# }
# /* cyrillic */
# @font-face {
#   font-family: 'Roboto Mono';
#   font-style: normal;
#   font-weight: 400;
#   font-display: block;
#   src: url(https://fonts.gstatic.com/s/robotomono/v23/L0xuDF4xlVMF-BfR8bXMIhJHg45mwgGEFl0_3vq_QOW4Ep0.woff2) format('woff2');
#   unicode-range: U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;
# }
# /* greek */
# @font-face {
#   font-family: 'Roboto Mono';
#   font-style: normal;
#   font-weight: 400;
#   font-display: block;
#   src: url(https://fonts.gstatic.com/s/robotomono/v23/L0xuDF4xlVMF-BfR8bXMIhJHg45mwgGEFl0_3vq_R-W4Ep0.woff2) format('woff2');
#   unicode-range: U+0370-0377, U+037A-037F, U+0384-038A, U+038C, U+038E-03A1, U+03A3-03FF;
# }
# /* vietnamese */
# @font-face {
#   font-family: 'Roboto Mono';
#   font-style: normal;
#   font-weight: 400;
#   font-display: block;
#   src: url(https://fonts.gstatic.com/s/robotomono/v23/L0xuDF4xlVMF-BfR8bXMIhJHg45mwgGEFl0_3vq_S-W4Ep0.woff2) format('woff2');
#   unicode-range: U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+0300-0301, U+0303-0304, U+0308-0309, U+0323, U+0329, U+1EA0-1EF9, U+20AB;
# }
# /* latin-ext */
# @font-face {
#   font-family: 'Roboto Mono';
#   font-style: normal;
#   font-weight: 400;
#   font-display: block;
#   src: url(https://fonts.gstatic.com/s/robotomono/v23/L0xuDF4xlVMF-BfR8bXMIhJHg45mwgGEFl0_3vq_SuW4Ep0.woff2) format('woff2');
#   unicode-range: U+0100-02AF, U+0304, U+0308, U+0329, U+1E00-1E9F, U+1EF2-1EFF, U+2020, U+20A0-20AB, U+20AD-20C0, U+2113, U+2C60-2C7F, U+A720-A7FF;
# }
# /* latin */
# @font-face {
#   font-family: 'Roboto Mono';
#   font-style: normal;
#   font-weight: 400;
#   font-display: block;
#   src: url(https://fonts.gstatic.com/s/robotomono/v23/L0xuDF4xlVMF-BfR8bXMIhJHg45mwgGEFl0_3vq_ROW4.woff2) format('woff2');
#   unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+0304, U+0308, U+0329, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
# }
#
# @font-face { font-family: "BR Hendrix Regular"; src: url("https://framerusercontent.com/assets/bKOTxbUOFMDRBo022CByInbiqIg.woff2"); font-display: swap }
# @font-face { font-family: "BR Hendrix SemiBold"; src: url("https://framerusercontent.com/assets/sACELSkW0qhZ8tU4nCmxXFULwBg.woff2"); font-display: swap }
# @font-face { font-family: "BR Hendrix Medium"; src: url("https://framerusercontent.com/assets/ZfjU3CXKujdW58xzQSYLHnpi0E.woff2"); font-display: swap }
# @font-face { font-family: "BR Hendrix Bold"; src: url("https://framerusercontent.com/assets/nDOLahoEypPbHbqPf7FZoIfq1xs.woff2"); font-display: swap }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Regular.cyrillic-ext-CFTLRB35.woff2"); font-display: swap; font-style: normal; font-weight: 400; unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Regular.cyrillic-KKLZBALH.woff2"); font-display: swap; font-style: normal; font-weight: 400; unicode-range: U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116 }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Regular.greek-ext-ULEBLIFV.woff2"); font-display: swap; font-style: normal; font-weight: 400; unicode-range: U+1F00-1FFF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Regular.greek-IRHSNFQB.woff2"); font-display: swap; font-style: normal; font-weight: 400; unicode-range: U+0370-03FF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Regular.latin-ext-VZDUGU3Q.woff2"); font-display: swap; font-style: normal; font-weight: 400; unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Regular.latin-JLQMKCHE.woff2"); font-display: swap; font-style: normal; font-weight: 400; unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Regular.vietnamese-QK7VSWXK.woff2"); font-display: swap; font-style: normal; font-weight: 400; unicode-range: U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+1EA0-1EF9, U+20AB }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Thin.cyrillic-ext-BHDA65O4.woff2"); font-display: block; font-style: normal; font-weight: 100; unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Thin.cyrillic-Q5IXHU2O.woff2"); font-display: block; font-style: normal; font-weight: 100; unicode-range: U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116 }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Thin.greek-ext-VVOQA2NE.woff2"); font-display: block; font-style: normal; font-weight: 100; unicode-range: U+1F00-1FFF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Thin.greek-E3WNEUH6.woff2"); font-display: block; font-style: normal; font-weight: 100; unicode-range: U+0370-03FF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Thin.latin-ext-5RC4NRHN.woff2"); font-display: block; font-style: normal; font-weight: 100; unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Thin.latin-GJ7CRGHG.woff2"); font-display: block; font-style: normal; font-weight: 100; unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Thin.vietnamese-Z3Y7DPWO.woff2"); font-display: block; font-style: normal; font-weight: 100; unicode-range: U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+1EA0-1EF9, U+20AB }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-ExtraLight.cyrillic-ext-7NWKXNAT.woff2"); font-display: block; font-style: normal; font-weight: 200; unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-ExtraLight.cyrillic-IBWUD6RJ.woff2"); font-display: block; font-style: normal; font-weight: 200; unicode-range: U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116 }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-ExtraLight.greek-ext-HUMDTRBU.woff2"); font-display: block; font-style: normal; font-weight: 200; unicode-range: U+1F00-1FFF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-ExtraLight.greek-ZLLHEEN3.woff2"); font-display: block; font-style: normal; font-weight: 200; unicode-range: U+0370-03FF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-ExtraLight.latin-ext-72JE5FGU.woff2"); font-display: block; font-style: normal; font-weight: 200; unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-ExtraLight.latin-2JHDAFAQ.woff2"); font-display: block; font-style: normal; font-weight: 200; unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-ExtraLight.vietnamese-VKRCA4VC.woff2"); font-display: block; font-style: normal; font-weight: 200; unicode-range: U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+1EA0-1EF9, U+20AB }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Light.cyrillic-ext-G3OTPKE4.woff2"); font-display: swap; font-style: normal; font-weight: 300; unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Light.cyrillic-JO7ZJTP6.woff2"); font-display: swap; font-style: normal; font-weight: 300; unicode-range: U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116 }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Light.greek-ext-N63XCCK3.woff2"); font-display: swap; font-style: normal; font-weight: 300; unicode-range: U+1F00-1FFF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Light.greek-5GVUXSXZ.woff2"); font-display: swap; font-style: normal; font-weight: 300; unicode-range: U+0370-03FF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Light.latin-ext-RREJIMQ3.woff2"); font-display: swap; font-style: normal; font-weight: 300; unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Light.latin-EKF76FXR.woff2"); font-display: swap; font-style: normal; font-weight: 300; unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Light.vietnamese-GVC2UOFS.woff2"); font-display: swap; font-style: normal; font-weight: 300; unicode-range: U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+1EA0-1EF9, U+20AB }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Medium.cyrillic-ext-M4WHNGTS.woff2"); font-display: swap; font-style: normal; font-weight: 500; unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Medium.cyrillic-JVU2PANX.woff2"); font-display: swap; font-style: normal; font-weight: 500; unicode-range: U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116 }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Medium.greek-ext-4KCQBEIZ.woff2"); font-display: swap; font-style: normal; font-weight: 500; unicode-range: U+1F00-1FFF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Medium.greek-DPOQGN7L.woff2"); font-display: swap; font-style: normal; font-weight: 500; unicode-range: U+0370-03FF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Medium.latin-ext-J4DBSW7F.woff2"); font-display: swap; font-style: normal; font-weight: 500; unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Medium.latin-Y3IVPL46.woff2"); font-display: swap; font-style: normal; font-weight: 500; unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Medium.vietnamese-PJV76O4P.woff2"); font-display: swap; font-style: normal; font-weight: 500; unicode-range: U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+1EA0-1EF9, U+20AB }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-SemiBold.cyrillic-ext-C7KWUKA7.woff2"); font-display: swap; font-style: normal; font-weight: 600; unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-SemiBold.cyrillic-JWV7SOZ6.woff2"); font-display: swap; font-style: normal; font-weight: 600; unicode-range: U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116 }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-SemiBold.greek-ext-FBKSFTSU.woff2"); font-display: swap; font-style: normal; font-weight: 600; unicode-range: U+1F00-1FFF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-SemiBold.greek-EQ3PSENU.woff2"); font-display: swap; font-style: normal; font-weight: 600; unicode-range: U+0370-03FF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-SemiBold.latin-ext-ULRSO3ZR.woff2"); font-display: swap; font-style: normal; font-weight: 600; unicode-range: U+0100-024F, U+0259, U+1E00-1EFF, U+2020, U+20A0-20AB, U+20AD-20CF, U+2113, U+2C60-2C7F, U+A720-A7FF }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-SemiBold.latin-RDYY2AG2.woff2"); font-display: swap; font-style: normal; font-weight: 600; unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-SemiBold.vietnamese-ESQNSEQ3.woff2"); font-display: swap; font-style: normal; font-weight: 600; unicode-range: U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+1EA0-1EF9, U+20AB }
# @font-face { font-family: "Inter"; src: url("https://app.framerstatic.com/Inter-Bold.cyrillic-ext-XOTVL7ZR.woff2"); font-display: swap; font-style: normal; font-weight: 700; unicode-range: U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F }
