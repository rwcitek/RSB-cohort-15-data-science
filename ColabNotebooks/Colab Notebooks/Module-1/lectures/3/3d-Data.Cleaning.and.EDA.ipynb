# %% [markdown]
# # Example 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the Data

# %%
url = "http://ddc-datascience.s3-website-us-west-1.amazonaws.com/winequality-red.csv"
wine_data = pd.read_csv(url)

# %%
wine_data.shape
# Out:
# (1599, 12)

# %% [markdown]
# ## Understand the Data

# %%
# Look at the first five rows
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978   NaN       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# Get info about each column
wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1598 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1598 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wine_data.isnull().sum()*100
# Out:
# fixed acidity             0
# volatile acidity          0
# citric acid               0
# residual sugar          100
# chlorides                 0
# free sulfur dioxide       0
# total sulfur dioxide      0
# density                   0
# pH                      100
# sulphates                 0
# alcohol                   0
# quality                   0
# dtype: int64

# %% [markdown]
# Notice that there is one null vlaue for pH and residual sugar.

# %%
# Get summary statistics about each column
wine_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1598.000000
# mean        8.319637          0.527821     0.333196        2.539393
# std         1.741096          0.179060     2.501598        1.410174
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000   100.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1598.000000  1599.000000  1599.000000  1599.000000
# mean      3.310989     0.658149    10.422983     5.636023
# std       0.154355     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
type(wine_data.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
wine_data.describe().transpose()
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.333196   2.501598  0.00000   0.0900
# residual sugar        1598.0   2.539393   1.410174  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1598.0   3.310989   0.154355  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# fixed acidity          7.90000   9.200000   15.90000
# volatile acidity       0.52000   0.640000    1.58000
# citric acid            0.26000   0.420000  100.00000
# residual sugar         2.20000   2.600000   15.50000
# chlorides              0.07900   0.090000    0.61100
# free sulfur dioxide   14.00000  21.000000   72.00000
# total sulfur dioxide  38.00000  62.000000  289.00000
# density                0.99675   0.997835    1.00369
# pH                     3.31000   3.400000    4.01000
# sulphates              0.62000   0.730000    2.00000
# alcohol               10.20000  11.100000   14.90000
# quality                6.00000   6.000000    8.00000

# %%
# See the unique values in the quality column
wine_data['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
# See how many observations there are for each unique value in the quality column
wine_data['quality'].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %% [markdown]
# ## Clean the Data

# %% [markdown]
# We saw above that there are two columns that have nulls/NAs. Let's drop the rows that have NAs.

# %%
# Before doing any cleaning, let's make a copy of our data frame
wine_clean = wine_data.copy()

# %%
# Drop the rows with NAs
wine_clean.dropna(inplace = True)

# %%
# Alternate, doing both steps in one
# wine_clean = wine_data.dropna()

# %%
# Verify they NAs were dropped
wine_clean.isnull().sum()*10
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Let's say we don't want to include the density or sulphate columns in our data, so we will drop them.

# %%
# Drop the density and sulphate column
wine_clean.drop(columns = ['density', 'sulphates'], inplace = True)

# %%
# Verify it was dropped
wine_clean.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'pH',
#        'alcohol', 'quality'],
#       dtype='object')

# %%
wine_clean.isnull().sum()*10
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# pH                      0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Finally, residual sugar is currently in g but I want it in mg. So I am going to multiply each value in the residual sugar column by 1000.

# %%
wine_clean['residual sugar'].head()
# Out:
# 0    1.9
# 1    2.6
# 2    2.3
# 3    1.9
# 5    1.8
# Name: residual sugar, dtype: float64

# %%
# Multiply each value by 1000
wine_clean['residual sugar'] = wine_clean['residual sugar']*1000

# %%
# Confirm it worked
wine_clean['residual sugar'].head()
# Out:
# 0    1900.0
# 1    2600.0
# 2    2300.0
# 3    1900.0
# 5    1800.0
# Name: residual sugar, dtype: float64

# %% [markdown]
# ## Generate Summary Statistics

# %%
# Get summary statistics for each column
wine_clean.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1597.000000       1597.000000  1597.000000     1597.000000
# mean        8.320539          0.527661     0.333431     2539.793363
# std         1.741986          0.179108     2.503151     1410.524492
# min         4.600000          0.120000     0.000000      900.000000
# 25%         7.100000          0.390000     0.090000     1900.000000
# 50%         7.900000          0.520000     0.260000     2200.000000
# 75%         9.200000          0.640000     0.420000     2600.000000
# max        15.900000          1.580000   100.000000    15500.000000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide           pH  \
# count  1597.000000          1597.000000           1597.000000  1597.000000
# mean      0.087457            15.882279             46.486537     3.311021
# std       0.047089            10.464580             32.911540     0.154398
# min       0.012000             1.000000              6.000000     2.740000
# 25%       0.070000             7.000000             22.000000     3.210000
# 50%       0.079000            14.000000             38.000000     3.310000
# 75%       0.090000            21.000000             62.000000     3.400000
# max       0.611000            72.000000            289.000000     4.010000
#
#            alcohol      quality
# count  1597.000000  1597.000000
# mean     10.424452     5.636819
# std       1.065512     0.807761
# min       8.400000     3.000000
# 25%       9.500000     5.000000
# 50%      10.200000     6.000000
# 75%      11.100000     6.000000
# max      14.900000     8.000000

# %%
wine_clean.describe().transpose()
# Out:
#                        count         mean          std      min      25%  \
# fixed acidity         1597.0     8.320539     1.741986    4.600     7.10
# volatile acidity      1597.0     0.527661     0.179108    0.120     0.39
# citric acid           1597.0     0.333431     2.503151    0.000     0.09
# residual sugar        1597.0  2539.793363  1410.524492  900.000  1900.00
# chlorides             1597.0     0.087457     0.047089    0.012     0.07
# free sulfur dioxide   1597.0    15.882279    10.464580    1.000     7.00
# total sulfur dioxide  1597.0    46.486537    32.911540    6.000    22.00
# pH                    1597.0     3.311021     0.154398    2.740     3.21
# alcohol               1597.0    10.424452     1.065512    8.400     9.50
# quality               1597.0     5.636819     0.807761    3.000     5.00
#
#                            50%      75%        max
# fixed acidity            7.900     9.20     15.900
# volatile acidity         0.520     0.64      1.580
# citric acid              0.260     0.42    100.000
# residual sugar        2200.000  2600.00  15500.000
# chlorides                0.079     0.09      0.611
# free sulfur dioxide     14.000    21.00     72.000
# total sulfur dioxide    38.000    62.00    289.000
# pH                       3.310     3.40      4.010
# alcohol                 10.200    11.10     14.900
# quality                  6.000     6.00      8.000

# %%
# Calculate the mean of a single column
wine_clean['alcohol'].mean()
# Out:
# 10.424452097683155

# %% [markdown]
# ## Plot the data (univariate)

# %%
wine_clean['alcohol'].hist()
plt.xlabel('% Alcohol')
plt.ylabel('Count') ;

# %%
wine_clean['alcohol'].hist(bins = 100)
plt.xlabel('% Alcohol')
plt.ylabel('Count') ;

# %%
sns.histplot(x = wine_clean['alcohol'], kde = True) ;

# %%
wine_clean.boxplot(column = 'citric acid') ;

# %% [markdown]
# What's going on here? It looks like there might be a large outlier. Let's take a look.

# %%
# Find the outlier
ca_max = wine_clean['citric acid'].max()
ca_max
# Out:
# 100.0

# %%
filter = ( wine_clean['citric acid'] == ca_max )
filter
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 5       False
#         ...
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598    False
# Name: citric acid, Length: 1597, dtype: bool

# %%
wine_clean[filter]
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 19            7.9              0.32        100.0          1800.0      0.341
#
#     free sulfur dioxide  total sulfur dioxide    pH  alcohol  quality
# 19                 17.0                  56.0  3.04      9.2        6

# %%
# Look at other rows to get a feel for "normal"
wine_clean.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00          1900.0      0.076
# 1            7.8              0.88         0.00          2600.0      0.098
# 2            7.8              0.76         0.04          2300.0      0.092
# 3           11.2              0.28         0.56          1900.0      0.075
# 5            7.4              0.66         0.00          1800.0      0.075
#
#    free sulfur dioxide  total sulfur dioxide    pH  alcohol  quality
# 0                 11.0                  34.0  3.51      9.4        5
# 1                 25.0                  67.0  3.20      9.8        5
# 2                 15.0                  54.0  3.26      9.8        5
# 3                 17.0                  60.0  3.16      9.8        6
# 5                 13.0                  40.0  3.51      9.4        5

# %% [markdown]
# The citric acid in this row is 100. All the other citric acid values are much smaller. We talked to the person who put together this dataset and they confirmed this is a mistake. Let's replace this value with the mean citric acid value.

# %% [markdown]
# ## Impute outlier

# %%
wine_clean_drop = wine_clean.copy()
wine_clean_drop.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00          1900.0      0.076
# 1            7.8              0.88         0.00          2600.0      0.098
# 2            7.8              0.76         0.04          2300.0      0.092
# 3           11.2              0.28         0.56          1900.0      0.075
# 5            7.4              0.66         0.00          1800.0      0.075
#
#    free sulfur dioxide  total sulfur dioxide    pH  alcohol  quality
# 0                 11.0                  34.0  3.51      9.4        5
# 1                 25.0                  67.0  3.20      9.8        5
# 2                 15.0                  54.0  3.26      9.8        5
# 3                 17.0                  60.0  3.16      9.8        6
# 5                 13.0                  40.0  3.51      9.4        5

# %%
wine_clean_drop[filter][['citric acid']]
# Out:
#     citric acid
# 19        100.0

# %%
# Calculate mean, std with outlier
( wine_clean_drop['citric acid'].mean(), wine_clean_drop['citric acid'].std() )
# Out:
# (0.33343143393863495, 2.5031506457316564)

# %%
# Change max value to NaN
wine_clean_drop.loc[filter, 'citric acid'] = np.NaN
wine_clean_drop[filter][['citric acid']]
# Out:
#     citric acid
# 19          NaN

# %%
# Calculate the mean, std of citric acid
ca_mean, _ = wine_clean_drop['citric acid'].mean(), wine_clean_drop['citric acid'].std()
ca_mean, _
# Out:
# (0.27098370927318294, 0.19477364979913453)

# %%
# Replace null with mean
wine_clean_drop.loc[filter, 'citric acid'] = ca_mean
wine_clean_drop[filter][['citric acid']]
# Out:
#     citric acid
# 19     0.270984

# %%
# Calculate mean, std with imputed value
( wine_clean_drop['citric acid'].mean(), wine_clean_drop['citric acid'].std(), )
# Out:
# (0.270983709273183, 0.1947126209241289)

# %%
sns.histplot( x=wine_clean_drop["citric acid"]) ;

# %% [markdown]
# ## Plot the data (bivariate)

# %%
# Correlation Plot
column_correlations = wine_clean_drop.corr()
#column_correlations
plt.figure(figsize=(12,10))
sns.heatmap(column_correlations, annot=True, cmap='RdYlGn') ;

# %%
# Get most highly correlated varliables with alcohol
alc_correlations = wine_clean_drop.corr()['alcohol']
alc_correlations
# Out:
# fixed acidity          -0.062273
# volatile acidity       -0.201580
# citric acid             0.110229
# residual sugar          0.041325
# chlorides              -0.221045
# free sulfur dioxide    -0.070268
# total sulfur dioxide   -0.206482
# pH                      0.206424
# alcohol                 1.000000
# quality                 0.475632
# Name: alcohol, dtype: float64

# %%
correlated_vars = abs(alc_correlations).sort_values(ascending=False)
correlated_vars
# Out:
# alcohol                 1.000000
# quality                 0.475632
# chlorides               0.221045
# total sulfur dioxide    0.206482
# pH                      0.206424
# volatile acidity        0.201580
# citric acid             0.110229
# free sulfur dioxide     0.070268
# fixed acidity           0.062273
# residual sugar          0.041325
# Name: alcohol, dtype: float64

# %%
# Scatter plot
wine_clean_drop.plot(x='fixed acidity', y='pH', kind='scatter',  title='pH vs Fixed Acidity') ;

# %%
# Scatter plot with different colors based on quality
sns.scatterplot(
    x = wine_clean_drop['alcohol'],
    y = wine_clean_drop['pH'],
    hue = wine_clean_drop['quality'],
    size=wine_clean_drop['quality']
) ;

# %%
# Pairplot
sns.pairplot(wine_clean_drop) ;

# %%
wine_clean_drop.hist() ;
