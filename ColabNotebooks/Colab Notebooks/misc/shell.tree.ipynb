# %%
# %%capture
# %%bash
apt-get update
apt-get install -y tree jq

# %% [markdown]
# ## Under the Files pane on the left, click on the "Mount drive" icon

# %%
# cd drive/MyDrive/Cohorts/Cohort.15.shared/Students/
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Cohorts/Cohort.15.shared/Students/'
# /content

# %%
# !tree ddds.cohort-15.Robert/
# Out:
# ddds.cohort-15.Robert/  [error opening dir]
#
# 0 directories, 0 files

# %%
# !cat /etc/os-release
# Out:
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %%
# !ls /MyDrive
# Out:
# ls: cannot access '/MyDrive': No such file or directory

# %%
# !tree
# Out:
# Streaming output truncated to the last 5000 lines.
# │   │   │   │   ├── ns
# │   │   │   │   │   ├── cgroup -> cgroup:[4026532552]
# │   │   │   │   │   ├── ipc -> ipc:[4026532488]
# │   │   │   │   │   ├── mnt -> mnt:[4026532486]
# │   │   │   │   │   ├── net -> net:[4026532490]
# │   │   │   │   │   ├── pid -> pid:[4026532489]
# │   │   │   │   │   ├── pid_for_children -> pid:[4026532489]
# │   │   │   │   │   ├── time -> time:[4026531834]
# │   │   │   │   │   ├── time_for_children -> time:[4026531834]
# │   │   │   │   │   ├── user -> user:[4026531837]
# │   │   │   │   │   └── uts -> uts:[4026532487]
# │   │   │   │   ├── numa_maps
# │   │   │   │   ├── oom_adj
# │   │   │   │   ├── oom_score
# │   │   │   │   ├── oom_score_adj
# │   │   │   │   ├── pagemap
# │   │   │   │   ├── personality
# │   │   │   │   ├── projid_map
# │   │   │   │   ├── root -> /
# │   │   │   │   ├── schedstat
# │   │   │   │   ├── sessionid
# │   │   │   │   ├── setgroups
# │   │   │   │   ├── smaps
# ...
