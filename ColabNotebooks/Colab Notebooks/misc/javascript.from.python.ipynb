# %%
import json

# %%
text = '''
  Wil: https://github.com/Wilkingc/ddc-datascience/blob/main/Project_1_Transaction_Analysis.ipynb
  Sam: https://github.com/samula98/proj1/blob/main/SundaySadday_Project_1.ipynb
  James: https://github.com/quasarfunk/datascience15/blob/main/Project_1_Transaction_Analysis.ipynb
  Mohamed: https://github.com/melhamdani/-Stamp-Prices/blob/main/Project_1_To_Do_List.ipynb
  Minerva: https://github.com/mincfranc/DD_DataScience/blob/main/Project_1_.ipynb
  Robert: https://github.com/RSBalchII/project-1-transaction-data/blob/main/project_1_transaction_prediction.ipynb
  Mel: https://github.com/DrMelissaFranklin/DrMelissaFranklin/blob/main/Mel_Project_1.ipynb
  Joe: https://github.com/jrobak94/Data_Science/blob/main/Project_1.ipynb
  Anna: https://github.com/RioAccountant/Project_1/blob/main/Project1_Work_in_Progress.ipynb
  Zack: https://github.com/ZacharyFry1/DD-Science-Cohort15/blob/main/Project_1.ipynb
'''
text
# Out:
# '\n  Wil: https://github.com/Wilkingc/ddc-datascience/blob/main/Project_1_Transaction_Analysis.ipynb\n  Sam: https://github.com/samula98/proj1/blob/main/SundaySadday_Project_1.ipynb\n  James: https://github.com/quasarfunk/datascience15/blob/main/Project_1_Transaction_Analysis.ipynb\n  Mohamed: https://github.com/melhamdani/-Stamp-Prices/blob/main/Project_1_To_Do_List.ipynb\n  Minerva: https://github.com/mincfranc/DD_DataScience/blob/main/Project_1_.ipynb\n  Robert: https://github.com/RSBalchII/project-1-transaction-data/blob/main/project_1_transaction_prediction.ipynb\n  Mel: https://github.com/DrMelissaFranklin/DrMelissaFranklin/blob/main/Mel_Project_1.ipynb\n  Joe: https://github.com/jrobak94/Data_Science/blob/main/Project_1.ipynb\n  Anna: https://github.com/RioAccountant/Project_1/blob/main/Project1_Work_in_Progress.ipynb\n  Zack: https://github.com/ZacharyFry1/DD-Science-Cohort15/blob/main/Project_1.ipynb\n'

# %%
print(text)
# Out:
#   Wil: https://github.com/Wilkingc/ddc-datascience/blob/main/Project_1_Transaction_Analysis.ipynb
#   Sam: https://github.com/samula98/proj1/blob/main/SundaySadday_Project_1.ipynb
#   James: https://github.com/quasarfunk/datascience15/blob/main/Project_1_Transaction_Analysis.ipynb
#   Mohamed: https://github.com/melhamdani/-Stamp-Prices/blob/main/Project_1_To_Do_List.ipynb
#   Minerva: https://github.com/mincfranc/DD_DataScience/blob/main/Project_1_.ipynb
#   Robert: https://github.com/RSBalchII/project-1-transaction-data/blob/main/project_1_transaction_prediction.ipynb
#   Mel: https://github.com/DrMelissaFranklin/DrMelissaFranklin/blob/main/Mel_Project_1.ipynb
#   Joe: https://github.com/jrobak94/Data_Science/blob/main/Project_1.ipynb
#   Anna: https://github.com/RioAccountant/Project_1/blob/main/Project1_Work_in_Progress.ipynb
#   Zack: https://github.com/ZacharyFry1/DD-Science-Cohort15/blob/main/Project_1.ipynb

# %%
text_dict = {
  k.strip(): v.strip()
    for x in text.split("\n")
      if x
        for k,v in [x.split(": ")]
}
text_dict
# Out:
# {'Wil': 'https://github.com/Wilkingc/ddc-datascience/blob/main/Project_1_Transaction_Analysis.ipynb',
#  'Sam': 'https://github.com/samula98/proj1/blob/main/SundaySadday_Project_1.ipynb',
#  'James': 'https://github.com/quasarfunk/datascience15/blob/main/Project_1_Transaction_Analysis.ipynb',
#  'Mohamed': 'https://github.com/melhamdani/-Stamp-Prices/blob/main/Project_1_To_Do_List.ipynb',
#  'Minerva': 'https://github.com/mincfranc/DD_DataScience/blob/main/Project_1_.ipynb',
#  'Robert': 'https://github.com/RSBalchII/project-1-transaction-data/blob/main/project_1_transaction_prediction.ipynb',
#  'Mel': 'https://github.com/DrMelissaFranklin/DrMelissaFranklin/blob/main/Mel_Project_1.ipynb',
#  'Joe': 'https://github.com/jrobak94/Data_Science/blob/main/Project_1.ipynb',
#  'Anna': 'https://github.com/RioAccountant/Project_1/blob/main/Project1_Work_in_Progress.ipynb',
#  'Zack': 'https://github.com/ZacharyFry1/DD-Science-Cohort15/blob/main/Project_1.ipynb'}

# %%
text_json = json.dumps(text_dict, indent=2)
print(text_json)
# Out:
# {
#   "Wil": "https://github.com/Wilkingc/ddc-datascience/blob/main/Project_1_Transaction_Analysis.ipynb",
#   "Sam": "https://github.com/samula98/proj1/blob/main/SundaySadday_Project_1.ipynb",
#   "James": "https://github.com/quasarfunk/datascience15/blob/main/Project_1_Transaction_Analysis.ipynb",
#   "Mohamed": "https://github.com/melhamdani/-Stamp-Prices/blob/main/Project_1_To_Do_List.ipynb",
#   "Minerva": "https://github.com/mincfranc/DD_DataScience/blob/main/Project_1_.ipynb",
#   "Robert": "https://github.com/RSBalchII/project-1-transaction-data/blob/main/project_1_transaction_prediction.ipynb",
#   "Mel": "https://github.com/DrMelissaFranklin/DrMelissaFranklin/blob/main/Mel_Project_1.ipynb",
#   "Joe": "https://github.com/jrobak94/Data_Science/blob/main/Project_1.ipynb",
#   "Anna": "https://github.com/RioAccountant/Project_1/blob/main/Project1_Work_in_Progress.ipynb",
#   "Zack": "https://github.com/ZacharyFry1/DD-Science-Cohort15/blob/main/Project_1.ipynb"
# }

# %%
print(f'''
const urlMap = {text_json} ;

// Get the first three URLs
const urls = Object.values(urlMap);

// Open each URL in a new tab
urls.forEach(url => window.open(url, '_blank'));

''')
# Out:
# const urlMap = {
#   "Wil": "https://github.com/Wilkingc/ddc-datascience/blob/main/Project_1_Transaction_Analysis.ipynb",
#   "Sam": "https://github.com/samula98/proj1/blob/main/SundaySadday_Project_1.ipynb",
#   "James": "https://github.com/quasarfunk/datascience15/blob/main/Project_1_Transaction_Analysis.ipynb",
#   "Mohamed": "https://github.com/melhamdani/-Stamp-Prices/blob/main/Project_1_To_Do_List.ipynb",
#   "Minerva": "https://github.com/mincfranc/DD_DataScience/blob/main/Project_1_.ipynb",
#   "Robert": "https://github.com/RSBalchII/project-1-transaction-data/blob/main/project_1_transaction_prediction.ipynb",
#   "Mel": "https://github.com/DrMelissaFranklin/DrMelissaFranklin/blob/main/Mel_Project_1.ipynb",
#   "Joe": "https://github.com/jrobak94/Data_Science/blob/main/Project_1.ipynb",
#   "Anna": "https://github.com/RioAccountant/Project_1/blob/main/Project1_Work_in_Progress.ipynb",
#   "Zack": "https://github.com/ZacharyFry1/DD-Science-Cohort15/blob/main/Project_1.ipynb"
# ...
