# %% [markdown]
# # Documentation and resources

# %% [markdown]
# **Big Query**
# - Colab has an example notebook on BigQuery too.  File > Open notebook > Examples > Getting Started with BigQuery.
# - Also a Big Query Snippets Example Notebook
# - [BigQuery Documentation]( https://cloud.google.com/bigquery/docs )
# - [Open Data Sets]( https://console.cloud.google.com/marketplace/browse?filter=solution-type:dataset )
# - [Reddit - list of data sets available on BQ]( https://www.reddit.com/r/bigquery/wiki/datasets )
#
#
# **Big Query Console**
# - [Google Cloud Console]( https://console.cloud.google.com )
# - Make sure your project is selected
# - Scroll down to BigQuery on the left menu
# - [Setup and query instructions]( https://cloud.google.com/bigquery/docs/quickstarts/query-public-dataset-console )
#
# **SQL**
# - [Kaggle Intro to SQL]( https://www.kaggle.com/learn/intro-to-sql ) uses BigQuery
# - [Kaggle Advanced SQL]( https://www.kaggle.com/learn/advanced-sql )

# %% [markdown]
# #  Linking BigQuery to Colab

# %% [markdown]
# ## Getting started

# %% [markdown]
# **You will only need to do this part once.**
#
# 1. Use the [Cloud Resource Manager](https://console.cloud.google.com/cloud-resource-manager) to Create a Cloud Platform project if you do not already have one.
#
#     - Create Project
#     - Project Name
#     - Location
#
# 2. [Enable BigQuery APIs](https://console.cloud.google.com/flows/enableapi?apiid=bigquery) for the project
#
# **Note:** You get 1 TB/month of free queries for open datasets
# - Kaggle gives you 5 TB/month free

# %% [markdown]
# ## Imports

# %%
# pandas module
import pandas as pd
import pandas_gbq

# gcp modules
from google.cloud import bigquery

# colab modules
from google.colab import auth
from google.colab import syntax
from google.colab import userdata

# %% [markdown]
# ### Provide your credentials

# %%
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %% [markdown]
# ## Optional: Enable data table display
#
# Colab includes the ``google.colab.data_table`` package that can be used to display large pandas dataframes as an interactive data table.
# It can be enabled with:

# %%
# %load_ext google.colab.data_table
# %unload_ext google.colab.data_table
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table

# %% [markdown]
# If you would prefer to return to the classic Pandas dataframe display, you can disable this by running:
# ```python
# %unload_ext google.colab.data_table
# ```

# %% [markdown]
# ## List projects

# %% [markdown]
# In order to query BigQuery, you will need to specify a project ID.  To get a list of project IDs associated with your account, run the following command.

# %%
# %alias gcloud gcloud

# %%
gcloud projects list --sort-by=projectId
# Out:
# PROJECT_ID                     NAME                    PROJECT_NUMBER
# data-science-project-3-439515  Data-Science-project-3  428650296072

# %% [markdown]
# ## Declare the Cloud project ID which will be used throughout this notebook
#
# To set up secret open keys tab on colab and provide projectid as the value and name your key to use your project from google colab

# %%
project_id = userdata.get('proj-3')

# %%
project_id
# Out:
# 'data-science-project-3-439515'

# %% [markdown]
# ## Samples data set

# %% [markdown]
# The [GSOD table](https://console.cloud.google.com/bigquery?p=bigquery-public-data&d=samples&t=gsod&page=table) in the Samples data set contains weather information collected by NOAA, such as precipitation amounts and wind speeds from late 1929 to early 2010.

# %% [markdown]
# # Use BigQuery via magics

# %% [markdown]
# The `google.cloud.bigquery` library also includes a magic command which runs a query and either displays the result or saves it to a variable as a `DataFrame`.

# %%
# Display query output immediately

# %%bigquery --project {project_id}
SELECT
  COUNT(1) as total_rows
FROM `bigquery-public-data.samples.gsod`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    total_rows
# 0   114420316

# %%
# Save output in a variable `df`

# %%bigquery df --project {project_id}
SELECT
  COUNT(1) as total_rows
FROM `bigquery-public-data.samples.gsod`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df
# Out:
#    total_rows
# 0   114420316

# %%
f'{df.iloc[0,0]:_}'
# Out:
# '114_420_316'

# %% [markdown]
# # Use BigQuery through google-cloud-bigquery

# %% [markdown]
# See [BigQuery documentation](https://cloud.google.com/bigquery/docs) and [library reference documentation](https://googlecloudplatform.github.io/google-cloud-python/latest/bigquery/usage.html).

# %% [markdown]
# ## Sample approximately 2000 random rows

# %% [markdown]
# ### Count total number of rows

# %%
client = bigquery.Client(project=project_id)

row_count = client.query('''
  SELECT
    COUNT(1) as total
  FROM `bigquery-public-data.samples.gsod`
  '''
).to_dataframe()["total"][0]

print(f'Full dataset has {row_count:_} rows')
# Out:
# Full dataset has 114_420_316 rows

# %% [markdown]
# ### Describe the sampled data

# %%
sample_count = 2000
df = client.query(f'''
  SELECT
    *
  FROM
    `bigquery-public-data.samples.gsod`
  WHERE RAND() < {sample_count}/{row_count}
''').to_dataframe()

# %%
df.describe().transpose().astype({"count": int})
# Out:
#                                     count           mean            std  \
# station_number                       2063  493971.275812  300800.537625
# wban_number                          2063   90966.826951   25571.378349
# year                                 2063    1986.759089      16.065688
# month                                2063       6.591372       3.452218
# day                                  2063      15.836646       8.838346
# mean_temp                            2063      52.128163      23.609143
# num_mean_temp_samples                2063      12.807077       7.843004
# mean_dew_point                       1972      41.618966      21.993648
# num_mean_dew_point_samples           1972      12.704361       7.827563
# mean_sealevel_pressure               1561    1015.109993       9.535269
# num_mean_sealevel_pressure_samples   1561      11.296605       7.506223
# mean_station_pressure                 750     967.539068      68.134389
# num_mean_station_pressure_samples     750         12.184       7.850455
# mean_visibility                      1867      12.084199       9.130739
# num_mean_visibility_samples          1867      12.467595       7.742949
# mean_wind_speed                      2043       6.750514       4.778353
# num_mean_wind_speed_samples          2043      12.746941       7.820156
# max_sustained_wind_speed             2009      12.083474       6.622787
# max_gust_wind_speed                   283      23.739223       8.655256
# max_temperature                      2063      43.717014      23.457806
# min_temperature                         0            NaN            NaN
# total_precipitation                  1865       0.064343       0.293204
# snow_depth                            107      11.614953      13.484098
#
#                                            min          25%         50%  \
# station_number                         10014.0     230370.0    489200.0
# wban_number                               13.0      99999.0     99999.0
# year                                    1933.0       1977.0      1989.0
# month                                      1.0          4.0         7.0
# day                                        1.0          8.0        16.0
# mean_temp                           -54.900002         38.5   54.900002
# num_mean_temp_samples                      4.0          7.0         8.0
# mean_dew_point                      -59.599998    29.700001   44.200001
# num_mean_dew_point_samples                 4.0          7.0         8.0
# mean_sealevel_pressure              951.700012  1009.799988      1015.0
# num_mean_sealevel_pressure_samples         4.0          6.0         8.0
# mean_station_pressure               632.799988   953.400009  993.700012
# num_mean_station_pressure_samples          4.0         6.25         8.0
# mean_visibility                            0.0         6.45         9.6
# num_mean_visibility_samples                4.0          6.0         8.0
# mean_wind_speed                            0.0          3.5         5.8
# num_mean_wind_speed_samples                4.0          7.0         8.0
# max_sustained_wind_speed                   1.0          7.8        11.1
# max_gust_wind_speed                        8.9         18.0        22.0
# max_temperature                     -63.400002    31.799999   46.400002
# min_temperature                            NaN          NaN         NaN
# total_precipitation                        0.0          0.0         0.0
# snow_depth                                 0.4          3.1         7.9
#
#                                             75%          max
# station_number                         724602.5     999999.0
# wban_number                             99999.0      99999.0
# year                                     2000.0       2010.0
# month                                      10.0         12.0
# day                                        23.0         31.0
# mean_temp                             69.900002   100.900002
# num_mean_temp_samples                      23.0         24.0
# mean_dew_point                        56.624999    80.599998
# num_mean_dew_point_samples                 23.0         24.0
# mean_sealevel_pressure              1020.599976  1059.199951
# num_mean_sealevel_pressure_samples         20.0         24.0
# mean_station_pressure               1009.375015       1038.0
# num_mean_station_pressure_samples          23.0         24.0
# mean_visibility                            14.9    99.400002
# num_mean_visibility_samples                23.0         24.0
# mean_wind_speed                             8.9    42.400002
# num_mean_wind_speed_samples                23.0         24.0
# max_sustained_wind_speed                   15.0         54.0
# max_gust_wind_speed                        28.0    62.900002
# max_temperature                       60.799999    87.800003
# min_temperature                             NaN          NaN
# total_precipitation                         0.0         6.97
# snow_depth                                 14.2         94.5

# %% [markdown]
# ### View the first 10 rows

# %%
df.head(10)
# Out:
# Warning: Total number of columns (31) exceeds max_columns (20). Falling back to pandas display.
#    station_number  wban_number  year  month  day  mean_temp  \
# 0          725660        24028  1943      5   21  56.200001
# 1           63800        99999  1949     10    5  57.400002
# 2          719250        99999  1950      1    8 -23.299999
# 3          203570        99999  1951     10   19  26.500000
# 4          276480        99999  1952      1    7  15.000000
# 5          999999        34066  1961     11    1  47.099998
# 6          943800        99999  1965     11    8  79.000000
# 7          161700        99999  1967     10   31  52.400002
# 8          727575        94925  1967     10   28  23.600000
# 9          336640        99999  1977      7    9  68.599998
#
#    num_mean_temp_samples  mean_dew_point  num_mean_dew_point_samples  \
# 0                     24       44.400002                          24
# 1                      8       51.400002                           8
# 2                      8      -29.400000                           8
# 3                      4       18.500000                           4
# 4                      4        8.500000                           4
# 5                     13       41.599998                          13
# 6                      7       71.099998                           7
# 7                      7       48.700001                           7
# 8                     24       14.400000                          24
# 9                      6       61.400002                           6
#
#    mean_sealevel_pressure  ...  min_temperature  min_temperature_explicit  \
# 0             1017.900024  ...              NaN                      <NA>
# 1                     NaN  ...              NaN                      <NA>
# 2             1002.000000  ...              NaN                      <NA>
# 3              993.099976  ...              NaN                      <NA>
# 4             1026.300049  ...              NaN                      <NA>
# 5             1030.199951  ...              NaN                      <NA>
# 6                     NaN  ...              NaN                      <NA>
# 7             1012.900024  ...              NaN                      <NA>
# 8             1013.099976  ...              NaN                      <NA>
# 9             1006.799988  ...              NaN                      <NA>
#
#    total_precipitation  snow_depth    fog   rain   snow   hail  thunder  \
# 0                  NaN         NaN  False  False  False  False    False
# 1                 0.00         NaN  False  False  False  False    False
# 2                  NaN         NaN  False  False  False  False    False
# 3                 0.02         NaN  False  False  False  False    False
# 4                 0.12         NaN   True   True   True   True     True
# 5                 0.00         NaN   True   True   True   True     True
# 6                 0.00         NaN  False  False  False  False    False
# 7                 0.31         NaN  False  False  False  False    False
# 8                  NaN         NaN  False  False  False  False    False
# 9                 0.04         NaN  False  False  False  False    False
#
#    tornado
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
#
# [10 rows x 31 columns]

# %%
df.shape
# Out:
# (2063, 31)

# %%
df.isnull().sum()
# Out:
# station_number                           0
# wban_number                              0
# year                                     0
# month                                    0
# day                                      0
# mean_temp                                0
# num_mean_temp_samples                    0
# mean_dew_point                          91
# num_mean_dew_point_samples              91
# mean_sealevel_pressure                 502
# num_mean_sealevel_pressure_samples     502
# mean_station_pressure                 1313
# num_mean_station_pressure_samples     1313
# mean_visibility                        196
# num_mean_visibility_samples            196
# mean_wind_speed                         20
# num_mean_wind_speed_samples             20
# max_sustained_wind_speed                54
# max_gust_wind_speed                   1780
# max_temperature                          0
# max_temperature_explicit                 0
# min_temperature                       2063
# min_temperature_explicit              2063
# total_precipitation                    198
# snow_depth                            1956
# fog                                      0
# rain                                     0
# snow                                     0
# hail                                     0
# thunder                                  0
# tornado                                  0
# dtype: int64

# %%
# 10 highest total_precipitation samples
(
df
  .sort_values('total_precipitation', ascending=False)
  .head(10)
  [['station_number', 'year', 'month', 'day', 'total_precipitation']]
)
# Out:
#       station_number  year  month  day  total_precipitation
# 1084          984260  1990      9    7                 6.97
# 1859          983280  1978      7   27                 5.51
# 611           474300  1993     11   14                 2.64
# 269           725109  2006      9   15                 2.56
# 326           914130  1990      6   24                 2.18
# 1787          913340  1981      1    4                 2.05
# 1639          723405  1998      2   11                 2.01
# 172           854170  1974     12   30                 2.01
# 2033          785010  1988     10   31                 1.97
# 1580          636120  1977     11    3                 1.73

# %% [markdown]
# # Use BigQuery through pandas-gbq

# %% [markdown]
# The `pandas-gbq` library is a community led project by the pandas community. It covers basic functionality, such as writing a DataFrame to BigQuery and running a query, but as a third-party library it may not handle all BigQuery features or use cases.
#
# [Pandas GBQ Documentation]( https://pandas-gbq.readthedocs.io/en/latest/reading.html )

# %%
df = pandas_gbq.read_gbq('''
  SELECT
    name, SUM(number) as count
  FROM
    bigquery-public-data.usa_names.usa_1910_2013
  WHERE
    state = 'TX'
  GROUP BY
    name
  ORDER BY
    count DESC
  LIMIT
    100
  ''', project_id=project_id, dialect='standard'
)

df.head()
# Out:
# Downloading: 100%|██████████|
#       name   count
# 0    James  272793
# 1     John  235139
# 2  Michael  225320
# 3   Robert  220399
# 4    David  219028

# %% [markdown]
# # Syntax highlighting
# `google.colab.syntax` can be used to add syntax highlighting to any Python string literals which are used in a query later.

# %%
query = syntax.sql('''
  SELECT
    COUNT(1) as total_rows
  FROM
    `bigquery-public-data.samples.gsod`
''')

pandas_gbq.read_gbq(query, project_id=project_id, dialect='standard')
# Out:
# Downloading: 100%|██████████|
#    total_rows
# 0   114420316

# %%
type(query)
# Out:
# str
