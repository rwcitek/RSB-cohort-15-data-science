# %% [markdown]
# # Practicing SQL Queries Using BigQuery
#
# We will be looking at the "covid19_google_mobility" dataset located [here](https://console.cloud.google.com/bigquery?p=bigquery-public-data&d=covid19_open_data&page=dataset&project=cool-monolith-286222&ws=!1m4!1m3!3m2!1sbigquery-public-data!2scovid19_open_data).

# %% [markdown]
# ## Setup

# %%
from google.cloud import bigquery
from google.colab import auth
import pandas as pd
import plotly.express as px
from google.colab import userdata

auth.authenticate_user()

# %%
# assign the project ID for BILLING purposes, i.e. who is going to pay for the query?
project_id = userdata.get('bq_billing_project_id')

# %%
# project_id

# %%
# Create client object
client = bigquery.Client(project=project_id)

# %% [markdown]
# ## Initial Exploration

# %% [markdown]
# ### List the data sets

# %% [markdown]
# https://cloud.google.com/bigquery/docs/listing-datasets#python_1

# %%
# assign the project ID that OWNS the data set
owner_project_id = "bigquery-public-data"

datasets = list(client.list_datasets(project=owner_project_id))  # Make an API request.

len(datasets)
# Out:
# 337

# %%
if datasets:
  print(f"Datasets in project {owner_project_id}:")
  print("\n".join( f"\t{d.dataset_id}" for d in datasets[:10] ) )
else:
  print(f"{owner_project_id} project does not contain any datasets.")
# Out:
# Datasets in project bigquery-public-data:
# 	america_health_rankings
# 	austin_311
# 	austin_bikeshare
# 	austin_crime
# 	austin_incidents
# 	austin_waste
# 	baseball
# 	bbc_news
# 	bigqueryml_ncaa
# 	bitcoin_blockchain

# %% [markdown]
# ### Data set properties
#
# https://cloud.google.com/bigquery/docs/listing-datasets#get_information_about_datasets

# %% [markdown]
# #### Friendly name

# %%
for dataset in datasets[:10]:
  full_dataset_id = f"{dataset.project}.{dataset.dataset_id}"
  friendly_name = dataset.friendly_name
  print(
    f"Got dataset '{full_dataset_id}' with friendly_name '{friendly_name}'."
  )
# Out:
# Got dataset 'bigquery-public-data.america_health_rankings' with friendly_name 'None'.
# Got dataset 'bigquery-public-data.austin_311' with friendly_name 'None'.
# Got dataset 'bigquery-public-data.austin_bikeshare' with friendly_name 'None'.
# Got dataset 'bigquery-public-data.austin_crime' with friendly_name 'None'.
# Got dataset 'bigquery-public-data.austin_incidents' with friendly_name 'None'.
# Got dataset 'bigquery-public-data.austin_waste' with friendly_name 'None'.
# Got dataset 'bigquery-public-data.baseball' with friendly_name 'None'.
# Got dataset 'bigquery-public-data.bbc_news' with friendly_name 'None'.
# Got dataset 'bigquery-public-data.bigqueryml_ncaa' with friendly_name 'None'.
# Got dataset 'bigquery-public-data.bitcoin_blockchain' with friendly_name 'None'.

# %% [markdown]
# #### Description

# %%
import textwrap
for dataset in datasets[:10]:
  print("==> " + dataset.full_dataset_id)
  fdi = f"{dataset.project}.{dataset.dataset_id}"
  dataset = client.get_dataset(fdi)
  desc = f"Description: {dataset.description}".split("\n")
  desc = "\n".join( [ f"\t{t}" for l in desc for t in textwrap.fill(l, 100).split("\n") ] )
  print(f"{desc if desc else 'None'}")
  print()
# Out:
# ==> bigquery-public-data:america_health_rankings
# 	Description: America Health Rankings
#
# ==> bigquery-public-data:austin_311
# 	Description: None
#
# ==> bigquery-public-data:austin_bikeshare
# 	Description: Austin Bikeshare dataset
#
# ==> bigquery-public-data:austin_crime
# 	Description: Austin Crime dataset
#
# ==> bigquery-public-data:austin_incidents
# 	Description: None
#
# ==> bigquery-public-data:austin_waste
# 	Description: austin waste and diversion
#
# ==> bigquery-public-data:baseball
# 	Description: Overview: This public data includes pitch-by-pitch data for Major League Baseball (MLB)
# 	games in 2016. This dataset contains the following tables: games_wide (every pitch, steal, or lineup
# 	event for each at bat in the 2016 regular season), games_post_wide(every pitch, steal, or lineup
# 	event for each at-bat in the 2016 post season), and schedules ( the schedule for every team in the
# 	regular season). The schemas for the games_wide and games_post_wide tables are identical. With this
# 	data you can effectively replay a game and rebuild basic statistics for players and teams.
#
# 	Update frequency: Historic (none)
#
# 	Dataset source: SportRadar
#
# 	Terms of use: Copyright Sportradar LLC. Access to data is intended solely for internal research and
# 	testing purposes, and is not to be used for any business or commercial purpose. Data are not to be
# 	exploited in any manner without express approval from Sportradar. Display of data must include the
# 	phrase, “Data provided by Sportradar LLC,” and be hyperlinked to www.sportradar.com
#
# 	See the GCP Marketplace listing for more details and sample queries:
# 	https://console.cloud.google.com/marketplace/details/sportradar-public-data/mlb-pitch-by-pitch
#
# ==> bigquery-public-data:bbc_news
# 	Description: None
#
# ==> bigquery-public-data:bigqueryml_ncaa
# 	Description: None
#
# ==> bigquery-public-data:bitcoin_blockchain
# 	Description: ****NOTE: This dataset has been migrated to `bigquery-public-data.crypto_bitcoin`.
# 	Updates to the data are being sent to the new version of this dataset, whose schema is better
# 	aligned with our other cryptocurrency offerings.
#
# 	This version of the data is no longer being updated and will be removed within the next 15 days.

# %% [markdown]
# ### Show labels

# %%
for dataset in datasets[:10]:
  print("==> " + dataset.full_dataset_id)
  fdi = f"{dataset.project}.{dataset.dataset_id}"
  labels = client.get_dataset(fdi).labels
  if labels:
    print("Labels:")
    print( "\n".join( f"\t{k}: {v}" for k, v in labels.items() ) )
  print()
# Out:
# ==> bigquery-public-data:america_health_rankings
#
# ==> bigquery-public-data:austin_311
#
# ==> bigquery-public-data:austin_bikeshare
#
# ==> bigquery-public-data:austin_crime
#
# ==> bigquery-public-data:austin_incidents
#
# ==> bigquery-public-data:austin_waste
#
# ==> bigquery-public-data:baseball
#
# ==> bigquery-public-data:bbc_news
#
# ==> bigquery-public-data:bigqueryml_ncaa
#
# ==> bigquery-public-data:bitcoin_blockchain

# %% [markdown]
# ### List the tables

# %% [markdown]
# #### Version 1

# %%
for dataset in datasets[:10]:
  print("==> " + dataset.full_dataset_id)
  # list tables
  print( "\n".join( "\t" + t.table_id \
                   for t in list(client.list_tables(dataset)) ))
# Out:
# ==> bigquery-public-data:america_health_rankings
# 	ahr
# 	america_health_rankings
# ==> bigquery-public-data:austin_311
# 	311_service_requests
# ==> bigquery-public-data:austin_bikeshare
# 	bikeshare_stations
# 	bikeshare_trips
# ==> bigquery-public-data:austin_crime
# 	crime
# ==> bigquery-public-data:austin_incidents
# 	incidents_2008
# 	incidents_2009
# 	incidents_2010
# 	incidents_2011
# 	incidents_2016
# ==> bigquery-public-data:austin_waste
# 	waste_and_diversion
# ==> bigquery-public-data:baseball
# 	games_post_wide
# 	games_wide
# 	schedules
# ==> bigquery-public-data:bbc_news
# 	fulltext
# ==> bigquery-public-data:bigqueryml_ncaa
# 	cume_games_view
# ==> bigquery-public-data:bitcoin_blockchain
# 	blocks
# 	transactions

# %% [markdown]
# #### Version 2

# %%
# assign the project ID that OWNS the data set
owner_project_id = "bigquery-public-data"

# Construct a reference to the "covid19_google_mobility" dataset
project_dataset = "covid19_google_mobility"
# project_dataset = "bitcoin_blockchain"

dataset_ref = client.dataset(project_dataset, project=owner_project_id)

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# Get all the tables in the dataset
tables = list(client.list_tables(dataset))

# Print names of all tables in the dataset
for table in tables:
  print(table.table_id)
# Out:
# mobility_report

# %% [markdown]
# ### Look at the table schema

# %%
# Construct a reference to the "mobility report" table
table_ref = dataset.table("mobility_report")

# API request - fetch the table
table = client.get_table(table_ref)

# See the table's schema - name, field type, mode, description
table.schema
# Out:
# [SchemaField('country_region_code', 'STRING', 'NULLABLE', None, '2 letter alpha code for the country/region in which changes are measured relative to the baseline. These values correspond with the ISO 3166-1 alpha-2 codes', (), None),
#  SchemaField('country_region', 'STRING', 'NULLABLE', None, 'The country/region in which changes are measured relative to the baseline', (), None),
#  SchemaField('sub_region_1', 'STRING', 'NULLABLE', None, 'First geographic sub-region in which the data is aggregated. This varies by country/region to ensure privacy and public health value in consultation with local public health authorities', (), None),
#  SchemaField('sub_region_2', 'STRING', 'NULLABLE', None, 'Second geographic sub-region in which the data is aggregated. This varies by country/region to ensure privacy and public health value in consultation with local public health authorities', (), None),
#  SchemaField('metro_area', 'STRING', 'NULLABLE', None, 'A specific metro area to measure mobility within a given city/metro area. This varies by country/region to ensure privacy and public health value in consultation with local public health authorities', (), None),
#  SchemaField('iso_3166_2_code', 'STRING', 'NULLABLE', None, 'Unique identifier for the geographic region as defined by ISO Standard 3166-2.', (), None),
#  SchemaField('census_fips_code', 'STRING', 'NULLABLE', None, 'Unique identifier for each US county as defined by the US Census Bureau. Maps to county_fips_code in other tables', (), None),
#  SchemaField('place_id', 'STRING', 'NULLABLE', None, 'A textual identifier that uniquely identifies a place in the Google Places database and on Google Maps (details). For example ChIJd_Y0eVIvkIARuQyDN0F1LBA. For details see the following link: https://developers.google.com/places/web-service/place-id', (), None),
#  SchemaField('date', 'DATE', 'NULLABLE', None, 'Changes for a given date as compared to baseline. Baseline is the median value for the corresponding day of the week during the 5-week period Jan 3–Feb 6 2020.', (), None),
#  SchemaField('retail_and_recreation_percent_change_from_baseline', 'INTEGER', 'NULLABLE', None, 'Mobility trends for places like restaurants cafes shopping centers theme parks museums libraries and movie theaters.', (), None),
#  SchemaField('grocery_and_pharmacy_percent_change_from_baseline', 'INTEGER', 'NULLABLE', None, 'Mobility trends for places like grocery markets food warehouses farmers markets specialty food shops drug stores and pharmacies.', (), None),
#  SchemaField('parks_percent_change_from_baseline', 'INTEGER', 'NULLABLE', None, 'Mobility trends for places like local parks national parks public beaches marinas dog parks plazas and public gardens.', (), None),
#  SchemaField('transit_stations_percent_change_from_baseline', 'INTEGER', 'NULLABLE', None, 'Mobility trends for places like public transport hubs such as subway bus and train stations.', (), None),
#  SchemaField('workplaces_percent_change_from_baseline', 'INTEGER', 'NULLABLE', None, 'Mobility trends for places of work.', (), None),
#  SchemaField('residential_percent_change_from_baseline', 'INTEGER', 'NULLABLE', None, 'Mobility trends for places of residence.', (), None),
#  SchemaField('source_url', 'STRING', 'NULLABLE', None, 'Source ', (), None),
#  SchemaField('etl_timestamp', 'TIMESTAMP', 'NULLABLE', None, 'Load time for this data row', (), None)]

# %% [markdown]
# #### Schema in a dataframe

# %%
fields = pd.DataFrame( [ x.to_api_repr() for x in table.schema ] )
fields.shape
# Out:
# (17, 4)

# %%
x = table.schema[0]
x.to_api_repr()
# Out:
# {'name': 'country_region_code',
#  'type': 'STRING',
#  'mode': 'NULLABLE',
#  'description': '2 letter alpha code for the country/region in which changes are measured relative to the baseline. These values correspond with the ISO 3166-1 alpha-2 codes'}

# %%
[ x.to_api_repr() for x in table.schema ][:3]
# Out:
# [{'name': 'country_region_code',
#   'type': 'STRING',
#   'mode': 'NULLABLE',
#   'description': '2 letter alpha code for the country/region in which changes are measured relative to the baseline. These values correspond with the ISO 3166-1 alpha-2 codes'},
#  {'name': 'country_region',
#   'type': 'STRING',
#   'mode': 'NULLABLE',
#   'description': 'The country/region in which changes are measured relative to the baseline'},
#  {'name': 'sub_region_1',
#   'type': 'STRING',
#   'mode': 'NULLABLE',
#   'description': 'First geographic sub-region in which the data is aggregated. This varies by country/region to ensure privacy and public health value in consultation with local public health authorities'}]

# %%
fields
# Out:
#                                                  name       type      mode  \
# 0                                 country_region_code     STRING  NULLABLE
# 1                                      country_region     STRING  NULLABLE
# 2                                        sub_region_1     STRING  NULLABLE
# 3                                        sub_region_2     STRING  NULLABLE
# 4                                          metro_area     STRING  NULLABLE
# 5                                     iso_3166_2_code     STRING  NULLABLE
# 6                                    census_fips_code     STRING  NULLABLE
# 7                                            place_id     STRING  NULLABLE
# 8                                                date       DATE  NULLABLE
# 9   retail_and_recreation_percent_change_from_base...    INTEGER  NULLABLE
# 10  grocery_and_pharmacy_percent_change_from_baseline    INTEGER  NULLABLE
# 11                 parks_percent_change_from_baseline    INTEGER  NULLABLE
# 12      transit_stations_percent_change_from_baseline    INTEGER  NULLABLE
# 13            workplaces_percent_change_from_baseline    INTEGER  NULLABLE
# 14           residential_percent_change_from_baseline    INTEGER  NULLABLE
# 15                                         source_url     STRING  NULLABLE
# 16                                      etl_timestamp  TIMESTAMP  NULLABLE
#
#                                           description
# 0   2 letter alpha code for the country/region in ...
# 1   The country/region in which changes are measur...
# 2   First geographic sub-region in which the data ...
# 3   Second geographic sub-region in which the data...
# 4   A specific metro area to measure mobility with...
# 5   Unique identifier for the geographic region as...
# 6   Unique identifier for each US county as define...
# 7   A textual identifier that uniquely identifies ...
# 8   Changes for a given date as compared to baseli...
# 9   Mobility trends for places like restaurants ca...
# 10  Mobility trends for places like grocery market...
# 11  Mobility trends for places like local parks na...
# 12  Mobility trends for places like public transpo...
# 13                Mobility trends for places of work.
# 14           Mobility trends for places of residence.
# 15                                            Source
# 16                        Load time for this data row

# %%
# Preview the first five lines of the table
client.list_rows(table, max_results=5).to_dataframe()
# Out:
#   country_region_code country_region   sub_region_1 sub_region_2 metro_area  \
# 0                  PT       Portugal  Faro District        Lagoa       None
# 1                  PT       Portugal  Faro District        Lagoa       None
# 2                  PT       Portugal  Faro District        Lagoa       None
# 3                  PT       Portugal  Faro District        Lagoa       None
# 4                  PT       Portugal  Faro District        Lagoa       None
#
#   iso_3166_2_code census_fips_code                     place_id        date  \
# 0            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2021-06-17
# 1            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2021-07-12
# 2            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2021-07-23
# 3            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2021-07-31
# 4            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2021-09-10
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                 27
# 1                                                 65
# 2                                                 96
# 3                                                111
# 4                                                127
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               <NA>
# 1                                                 99
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#    parks_percent_change_from_baseline  \
# 0                                 107
# 1                                <NA>
# 2                                <NA>
# 3                                 303
# 4                                <NA>
#
#    transit_stations_percent_change_from_baseline  \
# 0                                           <NA>
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
#
#    workplaces_percent_change_from_baseline  \
# 0                                       -3
# 1                                       -9
# 2                                       -5
# 3                                       24
# 4                                        2
#
#    residential_percent_change_from_baseline  \
# 0                                         1
# 1                                         3
# 2                                         2
# 3                                      <NA>
# 4                                         0
#
#                                           source_url  \
# 0  https://www.gstatic.com/covid19/mobility/Globa...
# 1  https://www.gstatic.com/covid19/mobility/Globa...
# 2  https://www.gstatic.com/covid19/mobility/Globa...
# 3  https://www.gstatic.com/covid19/mobility/Globa...
# 4  https://www.gstatic.com/covid19/mobility/Globa...
#
#                      etl_timestamp
# 0 2024-06-29 00:06:57.820714+00:00
# 1 2024-06-29 00:06:57.820714+00:00
# 2 2024-06-29 00:06:57.820714+00:00
# 3 2024-06-29 00:06:57.820714+00:00
# 4 2024-06-29 00:06:57.820714+00:00

# %% [markdown]
# ##  Add safe config settings

# %% [markdown]
# BigQuery allows you to query up to 1 TB per month. You can quickly reach this limit if you are not careful. Luckily, there are ways to assess and limit the amount of data you are querying.

# %% [markdown]
# Set constants for sizes

# %%
ONE_MB = 1_000*1_000
ONE_GB = 1_000*ONE_MB

# %% [markdown]
# Sample Query 1 - Covid - Dry Run
# You can use a 'dry run' to estimate the size of a query before running it.

# %%
query = """
        SELECT *
        FROM bigquery-public-data.covid19_google_mobility.mobility_report
        LIMIT 5
        """

dry_run_config = bigquery.QueryJobConfig(dry_run = True)
dry_run_query_job = client.query(query, job_config= dry_run_config)
size = dry_run_query_job.total_bytes_processed
print(f"{size:_}")
# Out:
# 2_215_181_051

# %% [markdown]
# Sample Query 1 - Covid - Safe Config
# You can also specify a limit for how much data you want to scan.

# %%
# This line should be included every time
# It seems like you should be able to set it and reuse it, but that doesn't work
safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=ONE_GB)

safe_query_job = client.query(query, job_config=safe_config)
df = safe_query_job.to_dataframe()
df.head()
# Out:
#   country_region_code country_region   sub_region_1 sub_region_2 metro_area  \
# 0                  PT       Portugal  Faro District        Lagoa       None
# 1                  PT       Portugal  Faro District        Lagoa       None
# 2                  PT       Portugal  Faro District        Lagoa       None
# 3                  PT       Portugal  Faro District        Lagoa       None
# 4                  PT       Portugal  Faro District        Lagoa       None
#
#   iso_3166_2_code census_fips_code                     place_id        date  \
# 0            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2021-06-17
# 1            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2021-07-12
# 2            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2021-07-23
# 3            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2021-07-31
# 4            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2021-09-10
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                 27
# 1                                                 65
# 2                                                 96
# 3                                                111
# 4                                                127
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               <NA>
# 1                                                 99
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#    parks_percent_change_from_baseline  \
# 0                                 107
# 1                                <NA>
# 2                                <NA>
# 3                                 303
# 4                                <NA>
#
#    transit_stations_percent_change_from_baseline  \
# 0                                           <NA>
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
#
#    workplaces_percent_change_from_baseline  \
# 0                                       -3
# 1                                       -9
# 2                                       -5
# 3                                       24
# 4                                        2
#
#    residential_percent_change_from_baseline  \
# 0                                         1
# 1                                         3
# 2                                         2
# 3                                      <NA>
# 4                                         0
#
#                                           source_url  \
# 0  https://www.gstatic.com/covid19/mobility/Globa...
# 1  https://www.gstatic.com/covid19/mobility/Globa...
# 2  https://www.gstatic.com/covid19/mobility/Globa...
# 3  https://www.gstatic.com/covid19/mobility/Globa...
# 4  https://www.gstatic.com/covid19/mobility/Globa...
#
#                      etl_timestamp
# 0 2024-06-29 00:06:57.820714+00:00
# 1 2024-06-29 00:06:57.820714+00:00
# 2 2024-06-29 00:06:57.820714+00:00
# 3 2024-06-29 00:06:57.820714+00:00
# 4 2024-06-29 00:06:57.820714+00:00

# %%
df.shape
# Out:
# (5, 17)

# %% [markdown]
# ## What do a couple of entries look like?

# %%
query = """
        SELECT *
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        LIMIT 5
        """
df = client.query(query, job_config=safe_config).to_dataframe()
df.head()
# Out:
#   country_region_code country_region   sub_region_1 sub_region_2 metro_area  \
# 0                  PT       Portugal  Faro District        Lagoa       None
# 1                  PT       Portugal  Faro District        Lagoa       None
# 2                  PT       Portugal  Faro District        Lagoa       None
# 3                  PT       Portugal  Faro District        Lagoa       None
# 4                  PT       Portugal  Faro District        Lagoa       None
#
#   iso_3166_2_code census_fips_code                     place_id        date  \
# 0            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2021-06-17
# 1            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2021-07-12
# 2            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2021-07-23
# 3            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2021-07-31
# 4            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2021-09-10
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                 27
# 1                                                 65
# 2                                                 96
# 3                                                111
# 4                                                127
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               <NA>
# 1                                                 99
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#    parks_percent_change_from_baseline  \
# 0                                 107
# 1                                <NA>
# 2                                <NA>
# 3                                 303
# 4                                <NA>
#
#    transit_stations_percent_change_from_baseline  \
# 0                                           <NA>
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
#
#    workplaces_percent_change_from_baseline  \
# 0                                       -3
# 1                                       -9
# 2                                       -5
# 3                                       24
# 4                                        2
#
#    residential_percent_change_from_baseline  \
# 0                                         1
# 1                                         3
# 2                                         2
# 3                                      <NA>
# 4                                         0
#
#                                           source_url  \
# 0  https://www.gstatic.com/covid19/mobility/Globa...
# 1  https://www.gstatic.com/covid19/mobility/Globa...
# 2  https://www.gstatic.com/covid19/mobility/Globa...
# 3  https://www.gstatic.com/covid19/mobility/Globa...
# 4  https://www.gstatic.com/covid19/mobility/Globa...
#
#                      etl_timestamp
# 0 2024-06-29 00:06:57.820714+00:00
# 1 2024-06-29 00:06:57.820714+00:00
# 2 2024-06-29 00:06:57.820714+00:00
# 3 2024-06-29 00:06:57.820714+00:00
# 4 2024-06-29 00:06:57.820714+00:00

# %% [markdown]
# ##What do the next 5 entries look like?
# 5 just wasn't enough!

# %%
query = """
        SELECT *
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        LIMIT 5 OFFSET 5
        """
df = client.query(query, job_config=safe_config).to_dataframe()
df.head()
# Out:
#   country_region_code country_region   sub_region_1 sub_region_2 metro_area  \
# 0                  PT       Portugal  Faro District        Lagoa       None
# 1                  PT       Portugal  Faro District        Lagoa       None
# 2                  PT       Portugal  Faro District        Lagoa       None
# 3                  PT       Portugal  Faro District        Lagoa       None
# 4                  PT       Portugal  Faro District        Lagoa       None
#
#   iso_3166_2_code census_fips_code                     place_id        date  \
# 0            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2022-01-05
# 1            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2022-01-27
# 2            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2022-02-01
# 3            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2022-02-15
# 4            None             None  ChIJGcrqJ7DXGg0R8DOQ5L3rAAQ  2022-06-14
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                  6
# 1                                                  8
# 2                                                 25
# 3                                                 46
# 4                                                136
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#    parks_percent_change_from_baseline  \
# 0                                  12
# 1                                  -9
# 2                                   5
# 3                                  50
# 4                                <NA>
#
#    transit_stations_percent_change_from_baseline  \
# 0                                           <NA>
# 1                                           <NA>
# 2                                           <NA>
# 3                                           <NA>
# 4                                           <NA>
#
#    workplaces_percent_change_from_baseline  \
# 0                                      -26
# 1                                      -16
# 2                                       -8
# 3                                       -2
# 4                                       11
#
#    residential_percent_change_from_baseline  \
# 0                                        11
# 1                                         8
# 2                                         7
# 3                                         3
# 4                                         0
#
#                                           source_url  \
# 0  https://www.gstatic.com/covid19/mobility/Globa...
# 1  https://www.gstatic.com/covid19/mobility/Globa...
# 2  https://www.gstatic.com/covid19/mobility/Globa...
# 3  https://www.gstatic.com/covid19/mobility/Globa...
# 4  https://www.gstatic.com/covid19/mobility/Globa...
#
#                      etl_timestamp
# 0 2024-06-29 00:06:57.820714+00:00
# 1 2024-06-29 00:06:57.820714+00:00
# 2 2024-06-29 00:06:57.820714+00:00
# 3 2024-06-29 00:06:57.820714+00:00
# 4 2024-06-29 00:06:57.820714+00:00

# %% [markdown]
# ## How many records are there?

# %%
query = """
        SELECT COUNT(1) as record_count
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        """
df = client.query(query).to_dataframe()
df.head()
# Out:
#    record_count
# 0      11730025

# %% [markdown]
# ## What countries are represented in this dataset?

# %%
data_prefix = 'bigquery-public-data.covid19_google_mobility'
data_table = 'mobility_report'

# %%
safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=ONE_MB)
query = f"""
        SELECT DISTINCT country_region
        FROM {data_prefix}.{data_table}
--        ORDER BY country_region DESC
        """
df = client.query(query, job_config = safe_config).to_dataframe()
df.head()
# Out:
#   country_region
# 0       Portugal
# 1          Qatar
# 2        Réunion
# 3        Romania
# 4      Guatemala

# %%
df.shape
# Out:
# (135, 1)

# %%
countries = df['country_region']
print(f"There are {countries.count()} countries")
# Out:
# There are 135 countries

# %% [markdown]
# **There are 193 or maybe 195 total countries so we are missing 60 countries in this dataset!!!**

# %% [markdown]
# ## What the subregions are in the US?

# %%
safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=ONE_MB)
query = """
        SELECT sub_region_1, sub_region_2
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        WHERE country_region = 'United States'
        LIMIT 10
        """
df = client.query(query, job_config = safe_config).to_dataframe()
df.head()
# Out:
#   sub_region_1    sub_region_2
# 0      Indiana   Dubois County
# 1      Indiana   Dubois County
# 2      Indiana   Dubois County
# 3      Indiana  Elkhart County
# 4      Indiana  Elkhart County

# %% [markdown]
# This isn't very informative. Let's look where the sub_regions do not equal 'None'.

# %%
query = """
        SELECT DISTINCT sub_region_1, sub_region_2
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        WHERE country_region = 'United States' AND sub_region_2 != 'None'
        """
df = client.query(query).to_dataframe()
df.head(10)
# Out:
#   sub_region_1       sub_region_2
# 0      Indiana     Fayette County
# 1      Indiana     Hancock County
# 2      Indiana       Henry County
# 3      Indiana     Jackson County
# 4      Indiana    Lawrence County
# 5      Indiana     Madison County
# 6      Indiana       Miami County
# 7      Indiana      Monroe County
# 8      Indiana  Montgomery County
# 9      Indiana      Starke County

# %% [markdown]
# Sub_region_1 appears to be the state and sub_region_2 appears to be the county.

# %% [markdown]
# ## What dates does this cover?

# %%
query = """
        SELECT MIN(date) AS min_date, MAX(date) AS max_date
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        WHERE country_region = 'United States'
        """
df = client.query(query).to_dataframe()
df.head()
# Out:
#      min_date    max_date
# 0  2020-02-15  2022-10-15

# %% [markdown]
# We have data from mid-February 2020 to mid-October of 2022

# %% [markdown]
# ## On average have retail and recreation trips decreased in Bernalillo County?

# %%
query = """
        SELECT AVG(retail_and_recreation_percent_change_from_baseline) as mean
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        WHERE sub_region_2 = "Bernalillo County" AND sub_region_1 = "New Mexico"
        """
df = client.query(query).to_dataframe()
df.head()
# Out:
#         mean
# 0 -15.294661

# %% [markdown]
# ## Are there any Bernalillo Counties in other states?

# %%
query = """
        SELECT DISTINCT sub_region_1
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        WHERE sub_region_2 = "Bernalillo County"
        """
df = client.query(query).to_dataframe()
df.head()
# Out:
#   sub_region_1
# 0   New Mexico

# %% [markdown]
# We're the only one!!!

# %% [markdown]
# ## How many states have a subregion 2 that is Lincoln County or similar?

# %%
query = """
        SELECT DISTINCT sub_region_1, sub_region_2, country_region
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        WHERE sub_region_2 LIKE "Lincoln%"
        """
df = client.query(query).to_dataframe()
df.head(50)
# Out:
#              sub_region_1      sub_region_2  country_region
# 0          North Carolina    Lincoln County   United States
# 1               Wisconsin    Lincoln County   United States
# 2              New Mexico    Lincoln County   United States
# 3                  Oregon    Lincoln County   United States
# 4                Missouri    Lincoln County   United States
# 5                   Idaho    Lincoln County   United States
# 6                 Wyoming    Lincoln County   United States
# 7                Nebraska    Lincoln County   United States
# 8                Kentucky    Lincoln County   United States
# 9                Arkansas    Lincoln County   United States
# 10              Louisiana    Lincoln Parish   United States
# 11                  Maine    Lincoln County   United States
# 12               Colorado    Lincoln County   United States
# 13            Mississippi    Lincoln County   United States
# 14             Washington    Lincoln County   United States
# 15           Lincolnshire  Lincoln District  United Kingdom
# 16          West Virginia    Lincoln County   United States
# 17                Montana    Lincoln County   United States
# 18  Buenos Aires Province   Lincoln Partido       Argentina
# 19              Tennessee    Lincoln County   United States
# 20              Minnesota    Lincoln County   United States
# 21               Oklahoma    Lincoln County   United States
# 22                Georgia    Lincoln County   United States
# 23           South Dakota    Lincoln County   United States

# %% [markdown]
# ## What was the lowest level of retail & recreation in Bernalillo county and when was that?

# %%
query = """
        SELECT MIN(retail_and_recreation_percent_change_from_baseline)
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        WHERE sub_region_2 = "Bernalillo County"
        """
df = client.query(query).to_dataframe()
df.head()
# Out:
#    f0_
# 0  -86

# %%
query = """
        SELECT date
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        WHERE sub_region_2 = "Bernalillo County" AND sub_region_1 = "New Mexico"
              AND retail_and_recreation_percent_change_from_baseline = -86
        """
df = client.query(query).to_dataframe()
df.head()
# Out:
#          date
# 0  2020-12-25

# %% [markdown]
# Christmas! We probably don't want to account for that day (or Thanksgiving day).

# %%
query = """
        SELECT MIN(retail_and_recreation_percent_change_from_baseline)
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        WHERE sub_region_2 = "Bernalillo County"
          AND date not in
          ('2020-12-25','2020-11-26','2021-12-25','2021-11-25','2022-11-24','2022-12-25')
        """
df = client.query(query).to_dataframe()
df.head()
# Out:
#    f0_
# 0  -61

# %%
query = """
        SELECT date
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        WHERE sub_region_2 = "Bernalillo County" AND sub_region_1 = "New Mexico"
              AND retail_and_recreation_percent_change_from_baseline = -61
        """
df = client.query(query).to_dataframe()
df.head()
# Out:
#          date
# 0  2020-04-12

# %% [markdown]
# ## Was that in a period of low retail and recreation activity or just noise in the data?

# %%
query = """
        SELECT date, retail_and_recreation_percent_change_from_baseline
        -- SELECT COUNT(*)
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        WHERE sub_region_2 = "Bernalillo County"
              AND retail_and_recreation_percent_change_from_baseline < -40
        -- ORDER BY retail_and_recreation_percent_change_from_baseline
        ORDER BY date
        """
df = client.query(query).to_dataframe()
df.head(25)
# Out:
#           date  retail_and_recreation_percent_change_from_baseline
# 0   2020-03-21                                                -42
# 1   2020-03-24                                                -43
# 2   2020-03-25                                                -44
# 3   2020-03-26                                                -45
# 4   2020-03-27                                                -45
# 5   2020-03-28                                                -51
# 6   2020-03-29                                                -46
# 7   2020-04-04                                                -47
# 8   2020-04-05                                                -44
# 9   2020-04-08                                                -41
# 10  2020-04-10                                                -42
# 11  2020-04-11                                                -48
# 12  2020-04-12                                                -61
# 13  2020-04-13                                                -48
# 14  2020-04-18                                                -45
# 15  2020-04-19                                                -41
# 16  2020-04-25                                                -43
# 17  2020-07-04                                                -41
# 18  2020-11-21                                                -45
# 19  2020-11-22                                                -44
# 20  2020-11-26                                                -80
# 21  2020-11-27                                                -54
# 22  2020-11-28                                                -51
# 23  2020-11-29                                                -45
# 24  2020-12-25                                                -86

# %% [markdown]
# ## What country has decreased retail and recreation activity the most?

# %%
query = """
        SELECT country_region, ROUND(AVG(retail_and_recreation_percent_change_from_baseline), 1) as mean
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        GROUP BY country_region
        ORDER BY mean
        """
df = client.query(query).to_dataframe()
df.head()
# Out:
#     country_region  mean
# 0  Myanmar (Burma) -38.2
# 1    Liechtenstein -33.9
# 2           Panama -28.6
# 3    Guinea-Bissau -25.3
# 4           Kuwait -24.3

# %%
df.tail(5)
# Out:
#     country_region  mean
# 130       Mongolia  43.1
# 131   Burkina Faso  46.8
# 132          Niger  57.6
# 133          Yemen  61.5
# 134          Libya  69.7

# %% [markdown]
# ## How does New Mexico compare to similar states?

# %%
query = """
        SELECT sub_region_1, AVG(retail_and_recreation_percent_change_from_baseline) as mean
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        WHERE sub_region_1 IN ( "New Mexico", "Colorado", "Arizona", "Oklahoma", "Texas", "Utah" )
        GROUP BY sub_region_1
        ORDER BY mean
        """
df = client.query(query).to_dataframe()
df.head()
# Out:
#   sub_region_1       mean
# 0   New Mexico -11.332305
# 1      Arizona  -7.709368
# 2     Colorado  -6.410616
# 3        Texas  -5.194934
# 4         Utah   0.878987

# %% [markdown]
# ## What does all the data for Bernalillo County look like?

# %%
table.schema
# Out:
# [SchemaField('country_region_code', 'STRING', 'NULLABLE', None, '2 letter alpha code for the country/region in which changes are measured relative to the baseline. These values correspond with the ISO 3166-1 alpha-2 codes', (), None),
#  SchemaField('country_region', 'STRING', 'NULLABLE', None, 'The country/region in which changes are measured relative to the baseline', (), None),
#  SchemaField('sub_region_1', 'STRING', 'NULLABLE', None, 'First geographic sub-region in which the data is aggregated. This varies by country/region to ensure privacy and public health value in consultation with local public health authorities', (), None),
#  SchemaField('sub_region_2', 'STRING', 'NULLABLE', None, 'Second geographic sub-region in which the data is aggregated. This varies by country/region to ensure privacy and public health value in consultation with local public health authorities', (), None),
#  SchemaField('metro_area', 'STRING', 'NULLABLE', None, 'A specific metro area to measure mobility within a given city/metro area. This varies by country/region to ensure privacy and public health value in consultation with local public health authorities', (), None),
#  SchemaField('iso_3166_2_code', 'STRING', 'NULLABLE', None, 'Unique identifier for the geographic region as defined by ISO Standard 3166-2.', (), None),
#  SchemaField('census_fips_code', 'STRING', 'NULLABLE', None, 'Unique identifier for each US county as defined by the US Census Bureau. Maps to county_fips_code in other tables', (), None),
#  SchemaField('place_id', 'STRING', 'NULLABLE', None, 'A textual identifier that uniquely identifies a place in the Google Places database and on Google Maps (details). For example ChIJd_Y0eVIvkIARuQyDN0F1LBA. For details see the following link: https://developers.google.com/places/web-service/place-id', (), None),
#  SchemaField('date', 'DATE', 'NULLABLE', None, 'Changes for a given date as compared to baseline. Baseline is the median value for the corresponding day of the week during the 5-week period Jan 3–Feb 6 2020.', (), None),
#  SchemaField('retail_and_recreation_percent_change_from_baseline', 'INTEGER', 'NULLABLE', None, 'Mobility trends for places like restaurants cafes shopping centers theme parks museums libraries and movie theaters.', (), None),
#  SchemaField('grocery_and_pharmacy_percent_change_from_baseline', 'INTEGER', 'NULLABLE', None, 'Mobility trends for places like grocery markets food warehouses farmers markets specialty food shops drug stores and pharmacies.', (), None),
#  SchemaField('parks_percent_change_from_baseline', 'INTEGER', 'NULLABLE', None, 'Mobility trends for places like local parks national parks public beaches marinas dog parks plazas and public gardens.', (), None),
#  SchemaField('transit_stations_percent_change_from_baseline', 'INTEGER', 'NULLABLE', None, 'Mobility trends for places like public transport hubs such as subway bus and train stations.', (), None),
#  SchemaField('workplaces_percent_change_from_baseline', 'INTEGER', 'NULLABLE', None, 'Mobility trends for places of work.', (), None),
#  SchemaField('residential_percent_change_from_baseline', 'INTEGER', 'NULLABLE', None, 'Mobility trends for places of residence.', (), None),
#  SchemaField('source_url', 'STRING', 'NULLABLE', None, 'Source ', (), None),
#  SchemaField('etl_timestamp', 'TIMESTAMP', 'NULLABLE', None, 'Load time for this data row', (), None)]

# %%
query = """
        SELECT date,
               retail_and_recreation_percent_change_from_baseline AS retail_recreation,
               grocery_and_pharmacy_percent_change_from_baseline AS grocery,
               parks_percent_change_from_baseline AS parks,
               transit_stations_percent_change_from_baseline AS transit,
               workplaces_percent_change_from_baseline AS work,
               residential_percent_change_from_baseline AS residential
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        WHERE sub_region_1 ="New Mexico" AND sub_region_2 = "Bernalillo County"
        ORDER BY date
        """
df = client.query(query).to_dataframe()
df.head(40)
# Out:
#           date  retail_recreation  grocery  parks  transit  work  residential
# 0   2020-02-15                  4       10     25        0     0           -1
# 1   2020-02-16                 12       10     28        4     2           -1
# 2   2020-02-17                 10        6     35        2   -24            4
# 3   2020-02-18                  5        8     17        6     3            0
# 4   2020-02-19                  1        8      6        3     1            0
# 5   2020-02-20                  5        4      9        3     1            0
# 6   2020-02-21                  3        6      4        1     4           -1
# 7   2020-02-22                  1        3    -12       -7     0            1
# 8   2020-02-23                  3        1    -32       -5     0            1
# 9   2020-02-24                  6        5      9        5     3           -1
# 10  2020-02-25                  5        4     -4        3     3            0
# 11  2020-02-26                 11        9      9        6     2           -1
# 12  2020-02-27                 13        9     24       11     1           -1
# 13  2020-02-28                 11       12     19       11     5           -3
# 14  2020-02-29                 13       13     41        6     4           -3
# 15  2020-03-01                 19       15     28        6     5           -2
# 16  2020-03-02                 12       11     26       10     4           -2
# 17  2020-03-03                 14       18     17        7     3           -1
# 18  2020-03-04                 11       15     24        8     2           -1
# 19  2020-03-05                 11       13     33        8     2           -1
# 20  2020-03-06                  8       12     27        7     5           -2
# 21  2020-03-07                 10       13     51        6     4           -2
# 22  2020-03-08                 10        9     -4       -1     2            0
# 23  2020-03-09                 12       12     49        4     3           -2
# 24  2020-03-10                 11       13     27        8     2           -1
# 25  2020-03-11                 12       23     23        8     0           -1
# 26  2020-03-12                 12       37     26        2    -8            1
# 27  2020-03-13                 -2       43    -17       -8   -10            4
# 28  2020-03-14                -11       23     29       -4    -2            3
# 29  2020-03-15                -11       13     28       -8    -5            3
# 30  2020-03-16                 -5       24     35       -9   -20            6
# 31  2020-03-17                -16       19      7      -11   -27           10
# 32  2020-03-18                -21       18    -14      -19   -32           13
# 33  2020-03-19                -30       10     -7      -22   -36           15
# 34  2020-03-20                -32       10      6      -26   -35           15
# 35  2020-03-21                -42       -1      9      -26   -25           11
# 36  2020-03-22                -40       -8     28      -32   -28            9
# 37  2020-03-23                -28       10     18      -31   -40           14
# 38  2020-03-24                -43      -14     14      -34   -46           19
# 39  2020-03-25                -44      -16      5      -36   -49           20

# %% [markdown]
# ##  How many counties in the U.S. have a name that starts with a B?

# %%
query = """
        SELECT DISTINCT sub_region_2
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        WHERE sub_region_2 LIKE "B%" AND country_region = "United States"
        """
df = client.query(query).to_dataframe()
df.head(6)
# Out:
#       sub_region_2
# 0    Bergen County
# 1   Baldwin County
# 2   Barbour County
# 3       Bee County
# 4    Blanco County
# 5  Brazoria County

# %%
df.count()
# Out:
# sub_region_2    143
# dtype: int64

# %% [markdown]
# ## What does all the data for Bernalillo County look like for June?

# %%
query = """
        SELECT date,
               retail_and_recreation_percent_change_from_baseline AS retail_recreation,
               grocery_and_pharmacy_percent_change_from_baseline AS grocery,
               parks_percent_change_from_baseline AS parks,
               transit_stations_percent_change_from_baseline AS transit,
               workplaces_percent_change_from_baseline AS work,
               residential_percent_change_from_baseline AS residential
        FROM `bigquery-public-data.covid19_google_mobility.mobility_report`
        WHERE sub_region_1 ="New Mexico" AND sub_region_2 = "Bernalillo County"
              AND date BETWEEN '2021-06-01' AND '2021-06-30'
        ORDER BY date
        """
df = client.query(query).to_dataframe()
df.head(30)
# Out:
#           date  retail_recreation  grocery  parks  transit  work  residential
# 0   2021-06-01                 -2        8     34      -14   -37            7
# 1   2021-06-02                 -7        1     28      -14   -37            8
# 2   2021-06-03                 -3        1     40      -16   -37            7
# 3   2021-06-04                 -8        1     29      -11   -33            6
# 4   2021-06-05                -14       -4     31       -6   -17            2
# 5   2021-06-06                 -5       -3     26       -6   -13            1
# 6   2021-06-07                 -5       -1     36      -12   -37            7
# 7   2021-06-08                 -4        1     28       -8   -36            8
# 8   2021-06-09                 -5        2     26      -11   -36            8
# 9   2021-06-10                 -5        0     36      -14   -37            8
# 10  2021-06-11                 -9        1     22       -9   -34            6
# 11  2021-06-12                -15       -4     24       -5   -18            1
# 12  2021-06-13                 -7       -4      8      -11   -13            1
# 13  2021-06-14                 -6       -3     29      -10   -38            7
# 14  2021-06-15                 -4        0     19       -9   -36            8
# 15  2021-06-16                 -4        2     18      -11   -37            7
# 16  2021-06-17                 -3        0     33      -13   -37            7
# 17  2021-06-18                 -8        2     19      -13   -36            6
# 18  2021-06-19                -13        1     28       -4   -17            1
# 19  2021-06-20                 -6        2      4      -13   -14           -1
# 20  2021-06-21                 -7       -5     27      -14   -39            7
# 21  2021-06-22                 -6        0     23       -8   -37            8
# 22  2021-06-23                 -7       -1     19       -9   -37            7
# 23  2021-06-24                 -7       -4     31      -15   -37            7
# 24  2021-06-25                 -8       -2     18      -11   -34            6
# 25  2021-06-26                -13       -7     28       -8   -17            1
# 26  2021-06-27                 -6       -6     17      -12   -13            1
# 27  2021-06-28                 -7       -7     21      -14   -38            4
# 28  2021-06-29                 -9       -6     -2      -12   -38            8
# 29  2021-06-30                 -6        0     13       -7   -37            8

# %% [markdown]
# ## Your Turn
# You will now practice using queries with Kaggle's Intro to SQL, located [here](https://www.kaggle.com/learn/intro-to-sql).
