# %% [markdown]
# # Exploring BigQuery
#
# - BigQuery metadata, i.e. information about a table
# - BigQuery query limits with QueryJobConfig()

# %% [markdown]
# ## Setup

# %%
from google.cloud import bigquery
from google.colab import auth
import pandas as pd

auth.authenticate_user()

# %%
billing_project_id = 'cool-monolith-286222'

# Create client object
client = bigquery.Client(project=billing_project_id)

# %% [markdown]
# ## Table Metadata Exploration

# %% [markdown]
# ### List the tables

# %%
# Construct a reference to the "Global Biodiversity Information Facility" dataset
dataset_ref = client.dataset("gbif", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# Get all the tables in the dataset
tables = list(client.list_tables(dataset))

# Print names of all tables in the dataset
for table in tables:
  print(table.table_id)
# Out:
# occurrences

# %%
table_id = "occurrences"
table_id
# Out:
# 'occurrences'

# %% [markdown]
# ### Look at the table schema

# %%
# Construct a reference to the "mobility report" table
table_ref = dataset.table("occurrences")

# API request - fetch the table
table = client.get_table(table_ref)

# See the table's schema - name, field type, mode, description
table.schema
# Out:
# [SchemaField('gbifid', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('datasetkey', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('occurrenceid', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('kingdom', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('phylum', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('class', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('order', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('family', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('genus', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('species', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('infraspecificepithet', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('taxonrank', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('scientificname', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('verbatimscientificname', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('verbatimscientificnameauthorship', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('countrycode', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('locality', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('stateprovince', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('occurrencestatus', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('individualcount', 'INTEGER', 'NULLABLE', None, None, (), None),
#  SchemaField('publishingorgkey', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('decimallatitude', 'FLOAT', 'NULLABLE', None, None, (), None),
#  SchemaField('decimallongitude', 'FLOAT', 'NULLABLE', None, None, (), None),
#  SchemaField('coordinateuncertaintyinmeters', 'FLOAT', 'NULLABLE', None, None, (), None),
#  SchemaField('coordinateprecision', 'FLOAT', 'NULLABLE', None, None, (), None),
#  SchemaField('elevation', 'FLOAT', 'NULLABLE', None, None, (), None),
#  SchemaField('elevationaccuracy', 'FLOAT', 'NULLABLE', None, None, (), None),
#  SchemaField('depth', 'FLOAT', 'NULLABLE', None, None, (), None),
#  SchemaField('depthaccuracy', 'FLOAT', 'NULLABLE', None, None, (), None),
#  SchemaField('eventdate', 'TIMESTAMP', 'NULLABLE', None, None, (), None),
#  SchemaField('day', 'INTEGER', 'NULLABLE', None, None, (), None),
#  SchemaField('month', 'INTEGER', 'NULLABLE', None, None, (), None),
#  SchemaField('year', 'INTEGER', 'NULLABLE', None, None, (), None),
#  SchemaField('taxonkey', 'INTEGER', 'NULLABLE', None, None, (), None),
#  SchemaField('specieskey', 'INTEGER', 'NULLABLE', None, None, (), None),
#  SchemaField('basisofrecord', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('institutioncode', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('collectioncode', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('catalognumber', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('recordnumber', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('identifiedby', 'RECORD', 'NULLABLE', None, None, (SchemaField('array', 'RECORD', 'REPEATED', None, None, (SchemaField('array_element', 'STRING', 'NULLABLE', None, None, (), None),), None),), None),
#  SchemaField('dateidentified', 'TIMESTAMP', 'NULLABLE', None, None, (), None),
#  SchemaField('license', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('rightsholder', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('recordedby', 'RECORD', 'NULLABLE', None, None, (SchemaField('array', 'RECORD', 'REPEATED', None, None, (SchemaField('array_element', 'STRING', 'NULLABLE', None, None, (), None),), None),), None),
#  SchemaField('typestatus', 'RECORD', 'NULLABLE', None, None, (SchemaField('array', 'RECORD', 'REPEATED', None, None, (SchemaField('array_element', 'STRING', 'NULLABLE', None, None, (), None),), None),), None),
#  SchemaField('establishmentmeans', 'STRING', 'NULLABLE', None, None, (), None),
#  SchemaField('lastinterpreted', 'TIMESTAMP', 'NULLABLE', None, None, (), None),
#  SchemaField('mediatype', 'RECORD', 'NULLABLE', None, None, (SchemaField('array', 'RECORD', 'REPEATED', None, None, (SchemaField('array_element', 'STRING', 'NULLABLE', None, None, (), None),), None),), None),
#  SchemaField('issue', 'RECORD', 'NULLABLE', None, None, (SchemaField('array', 'RECORD', 'REPEATED', None, None, (SchemaField('array_element', 'STRING', 'NULLABLE', None, None, (), None),), None),), None)]

# %%
# convert the table.schema into a data frame
fields = pd.DataFrame( [ x.to_api_repr() for x in table.schema ] )
fields.head()
# Out:
#            name    type      mode fields
# 0        gbifid  STRING  NULLABLE    NaN
# 1    datasetkey  STRING  NULLABLE    NaN
# 2  occurrenceid  STRING  NULLABLE    NaN
# 3       kingdom  STRING  NULLABLE    NaN
# 4        phylum  STRING  NULLABLE    NaN

# %%
fields.shape
# Out:
# (50, 4)

# %%
# Preview the first five lines of the table as a data frame
client.list_rows(table, max_results=5).to_dataframe().transpose()
# Out:
#                                                                                   0  \
# gbifid                                                                   3599137728
# datasetkey                                     4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# occurrenceid                                    URN:catalog:CLO:EBIRD:OBS1173704723
# kingdom                                                                    Animalia
# phylum                                                                     Chordata
# class                                                                          Aves
# order                                                                 Passeriformes
# family                                                                     Corvidae
# genus                                                                        Corvus
# species                                                       Corvus brachyrhynchos
# infraspecificepithet                                                           None
# taxonrank                                                                   SPECIES
# scientificname                                Corvus brachyrhynchos C.L.Brehm, 1822
# verbatimscientificname                                        Corvus brachyrhynchos
# verbatimscientificnameauthorship                                               None
# countrycode                                                                      US
# locality                            Donahoo Rd, Tonganoxie US-KS (39.1577,-95.0105)
# stateprovince                                                                Kansas
# occurrencestatus                                                            PRESENT
# individualcount                                                                   3
# publishingorgkey                               e2e717bf-551a-4917-bdc9-4fa0f342c530
# decimallatitude                                                           39.157715
# decimallongitude                                                          -95.01052
# coordinateuncertaintyinmeters                                                   NaN
# coordinateprecision                                                             NaN
# elevation                                                                       NaN
# elevationaccuracy                                                               NaN
# depth                                                                           NaN
# depthaccuracy                                                                   NaN
# eventdate                                                 2021-06-02 00:00:00+00:00
# day                                                                               2
# month                                                                             6
# year                                                                           2021
# taxonkey                                                                    2482507
# specieskey                                                                  2482507
# basisofrecord                                                     HUMAN_OBSERVATION
# institutioncode                                                                 CLO
# collectioncode                                                                EBIRD
# catalognumber                                                         OBS1173704723
# recordnumber                                                                   None
# identifiedby                                                          {'array': []}
# dateidentified                                                                  NaT
# license                                                                   CC_BY_4_0
# rightsholder                                                                   None
# recordedby                             {'array': [{'array_element': 'obsr684247'}]}
# typestatus                                                            {'array': []}
# establishmentmeans                                                             None
# lastinterpreted                                    2024-04-17 08:57:16.100000+00:00
# mediatype                                                             {'array': []}
# issue                             {'array': [{'array_element': 'CONTINENT_DERIVE...
#
#                                                                                   1  \
# gbifid                                                                   3172947391
# datasetkey                                     4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# occurrenceid                                     URN:catalog:CLO:EBIRD:OBS937842969
# kingdom                                                                    Animalia
# phylum                                                                     Chordata
# class                                                                          Aves
# order                                                                 Passeriformes
# family                                                                   Tyrannidae
# genus                                                                     Myiarchus
# species                                                          Myiarchus crinitus
# infraspecificepithet                                                           None
# taxonrank                                                                   SPECIES
# scientificname                                  Myiarchus crinitus (Linnaeus, 1758)
# verbatimscientificname                                           Myiarchus crinitus
# verbatimscientificnameauthorship                                               None
# countrycode                                                                      CA
# locality                                                                   Backyard
# stateprovince                                                               Ontario
# occurrencestatus                                                            PRESENT
# individualcount                                                                   1
# publishingorgkey                               e2e717bf-551a-4917-bdc9-4fa0f342c530
# decimallatitude                                                           45.389618
# decimallongitude                                                          -75.74444
# coordinateuncertaintyinmeters                                                   NaN
# coordinateprecision                                                             NaN
# elevation                                                                       NaN
# elevationaccuracy                                                               NaN
# depth                                                                           NaN
# depthaccuracy                                                                   NaN
# eventdate                                                 2020-06-05 00:00:00+00:00
# day                                                                               5
# month                                                                             6
# year                                                                           2020
# taxonkey                                                                    2483597
# specieskey                                                                  2483597
# basisofrecord                                                     HUMAN_OBSERVATION
# institutioncode                                                                 CLO
# collectioncode                                                                EBIRD
# catalognumber                                                          OBS937842969
# recordnumber                                                                   None
# identifiedby                                                          {'array': []}
# dateidentified                                                                  NaT
# license                                                                   CC_BY_4_0
# rightsholder                                                                   None
# recordedby                             {'array': [{'array_element': 'obsr335875'}]}
# typestatus                                                            {'array': []}
# establishmentmeans                                                             None
# lastinterpreted                                    2024-04-17 08:32:57.357000+00:00
# mediatype                                                             {'array': []}
# issue                             {'array': [{'array_element': 'CONTINENT_DERIVE...
#
#                                                                                   2  \
# gbifid                                                                   3523468642
# datasetkey                                     4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# occurrenceid                                URN:catalog:CLO:EBIRD_CAN:OBS1173830660
# kingdom                                                                    Animalia
# phylum                                                                     Chordata
# class                                                                          Aves
# order                                                                 Passeriformes
# family                                                                    Icteridae
# genus                                                                       Icterus
# species                                                             Icterus galbula
# infraspecificepithet                                                           None
# taxonrank                                                                   SPECIES
# scientificname                                     Icterus galbula (Linnaeus, 1758)
# verbatimscientificname                                              Icterus galbula
# verbatimscientificnameauthorship                                               None
# countrycode                                                                      CA
# locality                          Atlas square 15TVP09 - Rainy River District, 1...
# stateprovince                                                               Ontario
# occurrencestatus                                                            PRESENT
# individualcount                                                                   1
# publishingorgkey                               e2e717bf-551a-4917-bdc9-4fa0f342c530
# decimallatitude                                                           48.736866
# decimallongitude                                                          -94.25913
# coordinateuncertaintyinmeters                                                   NaN
# coordinateprecision                                                             NaN
# elevation                                                                       NaN
# elevationaccuracy                                                               NaN
# depth                                                                           NaN
# depthaccuracy                                                                   NaN
# eventdate                                                 2021-05-30 00:00:00+00:00
# day                                                                              30
# month                                                                             5
# year                                                                           2021
# taxonkey                                                                    2484340
# specieskey                                                                  2484340
# basisofrecord                                                     HUMAN_OBSERVATION
# institutioncode                                                                 CLO
# collectioncode                                                            EBIRD_CAN
# catalognumber                                                         OBS1173830660
# recordnumber                                                                   None
# identifiedby                                                          {'array': []}
# dateidentified                                                                  NaT
# license                                                                   CC_BY_4_0
# rightsholder                                                                   None
# recordedby                             {'array': [{'array_element': 'obsr766422'}]}
# typestatus                                                            {'array': []}
# establishmentmeans                                                             None
# lastinterpreted                                    2024-04-17 08:57:16.209000+00:00
# mediatype                                                             {'array': []}
# issue                             {'array': [{'array_element': 'CONTINENT_DERIVE...
#
#                                                                                   3  \
# gbifid                                                                   3169999285
# datasetkey                                     4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# occurrenceid                                     URN:catalog:CLO:EBIRD:OBS937959988
# kingdom                                                                    Animalia
# phylum                                                                     Chordata
# class                                                                          Aves
# order                                                                 Passeriformes
# family                                                                      Mimidae
# genus                                                                     Dumetella
# species                                                      Dumetella carolinensis
# infraspecificepithet                                                           None
# taxonrank                                                                   SPECIES
# scientificname                              Dumetella carolinensis (Linnaeus, 1766)
# verbatimscientificname                                       Dumetella carolinensis
# verbatimscientificnameauthorship                                               None
# countrycode                                                                      US
# locality                                                  Irish Grove MOS Sanctuary
# stateprovince                                                              Maryland
# occurrencestatus                                                            PRESENT
# individualcount                                                                   1
# publishingorgkey                               e2e717bf-551a-4917-bdc9-4fa0f342c530
# decimallatitude                                                           37.994404
# decimallongitude                                                          -75.73026
# coordinateuncertaintyinmeters                                                   NaN
# coordinateprecision                                                             NaN
# elevation                                                                       NaN
# elevationaccuracy                                                               NaN
# depth                                                                           NaN
# depthaccuracy                                                                   NaN
# eventdate                                                 2020-06-01 00:00:00+00:00
# day                                                                               1
# month                                                                             6
# year                                                                           2020
# taxonkey                                                                    2494936
# specieskey                                                                  2494936
# basisofrecord                                                     HUMAN_OBSERVATION
# institutioncode                                                                 CLO
# collectioncode                                                                EBIRD
# catalognumber                                                          OBS937959988
# recordnumber                                                                   None
# identifiedby                                                          {'array': []}
# dateidentified                                                                  NaT
# license                                                                   CC_BY_4_0
# rightsholder                                                                   None
# recordedby                             {'array': [{'array_element': 'obsr165954'}]}
# typestatus                                                            {'array': []}
# establishmentmeans                                                             None
# lastinterpreted                                    2024-04-17 08:32:57.472000+00:00
# mediatype                                                             {'array': []}
# issue                             {'array': [{'array_element': 'CONTINENT_DERIVE...
#
#                                                                                   4
# gbifid                                                                   3693280574
# datasetkey                                     4fa7b334-ce0d-4e88-aaae-2e0c138d049e
# occurrenceid                                    URN:catalog:CLO:EBIRD:OBS1173990708
# kingdom                                                                    Animalia
# phylum                                                                     Chordata
# class                                                                          Aves
# order                                                                 Passeriformes
# family                                                                 Hirundinidae
# genus                                                                Stelgidopteryx
# species                                                  Stelgidopteryx serripennis
# infraspecificepithet                                                           None
# taxonrank                                                                   SPECIES
# scientificname                           Stelgidopteryx serripennis (Audubon, 1838)
# verbatimscientificname                                   Stelgidopteryx serripennis
# verbatimscientificnameauthorship                                               None
# countrycode                                                                      US
# locality                          Jackson Park, Chicago--Wooded Island/Bobolink ...
# stateprovince                                                              Illinois
# occurrencestatus                                                            PRESENT
# individualcount                                                                   1
# publishingorgkey                               e2e717bf-551a-4917-bdc9-4fa0f342c530
# decimallatitude                                                           41.785713
# decimallongitude                                                          -87.58296
# coordinateuncertaintyinmeters                                                   NaN
# coordinateprecision                                                             NaN
# elevation                                                                       NaN
# elevationaccuracy                                                               NaN
# depth                                                                           NaN
# depthaccuracy                                                                   NaN
# eventdate                                                 2010-04-10 00:00:00+00:00
# day                                                                              10
# month                                                                             4
# year                                                                           2010
# taxonkey                                                                    2489202
# specieskey                                                                  2489202
# basisofrecord                                                     HUMAN_OBSERVATION
# institutioncode                                                                 CLO
# collectioncode                                                                EBIRD
# catalognumber                                                         OBS1173990708
# recordnumber                                                                   None
# identifiedby                                                          {'array': []}
# dateidentified                                                                  NaT
# license                                                                   CC_BY_4_0
# rightsholder                                                                   None
# recordedby                            {'array': [{'array_element': 'obsr1411120'}]}
# typestatus                                                            {'array': []}
# establishmentmeans                                                             None
# lastinterpreted                                    2024-04-17 08:57:16.293000+00:00
# mediatype                                                             {'array': []}
# issue                             {'array': [{'array_element': 'CONTINENT_DERIVE...

# %% [markdown]
# ##  Add safe config settings

# %% [markdown]
# BigQuery allows you to query up to 1 TB per month. You can quickly reach this limit if you are not careful. Luckily, there are ways to assess and limit the amount of data you are querying.

# %% [markdown]
# Set constants for sizes

# %%
ONE_MB = 1_000*1_000
ONE_GB = 1_000*ONE_MB

# %% [markdown]
# ### Sample Queries - Dry Run
#
# You can use a 'dry run' to estimate the size of a query before running it.

# %%
project_id = "bigquery-public-data"
dataset_id = "gbif"
table_id = "occurrences"

queries = []

queries += [ f"""
        SELECT countrycode
        FROM {project_id}.{dataset_id}.{table_id}
        WHERE class = "Magnoliopsida" AND countrycode ='US'
        LIMIT 10
        """ ]

queries += [ f"""
        SELECT countrycode
        FROM {project_id}.{dataset_id}.{table_id}
        WHERE class = "Magnoliopsida" AND countrycode ='US'
        """ ]

queries += [ f"""
        SELECT countrycode
        FROM {project_id}.{dataset_id}.{table_id}
        WHERE countrycode ='US'
        """ ]

queries += [ f"""
        SELECT year
        FROM {project_id}.{dataset_id}.{table_id}
        WHERE year = 2012
        """ ]

queries += [ f"""
        SELECT countrycode, class
        FROM {project_id}.{dataset_id}.{table_id}
        WHERE class = "Magnoliopsida" AND countrycode ='US'
        """ ]

queries += [ f"""
        SELECT countrycode, class
        FROM {project_id}.{dataset_id}.{table_id}
        WHERE countrycode ='US'
        """ ]

queries += [ f"""
        SELECT countrycode, class
        FROM {project_id}.{dataset_id}.{table_id}
        """ ]

queries += [ f"""
        SELECT countrycode
        FROM {project_id}.{dataset_id}.{table_id}
        """ ]

queries += [ f"""
        SELECT count(countrycode)
        FROM {project_id}.{dataset_id}.{table_id}
        """ ]

queries += [ f"""
        SELECT count(1)
        FROM {project_id}.{dataset_id}.{table_id}
        """ ]

queries += [ f"""
        SELECT count(countrycode)
        FROM {project_id}.{dataset_id}.{table_id}
        WHERE countrycode ='US'
        """ ]

queries += [ f"""
        SELECT count(1)
        FROM {project_id}.{dataset_id}.{table_id}
        WHERE countrycode ='US'
        """ ]

len(queries)
# Out:
# 12

# %%
for query in queries:
  dry_run_config = bigquery.QueryJobConfig(dry_run = True)
  dry_run_query_job = client.query(query, job_config= dry_run_config)
  size = dry_run_query_job.total_bytes_processed
  print(query)
  print(f"{size:_}")
  print()
# Out:
#         SELECT countrycode
#         FROM bigquery-public-data.gbif.occurrences
#         WHERE class = "Magnoliopsida" AND countrycode ='US'
#         LIMIT 10
#
# 35_002_295_626
#
#
#         SELECT countrycode
#         FROM bigquery-public-data.gbif.occurrences
#         WHERE class = "Magnoliopsida" AND countrycode ='US'
#
# 35_002_295_626
#
#
#         SELECT countrycode
#         FROM bigquery-public-data.gbif.occurrences
#         WHERE countrycode ='US'
#
# 11_685_171_796
#
#
#         SELECT year
#         FROM bigquery-public-data.gbif.occurrences
#         WHERE year = 2012
#
# 22_694_457_936
#
#
#         SELECT countrycode, class
#         FROM bigquery-public-data.gbif.occurrences
#         WHERE class = "Magnoliopsida" AND countrycode ='US'
#
# 35_002_295_626
#
#
#         SELECT countrycode, class
#         FROM bigquery-public-data.gbif.occurrences
#         WHERE countrycode ='US'
#
# 35_002_295_626
#
#
#         SELECT countrycode, class
#         FROM bigquery-public-data.gbif.occurrences
#
# 35_002_295_626
#
#
#         SELECT countrycode
#         FROM bigquery-public-data.gbif.occurrences
#
# 11_685_171_796
#
#
#         SELECT count(countrycode)
#         FROM bigquery-public-data.gbif.occurrences
#
# 11_685_171_796
#
#
#         SELECT count(1)
#         FROM bigquery-public-data.gbif.occurrences
#
# 0
#
#
#         SELECT count(countrycode)
#         FROM bigquery-public-data.gbif.occurrences
#         WHERE countrycode ='US'
#
# 11_685_171_796
#
#
#         SELECT count(1)
#         FROM bigquery-public-data.gbif.occurrences
#         WHERE countrycode ='US'
#
# 11_685_171_796

# %% [markdown]
# Sample Query 1 - Safe Config
# You can also specify a limit for how much data you want to scan.

# %%
# Create a list of queries
queries = []

queries += [ f"""
        SELECT count(1) as `total`
        FROM {project_id}.{dataset_id}.{table_id}
        """ ]

queries += [ f"""
        SELECT count(1) as `total`
        FROM {project_id}.{dataset_id}.{table_id}
        WHERE countrycode ='US'
        """ ]

queries += [ f"""
        SELECT count(countrycode) as `total`
        FROM {project_id}.{dataset_id}.{table_id}
        """ ]

queries += [ f"""
        SELECT count(countrycode) as `total`
        FROM {project_id}.{dataset_id}.{table_id}
        WHERE countrycode ='US'
        """ ]

len(queries)
# Out:
# 4

# %%
# safe_config needs to be included with every client.query() request
safe_config = bigquery.QueryJobConfig(
    maximum_bytes_billed=ONE_GB,
    # totalBytesProcessed=ONE_GB,
    # total_bytes_processed=ONE_GB,
)
# Use a try...except block to catch when the safe_config paramenter prevents a query
for query in queries:
  print(query)
  try:
    df = client.query(query, job_config=safe_config).to_dataframe()
    print(df.head())
  except:
    print("Blocked by safe_config")
# Out:
#         SELECT count(1) as `total`
#         FROM bigquery-public-data.gbif.occurrences
#
#         total
# 0  2961438667
#
#         SELECT count(1) as `total`
#         FROM bigquery-public-data.gbif.occurrences
#         WHERE countrycode ='US'
#
#         total
# 0  1088444124
#
#         SELECT count(countrycode) as `total`
#         FROM bigquery-public-data.gbif.occurrences
#
#         total
# 0  2921292949
#
#         SELECT count(countrycode) as `total`
#         FROM bigquery-public-data.gbif.occurrences
#         WHERE countrycode ='US'
#
#         total
# 0  1088444124

# %%
f"{ONE_GB:_}"
# Out:
# '1_000_000_000'

# %%
2669694827 > ONE_GB
# Out:
# True
