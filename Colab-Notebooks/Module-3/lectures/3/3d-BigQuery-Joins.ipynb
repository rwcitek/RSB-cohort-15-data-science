# %% [markdown]
# # Joins with BigQuery

# %% [markdown]
# ## Inner Joins

# %% [markdown]
# Inner Joins return data where there are matching records in both tables.

# %% [markdown]
# [Join documentation on BigQuery](https://cloud.google.com/bigquery/docs/reference/standard-sql/query-syntax#join_types)
#
# [Kaggle Inner Joins](https://www.kaggle.com/dansbecker/joining-data)
# [Kaggle Outter Joins](https://www.kaggle.com/alexisbcook/joins-and-unions)

# %% [markdown]
# Inner and Outer Joins Venn Diagram https://realpython.com/pandas-merge-join-and-concat/ about halfway down

# %%
from google.cloud import bigquery
from google.colab import auth
auth.authenticate_user()

# %%
billing_project_id = 'cool-monolith-286222'

# Create client object
client = bigquery.Client(project=billing_project_id)

# %%
dataset_ref = client.dataset("github_repos", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# Construct a reference to the "licenses" table
licenses_ref = dataset_ref.table("licenses")

# API request - fetch the table
licenses_table = client.get_table(licenses_ref)

# Preview the first five lines of the "licenses" table
client.list_rows(licenses_table, max_results=5).to_dataframe()
# Out:
#                                            repo_name       license
# 0             autarch/Dist-Zilla-Plugin-Test-TidyAll  artistic-2.0
# 1                           thundergnat/Prime-Factor  artistic-2.0
# 2                       kusha-b-k/Turabian_Engin_Fan  artistic-2.0
# 3  onlinepremiumoutlet/onlinepremiumoutlet.github.io  artistic-2.0
# 4                       huangyuanlove/LiaoBa_Service  artistic-2.0

# %%
# Construct a reference to the "sample_files" table
files_ref = dataset_ref.table("sample_files")

# API request - fetch the table
files_table = client.get_table(files_ref)

# Preview the first five lines of the "sample_files" table
client.list_rows(files_table, max_results=5).to_dataframe()
# Out:
#   repo_name                ref  \
# 0   EOL/eol  refs/heads/master
# 1   np/ling  refs/heads/master
# 2   np/ling  refs/heads/master
# 3   np/ling  refs/heads/master
# 4   np/ling  refs/heads/master
#
#                                                 path   mode  \
# 0                           generate/vendor/railties  40960
# 1  tests/success/merger_seq_inferred.t/merger_seq...  40960
# 2                       fixtures/sequence/lettype.ll  40960
# 3               fixtures/failure/wrong_order_seq3.ll  40960
# 4                             issues/sequence/keep.t  40960
#
#                                          id  \
# 0  0338c33fb3fda57db9e812ac7de969317cad4959
# 1  dd4bb3d5ecabe5044d3fa5a36e0a9bf7ca878209
# 2  8fdf536def2633116d65b92b3b9257bcf06e3e45
# 3  c2509ae1196c4bb79d7e60a3d679488ca4a753e9
# 4  5721de3488fb32745dfc11ec482e5dd0331fecaf
#
#                                  symlink_target
# 0             /usr/share/rails-ruby1.8/railties
# 1  ../../../fixtures/all/merger_seq_inferred.ll
# 2                             ../all/lettype.ll
# 3                    ../all/wrong_order_seq3.ll
# 4                                     ../keep.t

# %%
# Add safe config settings
ONE_MB = 1000*1000
TWO_GB = 2*1000*ONE_MB
SIX_GB = 6*1000*ONE_MB

# %%
query = """
        SELECT files.repo_name, licenses.license, files.path
        FROM `bigquery-public-data.github_repos.sample_files` AS files
        INNER JOIN `bigquery-public-data.github_repos.licenses` AS licenses
          ON files.repo_name = licenses.repo_name
        LIMIT 20
        """
# safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=TWO_GB)
safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=SIX_GB)
licenses = client.query(query, job_config=safe_config).to_dataframe()
licenses
# Out:
#           repo_name license                                               path
# 0   Piicksarn/cdnjs     mit        ajax/libs/ace/1.1.7/ext-static_highlight.js
# 1   Piicksarn/cdnjs     mit  ajax/libs/material-design-icons/1.0.0/device/d...
# 2   Piicksarn/cdnjs     mit  ajax/libs/mathjax/2.6.1-rc.1/fonts/HTML-CSS/Te...
# 3   Piicksarn/cdnjs     mit  ajax/libs/yui/3.8.0pr1/resize-proxy/resize-pro...
# 4   Piicksarn/cdnjs     mit  ajax/libs/material-design-icons/2.1.3/device/i...
# 5   Piicksarn/cdnjs     mit  ajax/libs/material-design-icons/2.1.3/content/...
# 6   Piicksarn/cdnjs     mit            ajax/libs/twemoji/1.2.1/36x36/1f4e6.png
# 7   Piicksarn/cdnjs     mit  ajax/libs/material-design-icons/2.1/image/svg/...
# 8   Piicksarn/cdnjs     mit  ajax/libs/angular-i18n/1.2.26/angular-locale_a...
# 9   Piicksarn/cdnjs     mit     ajax/libs/fullPage.js/2.5.0/jquery.fullPage.js
# 10  Piicksarn/cdnjs     mit  ajax/libs/jquery-mobile/1.4.3/images/icons-png...
# 11  Piicksarn/cdnjs     mit  ajax/libs/mathjax/2.4.0/fonts/HTML-CSS/TeX/png...
# 12  Piicksarn/cdnjs     mit  ajax/libs/mathjax/2.6.0-beta.2/fonts/HTML-CSS/...
# 13  Piicksarn/cdnjs     mit  ajax/libs/material-design-icons/2.2.2/maps/dra...
# 14  Piicksarn/cdnjs     mit  ajax/libs/material-design-icons/2.1.1/action/i...
# 15  Piicksarn/cdnjs     mit  ajax/libs/mathjax/1.1/fonts/HTML-CSS/TeX/png/F...
# 16  Piicksarn/cdnjs     mit  ajax/libs/angular-i18n/1.2.1/angular-locale_zu...
# 17  Piicksarn/cdnjs     mit  ajax/libs/material-design-icons/2.0.0/communic...
# 18  Piicksarn/cdnjs     mit  ajax/libs/mathjax/2.5.1/fonts/HTML-CSS/TeX/png...
# 19  Piicksarn/cdnjs     mit  ajax/libs/mathjax/2.5.0/fonts/HTML-CSS/TeX/png...

# %% [markdown]
# ## Outer Joins

# %%
# Construct a reference to the "hacker_news" dataset
dataset_ref = client.dataset("hacker_news", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

tables = client.list_tables(dataset)
for table in tables:
  print(table.table_id)
# Out:
# full

# %%
# Construct a reference to the "full" table
table_ref = dataset_ref.table("full")

# API request - fetch the table
table = client.get_table(table_ref)

# Preview the first five lines of the table
full = client.list_rows(table, max_results=5).to_dataframe()
full
# Out:
#   title   url  text  dead    by  score        time                 timestamp  \
# 0  None  None  None  <NA>  None   <NA>        <NA>                       NaT
# 1  None  None  None  <NA>  None   <NA>  1437161812 2015-07-17 19:36:52+00:00
# 2  None  None  None  True  None   <NA>  1437163755 2015-07-17 20:09:15+00:00
# 3  None  None  None  <NA>  None   <NA>        <NA>                       NaT
# 4  None  None  None  <NA>  None   <NA>  1437165877 2015-07-17 20:44:37+00:00
#
#     type       id  parent  descendants  ranking  deleted
# 0  story  9904684    <NA>         <NA>     <NA>     <NA>
# 1  story  9904796    <NA>         <NA>     <NA>     True
# 2  story  9904999    <NA>         <NA>     <NA>     True
# 3  story  9905071    <NA>         <NA>     <NA>     <NA>
# 4  story  9905201    <NA>         <NA>     <NA>     True

# %%
full[:2]
# Out:
#   title   url  text  dead    by  score        time                 timestamp  \
# 0  None  None  None  <NA>  None   <NA>        <NA>                       NaT
# 1  None  None  None  <NA>  None   <NA>  1437161812 2015-07-17 19:36:52+00:00
#
#     type       id  parent  descendants  ranking  deleted
# 0  story  9904684    <NA>         <NA>     <NA>     <NA>
# 1  story  9904796    <NA>         <NA>     <NA>     True

# %%
query = """
  SELECT
    parent AS story_id,
    title,
    url,

    by,
    time,
  FROM
    `bigquery-public-data.hacker_news.full` AS stories
  WHERE
    EXTRACT(DATE FROM stories.time_ts) = '2012-01-01'
"""

safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=TWO_GB)
comment_counts = client.query(query, job_config=safe_config).to_dataframe()
comment_counts
# Out:
# ---------------------------------------------------------------------------
# BadRequest                                Traceback (most recent call last)
# <ipython-input-10-604aab8440c6> in <cell line: 16>()
#      14
#      15 safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=TWO_GB)
# ---> 16 comment_counts = client.query(query, job_config=safe_config).to_dataframe()
#      17 comment_counts
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/job/query.py in to_dataframe(self, bqstorage_client, dtypes, progress_bar_type, create_bqstorage_client, max_results, geography_as_object, bool_dtype, int_dtype, float_dtype, string_dtype, date_dtype, datetime_dtype, time_dtype, timestamp_dtype)
#    1935                 :mod:`shapely` library cannot be imported.
#    1936         """
# -> 1937         query_result = wait_for_query(self, progress_bar_type, max_results=max_results)
#    1938         return query_result.to_dataframe(
#    1939             bqstorage_client=bqstorage_client,
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/_tqdm_helpers.py in wait_for_query(query_job, progress_bar_type, max_results)
#     105     )
#     106     if progress_bar is None:
# --> 107         return query_job.result(max_results=max_results)
#     108
#     109     i = 0
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/job/query.py in result(self, page_size, max_results, retry, timeout, start_index, job_retry)
#    1624                 # Since is_job_done() calls jobs.getQueryResults, which is a
#    1625                 # long-running API, don't delay the next request at all.
# -> 1626                 while not is_job_done():
#    1627                     pass
#    1628             else:
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /usr/local/lib/python3.10/dist-packages/google/cloud/bigquery/job/query.py in is_job_done()
#    1575                         # `job_retry` predicate.
#    1576                         restart_query_job = True
# -> 1577                         raise job_failed_exception
#    1578                     else:
#    1579                         # Make sure that the _query_results are cached so we
#
# BadRequest: 400 Syntax error: Expected end of input but got keyword BY at [7:5]; reason: invalidQuery, location: query, message: Syntax error: Expected end of input but got keyword BY at [7:5]
#
# Location: US
# Job ID: 98ab5dea-8d74-48b8-889f-29739d08ad3e

# %%
full.shape

# %%
full.columns

# %%
# Construct a reference to the "stories" table
table_ref = dataset_ref.table("stories")

# API request - fetch the table
table = client.get_table(table_ref)

# Preview the first five lines of the table
stories = client.list_rows(table, max_results=5).to_dataframe()
stories

# %%
stories.shape

# %%
stories.columns

# %%
query = """
        SELECT stories.id AS story_id, stories.by, stories.title, comments.ranking, comments.id
        FROM `bigquery-public-data.hacker_news.stories` AS stories
        LEFT JOIN `bigquery-public-data.hacker_news.comments` AS comments
        ON stories.id = comments.parent
        WHERE EXTRACT(DATE FROM stories.time_ts) = '2012-01-01'
        """

safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=TWO_GB)
comment_counts = client.query(query, job_config=safe_config).to_dataframe()
comment_counts

# %%
1-comment_counts["ranking"].isnull().mean()

# %% [markdown]
# ## Normalize table

# %%
query = """
        SELECT
          stories.id AS story_id,
          stories.by,
          stories.title,
          comments.ranking,
          comments.id
        FROM
          `bigquery-public-data.hacker_news.stories` AS stories
        LEFT JOIN
          `bigquery-public-data.hacker_news.comments` AS comments
        ON
          stories.id = comments.parent
        WHERE
          EXTRACT(DATE FROM stories.time_ts) = '2012-01-01'
        """

safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=TWO_GB)
comment_counts = client.query(query, job_config=safe_config).to_dataframe()
comment_counts

# %%
full[:2]

# %%
query = """
        SELECT
          parent,
          title,
          id
        FROM
          `bigquery-public-data.hacker_news.full`
        WHERE
          parent = 363 and title <> "None"
        ORDER BY
          id
        LIMIT 20
"""

safe_config = bigquery.QueryJobConfig(maximum_bytes_billed=TWO_GB)
comment_counts = client.query(query, job_config=safe_config).to_dataframe()
comment_counts
